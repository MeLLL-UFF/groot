# %%
import json
import numpy as np
import time

from src.experiments.aux_code import *
from datasets.get_datasets import *
import time
from src.brkga.genetic import genetic as brkga
from src.brkga_variation.genetic import genetic as brkga_var
from src.s_genetic.genetic import *
from src.predicate import *

# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# %%
source='teamplayssport'
target='companyeconomicsector'

# %%
kb = json.loads(open('src/experiments/kb.txt').readline())

kb_source = kb['nell_sports']
kb_target = kb['nell_finances']

# %%
pred_target = create_pred_target(kb_target)

# %%
sports_dataset = datasets.load('nell_sports', kb_source, target=source, seed=441773, balanced=0) #facts, pos, neg
finances_dataset = datasets.load('nell_finances', kb_target, target=target, seed=441773, balanced=0) #facts, pos, neg

# train_facts_source, train_pos_source, train_neg_source = get_train_division(sports_dataset)
# background_knowledge_src = boostsrl.modes(kb_source, [source], useStdLogicVariables=False, 
#                                       maxTreeDepth=3, nodeSize=2, numOfClauses=8)
# # model_src = boostsrl.train(background_knowledge_src, train_pos_source, np.random.choice(train_neg_source, 2*len(train_pos_source)), train_facts_source, trees=10)
# model_src = boostsrl.train(background_knowledge_src, train_pos_source, train_neg_source, train_facts_source, trees=10)

# structured_src, new_src_struct = create_structured_trees(model_src)

# %%
s_src = [['teamplayssport(A, B)',
  {'': 'athleteplayssport(C, B)',
   'true': 'athleteledsportsteam(C, D)',
   'true,true': 'teamplaysinleague(A, E), teamplaysinleague(D, E)',
   'true,true,true': 'athleteplaysforteam(C, D)',
   'true,true,false': 'teamplaysagainstteam(A, F), athleteplaysforteam(G, A)',
   'true,false': 'teamplaysagainstteam(H, A), athleteplaysinleague(C, I)',
   'true,false,true': 'athleteplaysforteam(J, H), athleteplaysinleague(J, I)',
   'true,false,false': 'teamalsoknownas(K, A)'},
  {'true,true,true,true': [1.08e-06, 0, 235],
   'true,true,true,false': [0.943, 1, 8],
   'true,true,false,true': [1.604, 3, 18],
   'true,true,false,false': [1.966, 4, 113],
   'true,false,true,true': [0.816, 1, 2],
   'true,false,true,false': [0.0, 0, 13],
   'true,false,false,true': [0.866, 1, 3],
   'true,false,false,false': [1.095, 3, 2],
   'false': [0.062, 781, 3]}],
 ['teamplayssport(A, B)',
  {'': 'athleteplayssport(C, B), athleteplaysinleague(C, D)',
   'true': 'athleteledsportsteam(C, E)',
   'true,true': 'teamplaysagainstteam(F, A), teamalsoknownas(G, F)',
   'true,false': 'teamplaysinleague(A, H), athleteplaysinleague(I, H)',
   'true,false,true': 'teamplaysagainstteam(A, J)',
   'false': 'teamplaysinleague(A, K)',
   'false,false': 'athleteplayssport(L, B)',
   'false,false,false': 'teamplaysagainstteam(A, M), teamalsoknownas(A, N)'},
  {'true,true,true': [0.102, 0, 163],
   'true,true,false': [0.097, 2, 211],
   'true,false,true,true': [0.816, 1, 2],
   'true,false,true,false': [0.981, 2, 3],
   'true,false,false': [0.091, 0, 12],
   'false,true': [0.054, 613, 2],
   'false,false,true': [0.816, 1, 2],
   'false,false,false,true': [0.949, 9, 1],
   'false,false,false,false': [0.997, 172, 1]}],
 ['teamplayssport(A, B)',
  {'': 'athleteplayssport(C, B), athleteplaysinleague(C, D)',
   'true': 'teamplaysagainstteam(E, A), teamplaysinleague(A, F)',
   'true,false': 'teamalsoknownas(G, A), teamplaysinleague(A, H)',
   'true,false,false': 'athleteledsportsteam(C, I), teamplaysagainstteam(A, J)',
   'false': 'teamalsoknownas(K, A), teamalsoknownas(L, K)',
   'false,true': 'teamplaysagainstteam(A, L), athleteplaysforteam(M, L)',
   'false,true,true': 'teamalsoknownas(N, L)',
   'false,true,false': 'teamalsoknownas(K, L)'},
  {'true,true': [0.071, 1, 211],
   'true,false,true': [0.054, 0, 21],
   'true,false,false,true': [1.356, 2, 20],
   'true,false,false,false': [2.142, 5, 139],
   'false,true,true,true': [7.45e-09, 22, 0],
   'false,true,true,false': [1.0, 2, 2],
   'false,true,false,true': [0.896, 81, 1],
   'false,true,false,false': [0.189, 4, 0],
   'false,false': [0.06, 694, 3]}],
 ['teamplayssport(A, B)',
  {'': 'athleteplayssport(C, B), athleteplaysinleague(C, D)',
   'true': 'athleteledsportsteam(C, E)',
   'true,true': 'teamplaysinleague(A, F), teamplaysinleague(E, F)',
   'true,true,false': 'athleteplaysforteam(C, G), teamalsoknownas(E, G)',
   'false': 'teamplaysinleague(A, H)',
   'false,true': 'teamalsoknownas(I, A), athleteplaysforteam(J, I)',
   'false,false': 'teamplaysagainstteam(A, K), teamalsoknownas(L, A)',
   'false,false,false': 'teamplaysagainstteam(M, A)'},
  {'true,true,true': [0.084, 0, 188],
   'true,true,false,true': [1.261, 2, 8],
   'true,true,false,false': [1.988, 4, 178],
   'true,false': [0.039, 0, 17],
   'false,true,true': [0.165, 60, 2],
   'false,true,false': [0.146, 584, 0],
   'false,false,true': [0.807, 3, 1],
   'false,false,false,true': [0.026, 66, 0],
   'false,false,false,false': [1.566, 107, 3]}],
 ['teamplayssport(A, B)',
  {'': 'athleteplayssport(C, B)',
   'true': 'athleteledsportsteam(C, D)',
   'true,true': 'athleteplaysforteam(E, A), athleteledsportsteam(E, F)',
   'true,true,true': 'teamplaysagainstteam(A, D), athleteplaysforteam(C, D)',
   'true,true,false': 'teamplaysagainstteam(A, G)',
   'true,false': 'teamplaysinleague(A, H), athleteplaysinleague(I, H)',
   'true,false,true': 'athleteplayssport(I, J)',
   'true,false,false': 'teamplaysagainstteam(K, A)'},
  {'true,true,true,true': [0.074, 0, 88],
   'true,true,true,false': [1.282, 2, 11],
   'true,true,false,true': [0.197, 0, 114],
   'true,true,false,false': [1.376, 2, 161],
   'true,false,true,true': [0.485, 5, 0],
   'true,false,true,false': [0.974, 2, 5],
   'true,false,false,true': [0.529, 1, 10],
   'true,false,false,false': [0.83, 1, 5],
   'false': [0.059, 782, 3]}],
 ['teamplayssport(A, B)',
  {'': 'athleteledsportsteam(C, A), athleteplayssport(C, D)',
   'true': 'athleteplayssport(E, B), athleteledsportsteam(E, F)',
   'true,true': 'teamplaysagainstteam(A, F)',
   'true,true,true': 'teamalsoknownas(G, A), teamalsoknownas(G, F)',
   'false': 'athleteplayssport(H, B)',
   'false,true': 'athleteplaysforteam(H, I)',
   'false,true,true': 'teamplaysinleague(A, J), athleteledsportsteam(K, I)',
   'false,true,false': 'athleteplaysinleague(H, L), teamplaysagainstteam(M, A)'},
  {'true,true,true,true': [0.961, 1, 12],
   'true,true,true,false': [0.07, 0, 75],
   'true,true,false': [0.843, 1, 3],
   'true,false': [0.368, 216, 0],
   'false,true,true,true': [1.784, 4, 204],
   'false,true,true,false': [1.237, 2, 82],
   'false,true,false,true': [0.746, 1, 15],
   'false,true,false,false': [1.09, 4, 3],
   'false,false': [0.068, 597, 3]}],
 ['teamplayssport(A, B)',
  {'': 'athleteplayssport(C, B), athleteplaysinleague(C, D)',
   'true': 'athleteledsportsteam(E, A)',
   'true,false': 'teamplaysinleague(A, F), teamplaysagainstteam(A, G)',
   'true,false,true': 'athleteledsportsteam(C, H), teamplaysinleague(H, F)',
   'true,false,false': 'teamplaysagainstteam(I, A), teamplaysinleague(I, J)',
   'false': 'teamalsoknownas(K, A), athleteplaysforteam(L, K)',
   'false,true': 'teamplaysagainstteam(M, A), teamplaysagainstteam(M, K)',
   'false,true,false': 'athleteledsportsteam(L, K)'},
  {'true,true': [0.159, 0, 107],
   'true,false,true,true': [0.996, 1, 69],
   'true,false,true,false': [1.784, 4, 29],
   'true,false,false,true': [0.147, 0, 37],
   'true,false,false,false': [1.716, 3, 149],
   'false,true,true': [0.05, 45, 0],
   'false,true,false,true': [0.0, 3, 0],
   'false,true,false,false': [1.066, 5, 2],
   'false,false': [0.066, 699, 4]}],
 ['teamplayssport(A, B)',
  {'': 'athleteplayssport(C, B), athleteplaysinleague(C, D)',
   'true': 'teamplaysinleague(A, E), athleteplaysinleague(F, E)',
   'true,true': 'athleteledsportsteam(C, G)',
   'true,true,true': 'teamplaysinleague(G, E), teamalsoknownas(G, H)',
   'true,true,false': 'athleteplaysforteam(I, A)',
   'false': 'teamalsoknownas(J, A), athleteplaysforteam(K, J)',
   'false,true': 'teamplaysagainstteam(L, A), teamplaysagainstteam(L, J)',
   'false,true,false': 'athleteledsportsteam(K, J)'},
  {'true,true,true,true': [1.404, 2, 185],
   'true,true,true,false': [1.883, 4, 37],
   'true,true,false,true': [0.081, 3, 0],
   'true,true,false,false': [0.018, 0, 5],
   'true,false': [0.144, 0, 164],
   'false,true,true': [0.087, 45, 0],
   'false,true,false,true': [1.86e-09, 3, 0],
   'false,true,false,false': [1.065, 3, 2],
   'false,false': [0.067, 716, 4]}],
 ['teamplayssport(A, B)',
  {'': 'athleteplayssport(C, B), athleteplaysforteam(C, D)',
   'true': 'teamalsoknownas(A, E), teamplaysagainstteam(A, F)',
   'true,true': 'athleteplaysforteam(G, A), athleteplaysforteam(H, F)',
   'true,true,false': 'athleteledsportsteam(C, D), teamalsoknownas(D, I)',
   'true,false': 'teamplaysagainstteam(A, J), teamalsoknownas(J, A)',
   'true,false,true': 'teamalsoknownas(J, D)',
   'true,false,false': 'teamalsoknownas(D, K), teamalsoknownas(K, L)',
   'false': 'teamplaysagainstteam(A, M), teamalsoknownas(N, A)'},
  {'true,true,true': [0.079, 0, 28],
   'true,true,false,true': [1.222, 3, 3],
   'true,true,false,false': [0.024, 0, 4],
   'true,false,true,true': [0.029, 0, 13],
   'true,false,true,false': [0.724, 2, 1],
   'true,false,false,true': [2.369, 6, 174],
   'true,false,false,false': [0.822, 2, 153],
   'false,true': [0.168, 64, 6],
   'false,false': [0.081, 662, 15]}],
 ['teamplayssport(A, B)',
  {'': 'athleteplayssport(C, B)',
   'true': 'athleteledsportsteam(C, D), teamplaysagainstteam(D, A)',
   'true,false': 'teamplaysagainstteam(A, E), athleteledsportsteam(F, E)',
   'true,false,true': 'athleteplaysinleague(F, G), teamplaysinleague(A, G)',
   'true,false,false': 'teamplaysinleague(A, H), teamalsoknownas(I, A)',
   'false': 'teamalsoknownas(J, A), teamplaysagainstteam(A, K)',
   'false,true': 'teamalsoknownas(L, K)',
   'false,true,false': 'teamalsoknownas(K, J)'},
  {'true,true': [0.103, 0, 165],
   'true,false,true,true': [1.526, 9, 4],
   'true,false,true,false': [0.381, 1, 27],
   'true,false,false,true': [0.415, 0, 25],
   'true,false,false,false': [2.65, 9, 173],
   'false,true,true': [0.037, 48, 0],
   'false,true,false,true': [1.216, 6, 2],
   'false,true,false,false': [0.019, 8, 0],
   'false,false': [0.038, 681, 1]}]]

# %%
import copy
src_struct = copy.deepcopy(s_src)
new_src_struct = []
for i in range(0, len(src_struct)):
    new_src_struct.append(define_individual(src_struct[i], i))  
structured_src = src_struct

# %%
new_src_struct
# Out:
# [['0;;teamplayssport(A, B) :- athleteplayssport(C, B).;true;false',
#   '0;true;athleteledsportsteam(C, D).;true;true',
#   '0;true,true;teamplaysinleague(A, E), teamplaysinleague(D, E).;true;true',
#   '0;true,true,true;athleteplaysforteam(C, D).;false;false',
#   '0;true,true,false;teamplaysagainstteam(A, F), athleteplaysforteam(G, A).;false;false',
#   '0;true,false;teamplaysagainstteam(H, A), athleteplaysinleague(C, I).;true;true',
#   '0;true,false,true;athleteplaysforteam(J, H), athleteplaysinleague(J, I).;false;false',
#   '0;true,false,false;teamalsoknownas(K, A).;false;false'],
#  ['1;;teamplayssport(A, B) :- athleteplayssport(C, B), athleteplaysinleague(C, D).;true;true',
#   '1;true;athleteledsportsteam(C, E).;true;true',
#   '1;true,true;teamplaysagainstteam(F, A), teamalsoknownas(G, F).;false;false',
#   '1;true,false;teamplaysinleague(A, H), athleteplaysinleague(I, H).;true;false',
#   '1;true,false,true;teamplaysagainstteam(A, J).;false;false',
#   '1;false;teamplaysinleague(A, K).;false;true',
#   '1;false,false;athleteplayssport(L, B).;false;true',
#   '1;false,false,false;teamplaysagainstteam(A, M), teamalsoknownas(A, N).;false;false'],
#  ['2;;teamplayssport(A, B) :- athleteplayssport(C, B), athleteplaysinleague(C, D).;true;true',
#   '2;true;teamplaysagainstteam(E, A), teamplaysinleague(A, F).;false;true',
#   '2;true,false;teamalsoknownas(G, A), teamplaysinleague(A, H).;false;true',
#   '2;true,false,false;athleteledsportsteam(C, I), teamplaysagainstteam(A, J).;false;false',
#   '2;false;teamalsoknownas(K, A), teamalsoknownas(L, K).;true;false',
#   '2;false,true;teamplaysagainstteam(A, L), athleteplaysforteam(M, L).;true;true',
#   '2;false,true,true;teamalsoknownas(N, L).;false;false',
#   '2;false,true,false;teamalsoknownas(K, L).;false;false'],
#  ['3;;teamplayssport(A, B) :- athleteplayssport(C, B), athleteplaysinleague(C, D).;true;true',
#   '3;true;athleteledsportsteam(C, E).;true;false',
#   '3;true,true;teamplaysinleague(A, F), teamplaysinleague(E, F).;false;true',
#   '3;true,true,false;athleteplaysforteam(C, G), teamalsoknownas(E, G).;false;false',
#   '3;false;teamplaysinleague(A, H).;true;true',
#   '3;false,true;teamalsoknownas(I, A), athleteplaysforteam(J, I).;false;false',
#   '3;false,false;teamplaysagainstteam(A, K), teamalsoknownas(L, A).;false;true',
#   '3;false,false,false;teamplaysagainstteam(M, A).;false;false'],
#  ['4;;teamplayssport(A, B) :- athleteplayssport(C, B).;true;false',
#   '4;true;athleteledsportsteam(C, D).;true;true',
#   '4;true,true;athleteplaysforteam(E, A), athleteledsportsteam(E, F).;true;true',
#   '4;true,true,true;teamplaysagainstteam(A, D), athleteplaysforteam(C, D).;false;false',
#   '4;true,true,false;teamplaysagainstteam(A, G).;false;false',
#   '4;true,false;teamplaysinleague(A, H), athleteplaysinleague(I, H).;true;true',
#   '4;true,false,true;athleteplayssport(I, J).;false;false',
#   '4;true,false,false;teamplaysagainstteam(K, A).;false;false'],
#  ['5;;teamplayssport(A, B) :- athleteledsportsteam(C, A), athleteplayssport(C, D).;true;true',
#   '5;true;athleteplayssport(E, B), athleteledsportsteam(E, F).;true;false',
#   '5;true,true;teamplaysagainstteam(A, F).;true;false',
#   '5;true,true,true;teamalsoknownas(G, A), teamalsoknownas(G, F).;false;false',
#   '5;false;athleteplayssport(H, B).;true;false',
#   '5;false,true;athleteplaysforteam(H, I).;true;true',
#   '5;false,true,true;teamplaysinleague(A, J), athleteledsportsteam(K, I).;false;false',
#   '5;false,true,false;athleteplaysinleague(H, L), teamplaysagainstteam(M, A).;false;false'],
#  ['6;;teamplayssport(A, B) :- athleteplayssport(C, B), athleteplaysinleague(C, D).;true;true',
#   '6;true;athleteledsportsteam(E, A).;false;true',
#   '6;true,false;teamplaysinleague(A, F), teamplaysagainstteam(A, G).;true;true',
#   '6;true,false,true;athleteledsportsteam(C, H), teamplaysinleague(H, F).;false;false',
#   '6;true,false,false;teamplaysagainstteam(I, A), teamplaysinleague(I, J).;false;false',
#   '6;false;teamalsoknownas(K, A), athleteplaysforteam(L, K).;true;false',
#   '6;false,true;teamplaysagainstteam(M, A), teamplaysagainstteam(M, K).;false;true',
#   '6;false,true,false;athleteledsportsteam(L, K).;false;false'],
#  ['7;;teamplayssport(A, B) :- athleteplayssport(C, B), athleteplaysinleague(C, D).;true;true',
#   '7;true;teamplaysinleague(A, E), athleteplaysinleague(F, E).;true;false',
#   '7;true,true;athleteledsportsteam(C, G).;true;true',
#   '7;true,true,true;teamplaysinleague(G, E), teamalsoknownas(G, H).;false;false',
#   '7;true,true,false;athleteplaysforteam(I, A).;false;false',
#   '7;false;teamalsoknownas(J, A), athleteplaysforteam(K, J).;true;false',
#   '7;false,true;teamplaysagainstteam(L, A), teamplaysagainstteam(L, J).;false;true',
#   '7;false,true,false;athleteledsportsteam(K, J).;false;false'],
#  ['8;;teamplayssport(A, B) :- athleteplayssport(C, B), athleteplaysforteam(C, D).;true;true',
#   '8;true;teamalsoknownas(A, E), teamplaysagainstteam(A, F).;true;true',
#   '8;true,true;athleteplaysforteam(G, A), athleteplaysforteam(H, F).;false;true',
#   '8;true,true,false;athleteledsportsteam(C, D), teamalsoknownas(D, I).;false;false',
#   '8;true,false;teamplaysagainstteam(A, J), teamalsoknownas(J, A).;true;true',
#   '8;true,false,true;teamalsoknownas(J, D).;false;false',
#   '8;true,false,false;teamalsoknownas(D, K), teamalsoknownas(K, L).;false;false',
#   '8;false;teamplaysagainstteam(A, M), teamalsoknownas(N, A).;false;false'],
#  ['9;;teamplayssport(A, B) :- athleteplayssport(C, B).;true;true',
#   '9;true;athleteledsportsteam(C, D), teamplaysagainstteam(D, A).;false;true',
#   '9;true,false;teamplaysagainstteam(A, E), athleteledsportsteam(F, E).;true;true',
#   '9;true,false,true;athleteplaysinleague(F, G), teamplaysinleague(A, G).;false;false',
#   '9;true,false,false;teamplaysinleague(A, H), teamalsoknownas(I, A).;false;false',
#   '9;false;teamalsoknownas(J, A), teamplaysagainstteam(A, K).;true;false',
#   '9;false,true;teamalsoknownas(L, K).;false;true',
#   '9;false,true,false;teamalsoknownas(K, J).;false;false']]

# %%
train_facts, train_pos, train_neg, test_facts, test_pos, test_neg = get_train_test(finances_dataset, 0)

facts = []
facts.extend(train_facts[0])
facts.extend(train_facts[1])
facts.extend(test_facts)
train_facts = [copy.deepcopy(facts), copy.deepcopy(facts)]
test_facts = [copy.deepcopy(facts)]
# Out:
# 0

# %%
with open('train_facts.txt', 'w') as f:
    for line in train_facts:
        f.write(json.dumps(line))
        f.write('\n')
f.close()

with open('train_neg.txt', 'w') as f:
    for line in train_neg:
        f.write(json.dumps(list(line)))
        f.write('\n')
f.close()

with open('train_pos.txt', 'w') as f:
    for line in train_pos:
        f.write(json.dumps(list(line)))
        f.write('\n')
f.close()

with open('test_facts.txt', 'w') as f:
    for line in test_facts:
        f.write(json.dumps(list(line)))
        f.write('\n')
f.close()

with open('test_pos.txt', 'w') as f:
    for line in test_pos:
        f.write(json.dumps(list(line)))
        f.write('\n')
f.close()

with open('test_neg.txt', 'w') as f:
    for line in test_neg:
        f.write(json.dumps(list(line)))
        f.write('\n')
f.close()

# %%
def get_k_best_individuals(population, k):
    best_ind = []
    all_fitness = []
    for i in range(0, len(population)):
        all_fitness.append((population[i].fitness.values[0], i))
    
    sorted_ind = sorted(all_fitness, key=lambda tup: tup[0])
    for i in range(0, k):
        best_ind.append(population[sorted_ind[i][1]])
    return best_ind

# %% [markdown]
# # Crossover original

# %% [markdown]
# ## sem revisão

# %%
start = time.time()
res_rc = genetic(new_src_struct, target, source, train_pos, 
                                         train_neg, train_facts, kb_source, kb_target, pred_target,
                                          NUM_GEN=14, pop_size=30)
print("FIM DO GROOT GENETIC: ", time.time()-start)
# Out:
# /Users/leticia.figueiredo/opt/anaconda3/envs/groot/lib/python3.6/site-packages/deap/creator.py:141: RuntimeWarning: A class named 'FitnessMin' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   RuntimeWarning)
# /Users/leticia.figueiredo/opt/anaconda3/envs/groot/lib/python3.6/site-packages/deap/creator.py:141: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   RuntimeWarning)
# GENERATION:  0
# MELHOR RESULTADO:  -0.32207775564644325
# estou nesse crossover
# BEST: {'m_auc_pr': 0.0375615, 'm_auc_roc': 0.7936215, 'm_cll': -0.31988, 'm_rec': 0.0, 'm_pred': 0.25, 'm_f1': nan, 's_auc_pr': 0.0034865, 's_auc_roc': 0.016376500000000016, 's_cll': 0.0010930000000000106, 's_rec': 0.0, 's_prec': 0.25, 's_f1': nan}
# GENERATION:  1
# MELHOR RESULTADO:  -0.32207775564644325
# estou nesse crossover
# BEST: {'m_auc_pr': 0.0375615, 'm_auc_roc': 0.7936215, 'm_cll': -0.31988, 'm_rec': 0.0, 'm_pred': 0.25, 'm_f1': nan, 's_auc_pr': 0.0034865, 's_auc_roc': 0.016376500000000016, 's_cll': 0.0010930000000000106, 's_rec': 0.0, 's_prec': 0.25, 's_f1': nan}
# GENERATION:  2
# MELHOR RESULTADO:  -0.32207775564644325
# estou nesse crossover
# BEST: {'m_auc_pr': 0.0375615, 'm_auc_roc': 0.7936215, 'm_cll': -0.31988, 'm_rec': 0.0, 'm_pred': 0.25, 'm_f1': nan, 's_auc_pr': 0.0034865, 's_auc_roc': 0.016376500000000016, 's_cll': 0.0010930000000000106, 's_rec': 0.0, 's_prec': 0.25, 's_f1': nan}
# GENERATION:  3
# MELHOR RESULTADO:  -0.32735099974072174
# estou nesse crossover
# BEST: {'m_auc_pr': 0.2213225, 'm_auc_roc': 0.9851455, 'm_cll': -0.241195, 'm_rec': 0.7316180000000001, 'm_pred': 0.325593, 'm_f1': 0.247435, 's_auc_pr': 0.007445499999999994, 's_auc_roc': 0.0006304999999999783, 's_cll': 0.0015430000000000027, 's_rec': 0.007352999999999998, 's_prec': 0.17747334646926563, 's_f1': 0.06443499999999999}
# GENERATION:  4
# MELHOR RESULTADO:  -0.32735099974072174
# estou nesse crossover
# BEST: {'m_auc_pr': 0.2213225, 'm_auc_roc': 0.9851455, 'm_cll': -0.241195, 'm_rec': 0.7316180000000001, 'm_pred': 0.325593, 'm_f1': 0.247435, 's_auc_pr': 0.007445499999999994, 's_auc_roc': 0.0006304999999999783, 's_cll': 0.0015430000000000027, 's_rec': 0.007352999999999998, 's_prec': 0.17747334646926563, 's_f1': 0.06443499999999999}
# GENERATION:  5
# MELHOR RESULTADO:  -0.32735099974072174
# estou nesse crossover
# BEST: {'m_auc_pr': 0.2213225, 'm_auc_roc': 0.9851455, 'm_cll': -0.241195, 'm_rec': 0.7316180000000001, 'm_pred': 0.325593, 'm_f1': 0.247435, 's_auc_pr': 0.007445499999999994, 's_auc_roc': 0.0006304999999999783, 's_cll': 0.0015430000000000027, 's_rec': 0.007352999999999998, 's_prec': 0.17747334646926563, 's_f1': 0.06443499999999999}
# GENERATION:  6
# MELHOR RESULTADO:  -0.3655850267177938
# estou nesse crossover
# BEST: {'m_auc_pr': 0.3173475, 'm_auc_roc': 0.9851384999999999, 'm_cll': -0.181502, 'm_rec': 1.0, 'm_pred': 0.2564395, 'm_f1': 0.02543, 's_auc_pr': 0.00973750000000001, 's_auc_roc': 0.0010724999999999763, 's_cll': 0.003716999999999998, 's_rec': 0.0, 's_prec': 0.24356067848638868, 's_f1': 0.0008120000000000002}
# GENERATION:  7
# MELHOR RESULTADO:  -0.3655850267177938
# estou nesse crossover
# BEST: {'m_auc_pr': 0.3173475, 'm_auc_roc': 0.9851384999999999, 'm_cll': -0.181502, 'm_rec': 1.0, 'm_pred': 0.2564395, 'm_f1': 0.02543, 's_auc_pr': 0.00973750000000001, 's_auc_roc': 0.0010724999999999763, 's_cll': 0.003716999999999998, 's_rec': 0.0, 's_prec': 0.24356067848638868, 's_f1': 0.0008120000000000002}
# GENERATION:  8
# MELHOR RESULTADO:  -0.36892446088630393
# estou nesse crossover
# BEST: {'m_auc_pr': 0.0013475, 'm_auc_roc': 0.49022750000000004, 'm_cll': -0.36892199999999997, 'm_rec': 0.0, 'm_pred': nan, 'm_f1': nan, 's_auc_pr': 5.049999999999998e-05, 's_auc_roc': 0.005008499999999999, 's_cll': 0.00011300000000000199, 's_rec': 0.0, 's_prec': nan, 's_f1': nan}
# GENERATION:  9
# MELHOR RESULTADO:  -0.36892446088630393
# estou nesse crossover
# BEST: {'m_auc_pr': 0.0013475, 'm_auc_roc': 0.49022750000000004, 'm_cll': -0.36892199999999997, 'm_rec': 0.0, 'm_pred': nan, 'm_f1': nan, 's_auc_pr': 5.049999999999998e-05, 's_auc_roc': 0.005008499999999999, 's_cll': 0.00011300000000000199, 's_rec': 0.0, 's_prec': nan, 's_f1': nan}
# GENERATION:  10
# MELHOR RESULTADO:  -0.36892446088630393
# estou nesse crossover
# BEST: {'m_auc_pr': 0.0013475, 'm_auc_roc': 0.49022750000000004, 'm_cll': -0.36892199999999997, 'm_rec': 0.0, 'm_pred': nan, 'm_f1': nan, 's_auc_pr': 5.049999999999998e-05, 's_auc_roc': 0.005008499999999999, 's_cll': 0.00011300000000000199, 's_rec': 0.0, 's_prec': nan, 's_f1': nan}
# GENERATION:  11
# MELHOR RESULTADO:  -0.36892446088630393
# estou nesse crossover
# BEST: {'m_auc_pr': 0.0013475, 'm_auc_roc': 0.49022750000000004, 'm_cll': -0.36892199999999997, 'm_rec': 0.0, 'm_pred': nan, 'm_f1': nan, 's_auc_pr': 5.049999999999998e-05, 's_auc_roc': 0.005008499999999999, 's_cll': 0.00011300000000000199, 's_rec': 0.0, 's_prec': nan, 's_f1': nan}
# GENERATION:  12
# MELHOR RESULTADO:  -0.36892446088630393
# estou nesse crossover
# BEST: {'m_auc_pr': 0.0013475, 'm_auc_roc': 0.49022750000000004, 'm_cll': -0.36892199999999997, 'm_rec': 0.0, 'm_pred': nan, 'm_f1': nan, 's_auc_pr': 5.049999999999998e-05, 's_auc_roc': 0.005008499999999999, 's_cll': 0.00011300000000000199, 's_rec': 0.0, 's_prec': nan, 's_f1': nan}
# GENERATION:  13
# MELHOR RESULTADO:  -0.36892446088630393
# estou nesse crossover
# BEST: {'m_auc_pr': 0.0013475, 'm_auc_roc': 0.49022750000000004, 'm_cll': -0.36892199999999997, 'm_rec': 0.0, 'm_pred': nan, 'm_f1': nan, 's_auc_pr': 5.049999999999998e-05, 's_auc_roc': 0.005008499999999999, 's_cll': 0.00011300000000000199, 's_rec': 0.0, 's_prec': nan, 's_f1': nan}
# -0.3899306564778538 -0.3899306564778538
# [{'m_auc_pr': 0.300833, 'm_auc_roc': 0.9838675, 'm_cll': -0.2480835, 'm_rec': 0.702206, 'm_pred': 0.311694, 'm_f1': 0.20989449999999998, 's_auc_pr': 0.005245, 's_auc_roc': 0.0006104999999999583, 's_cll': 0.0010365000000000096, 's_rec': 0.025734999999999952, 's_prec': 0.1883341149075228, 's_f1': 0.007807500000000009}]
# RESULT: {'m_auc_pr': 0.300833, 'm_auc_roc': 0.9838675, 'm_cll': -0.2480835, 'm_rec': 0.702206, 'm_pred': 0.311694, 'm_f1': 0.20989449999999998, 's_auc_pr': 0.005245, 's_auc_roc': 0.0006104999999999583, 's_cll': 0.0010365000000000096, 's_rec': 0.025734999999999952, 's_prec': 0.1883341149075228, 's_f1': 0.007807500000000009}
# FIM DO GROOT GENETIC:  5360.572069168091

# %%
res_rc
# Out:
# (<src.s_genetic.population.Population at 0x7fa9e22cbc18>,
#  [-0.32207775564644325,
#   -0.32207775564644325,
#   -0.32207775564644325,
#   -0.32735099974072174,
#   -0.32735099974072174,
#   -0.32735099974072174,
#   -0.3655850267177938,
#   -0.3655850267177938,
#   -0.36892446088630393,
#   -0.36892446088630393,
#   -0.36892446088630393,
#   -0.36892446088630393,
#   -0.36892446088630393,
#   -0.36892446088630393,
#   -0.3899306564778538],
#  [{'m_auc_pr': 0.0375615,
#    'm_auc_roc': 0.7936215,
#    'm_cll': -0.31988,
#    'm_rec': 0.0,
#    'm_pred': 0.25,
#    'm_f1': nan,
#    's_auc_pr': 0.0034865,
#    's_auc_roc': 0.016376500000000016,
#    's_cll': 0.0010930000000000106,
#    's_rec': 0.0,
#    's_prec': 0.25,
#    's_f1': nan},
#   {'m_auc_pr': 0.0375615,
#    'm_auc_roc': 0.7936215,
#    'm_cll': -0.31988,
#    'm_rec': 0.0,
#    'm_pred': 0.25,
#    'm_f1': nan,
#    's_auc_pr': 0.0034865,
#    's_auc_roc': 0.016376500000000016,
#    's_cll': 0.0010930000000000106,
#    's_rec': 0.0,
#    's_prec': 0.25,
#    's_f1': nan},
#   {'m_auc_pr': 0.0375615,
#    'm_auc_roc': 0.7936215,
#    'm_cll': -0.31988,
#    'm_rec': 0.0,
#    'm_pred': 0.25,
#    'm_f1': nan,
#    's_auc_pr': 0.0034865,
#    's_auc_roc': 0.016376500000000016,
#    's_cll': 0.0010930000000000106,
#    's_rec': 0.0,
#    's_prec': 0.25,
#    's_f1': nan},
#   {'m_auc_pr': 0.2213225,
#    'm_auc_roc': 0.9851455,
#    'm_cll': -0.241195,
#    'm_rec': 0.7316180000000001,
#    'm_pred': 0.325593,
#    'm_f1': 0.247435,
#    's_auc_pr': 0.007445499999999994,
#    's_auc_roc': 0.0006304999999999783,
#    's_cll': 0.0015430000000000027,
#    's_rec': 0.007352999999999998,
#    's_prec': 0.17747334646926563,
#    's_f1': 0.06443499999999999},
#   {'m_auc_pr': 0.2213225,
#    'm_auc_roc': 0.9851455,
#    'm_cll': -0.241195,
#    'm_rec': 0.7316180000000001,
#    'm_pred': 0.325593,
#    'm_f1': 0.247435,
#    's_auc_pr': 0.007445499999999994,
#    's_auc_roc': 0.0006304999999999783,
#    's_cll': 0.0015430000000000027,
#    's_rec': 0.007352999999999998,
#    's_prec': 0.17747334646926563,
#    's_f1': 0.06443499999999999},
#   {'m_auc_pr': 0.2213225,
#    'm_auc_roc': 0.9851455,
#    'm_cll': -0.241195,
#    'm_rec': 0.7316180000000001,
#    'm_pred': 0.325593,
#    'm_f1': 0.247435,
#    's_auc_pr': 0.007445499999999994,
#    's_auc_roc': 0.0006304999999999783,
#    's_cll': 0.0015430000000000027,
#    's_rec': 0.007352999999999998,
#    's_prec': 0.17747334646926563,
#    's_f1': 0.06443499999999999},
#   {'m_auc_pr': 0.3173475,
#    'm_auc_roc': 0.9851384999999999,
#    'm_cll': -0.181502,
#    'm_rec': 1.0,
#    'm_pred': 0.2564395,
#    'm_f1': 0.02543,
#    's_auc_pr': 0.00973750000000001,
#    's_auc_roc': 0.0010724999999999763,
#    's_cll': 0.003716999999999998,
#    's_rec': 0.0,
#    's_prec': 0.24356067848638868,
#    's_f1': 0.0008120000000000002},
#   {'m_auc_pr': 0.3173475,
#    'm_auc_roc': 0.9851384999999999,
#    'm_cll': -0.181502,
#    'm_rec': 1.0,
#    'm_pred': 0.2564395,
#    'm_f1': 0.02543,
#    's_auc_pr': 0.00973750000000001,
#    's_auc_roc': 0.0010724999999999763,
#    's_cll': 0.003716999999999998,
#    's_rec': 0.0,
#    's_prec': 0.24356067848638868,
#    's_f1': 0.0008120000000000002},
#   {'m_auc_pr': 0.0013475,
#    'm_auc_roc': 0.49022750000000004,
#    'm_cll': -0.36892199999999997,
#    'm_rec': 0.0,
#    'm_pred': nan,
#    'm_f1': nan,
#    's_auc_pr': 5.049999999999998e-05,
#    's_auc_roc': 0.005008499999999999,
#    's_cll': 0.00011300000000000199,
#    's_rec': 0.0,
#    's_prec': nan,
#    's_f1': nan},
#   {'m_auc_pr': 0.0013475,
#    'm_auc_roc': 0.49022750000000004,
#    'm_cll': -0.36892199999999997,
#    'm_rec': 0.0,
#    'm_pred': nan,
#    'm_f1': nan,
#    's_auc_pr': 5.049999999999998e-05,
#    's_auc_roc': 0.005008499999999999,
#    's_cll': 0.00011300000000000199,
#    's_rec': 0.0,
#    's_prec': nan,
#    's_f1': nan},
#   {'m_auc_pr': 0.0013475,
#    'm_auc_roc': 0.49022750000000004,
#    'm_cll': -0.36892199999999997,
#    'm_rec': 0.0,
#    'm_pred': nan,
#    'm_f1': nan,
#    's_auc_pr': 5.049999999999998e-05,
#    's_auc_roc': 0.005008499999999999,
#    's_cll': 0.00011300000000000199,
#    's_rec': 0.0,
#    's_prec': nan,
#    's_f1': nan},
#   {'m_auc_pr': 0.0013475,
#    'm_auc_roc': 0.49022750000000004,
#    'm_cll': -0.36892199999999997,
#    'm_rec': 0.0,
#    'm_pred': nan,
#    'm_f1': nan,
#    's_auc_pr': 5.049999999999998e-05,
#    's_auc_roc': 0.005008499999999999,
#    's_cll': 0.00011300000000000199,
#    's_rec': 0.0,
#    's_prec': nan,
#    's_f1': nan},
#   {'m_auc_pr': 0.0013475,
#    'm_auc_roc': 0.49022750000000004,
#    'm_cll': -0.36892199999999997,
#    'm_rec': 0.0,
#    'm_pred': nan,
#    'm_f1': nan,
#    's_auc_pr': 5.049999999999998e-05,
#    's_auc_roc': 0.005008499999999999,
#    's_cll': 0.00011300000000000199,
#    's_rec': 0.0,
#    's_prec': nan,
#    's_f1': nan},
#   {'m_auc_pr': 0.0013475,
#    'm_auc_roc': 0.49022750000000004,
#    'm_cll': -0.36892199999999997,
#    'm_rec': 0.0,
#    'm_pred': nan,
#    'm_f1': nan,
#    's_auc_pr': 5.049999999999998e-05,
#    's_auc_roc': 0.005008499999999999,
#    's_cll': 0.00011300000000000199,
#    's_rec': 0.0,
#    's_prec': nan,
#    's_f1': nan},
#   {'m_auc_pr': 0.300833,
#    'm_auc_roc': 0.9838675,
#    'm_cll': -0.2480835,
#    'm_rec': 0.702206,
#    'm_pred': 0.311694,
#    'm_f1': 0.20989449999999998,
#    's_auc_pr': 0.005245,
#    's_auc_roc': 0.0006104999999999583,
#    's_cll': 0.0010365000000000096,
#    's_rec': 0.025734999999999952,
#    's_prec': 0.1883341149075228,
#    's_f1': 0.007807500000000009}])

# %%
# final_results[f'groot_test:{source}->{target}'] = []
# final_results[f'groot_test_rev:{source}->{target}'] = []
# final_results[f'inf_res:{source}->{target}'] = []
# final_results[f'inf_res_rev:{source}->{target}'] = []

# uwcse_dataset = datasets.load('uwcse', kb_target, target=target, seed=441773)
# train_facts, train_pos, train_neg, test_facts, test_pos, test_neg = get_train_test(uwcse_dataset, 1)
# tr_train_pos = []
# tr_train_neg = []
# tr_train_facts = []

# for i in range(0, len(train_pos)):
#     tr_train_pos.extend(train_pos[i])
#     tr_train_neg.extend(train_neg[i])
#     tr_train_facts.extend(train_facts[i])

# train = [tr_train_pos, tr_train_neg, tr_train_facts]
test = [test_pos, test_neg, test_facts[0]]

individuals_rc = get_k_best_individuals(res_rc[0].population, 3)

# n_ind = 1
# for individual in individuals:
#     print("INDIVIDUO ", n_ind)
#     refine, transfer = get_refine_transfer(individual, source, target, 'nell_sports', 'nell_finances')
#     for i in range(len(train_pos)):
#         ttrain = [train_pos[i], train_neg[i][:len(train_pos[i])], train_facts[i]]
#         res_ = test_refine_transfer(kb_target, target, refine, transfer, ttrain, test)
#         print(res_)
# #         final_results[f'groot_test:{source}->{target}'].append(res)
# #         import os
#     #     thisFile = f'boostsrl/best/test/results_{target.replace('recursion_', '')}.db'
#     #     thisFile = f'boostsrl/best/test/results_{target}.db'
#     #     base = os.path.splitext(thisFile)[0]
#     #     os.rename(thisFile, base + ".txt")
#     #     tt = open('boostsrl/best/test/results_advisedby.txt', 'r').readlines()
#     #     final = []
#     #     for i in tt:
#     #         final.append(i.replace('\n', ''))
#     #     final_results[f'inf_res:{source}->{target}'].append(final)
#         print("===========================================================================")
# #         break

#     n_ind += 1

# %%
individuals_rc = get_k_best_individuals(res_rc[0].population, 3)
n_i = 1
for ind in individuals_rc:
    refine, transfer = get_refine_transfer(ind, source, target, 'nell_sports', 'nell_finances')
    print("INDIVIDUO ", n_i)
    print("REFINE: ", refine)
    print("TRANSFER: ", transfer)
    print("==========================")
    n_i += 1
# Out:
# INDIVIDUO  1
# REFINE:  ['0;;teamplayssport00(A,B):- athleteplayssport01(C, B);true;false', '0;true;athleteledsportsteam02(C, D).;true;true', '0;true,true;teamplaysinleague03(A, E), teamplaysinleague04(D, E).;true;true', '0;true,true,true;athleteplaysforteam04(C, D).;false;false', '0;true,true,false;teamplaysagainstteam05(A, F), athleteplaysforteam06(G, A).;false;false', '0;true,false;teamplaysagainstteam06(H, A), athleteplaysinleague07(I, C).;true;true', '0;true,false,true;athleteplaysforteam07(J, H), athleteplaysinleague08(I, J).;false;false', '0;true,false,false;teamalsoknownas08(K, A).;false;false', '1;;teamplayssport10(A,B):- athleteplayssport11(C, B), athleteplaysinleague11(D, C);true;true', '1;true;athleteledsportsteam12(C, E).;true;true', '1;true,true;teamplaysagainstteam13(F, A), teamalsoknownas14(G, F).;false;false', '1;true,false;teamplaysinleague14(H, A), athleteplaysinleague15(I, H).;true;false', '1;true,false,true;teamplaysagainstteam15(A, J).;false;false', '1;false;teamplaysinleague16(K, A).;false;true', '1;false,false;athleteplayssport17(B, L).;false;true', '1;false,false,false;teamplaysagainstteam18(A, M), teamalsoknownas19(A, N).;false;false', '2;;teamplayssport20(A,B):- athleteplayssport21(C, B), athleteplaysinleague21(C, D);true;true', '2;true;teamplaysagainstteam22(E, A), teamplaysinleague23(A, F).;false;true', '2;true,false;teamalsoknownas23(G, A), teamplaysinleague24(A, H).;false;true', '2;true,false,false;athleteledsportsteam24(C, I), teamplaysagainstteam25(A, J).;false;false', '2;false;teamalsoknownas25(K, A), teamalsoknownas26(L, K).;true;false', '2;false,true;teamplaysagainstteam26(A, L), athleteplaysforteam27(M, L).;true;true', '2;false,true,true;teamalsoknownas27(N, L).;false;false', '2;false,true,false;teamalsoknownas28(K, L).;false;false', '3;;teamplayssport30(A,B):- athleteplayssport31(B, C), athleteplaysinleague31(D, C);true;true', '3;true;athleteledsportsteam32(C, E).;true;false', '3;true,true;teamplaysinleague33(F, A), teamplaysinleague34(F, E).;false;true', '3;true,true,false;athleteplaysforteam34(C, G), teamalsoknownas35(E, G).;false;false', '3;false;teamplaysinleague35(H, A).;true;true', '3;false,true;teamalsoknownas36(I, A), athleteplaysforteam37(J, I).;false;false', '3;false,false;teamplaysagainstteam37(A, K), teamalsoknownas38(L, A).;false;true', '3;false,false,false;teamplaysagainstteam38(M, A).;false;false', '4;;teamplayssport40(A,B):- athleteplayssport41(C, B);true;false', '4;true;athleteledsportsteam42(C, D).;true;true', '4;true,true;athleteplaysforteam43(E, A), athleteledsportsteam44(E, F).;true;true', '4;true,true,true;teamplaysagainstteam44(A, D), athleteplaysforteam45(C, D).;false;false', '4;true,true,false;teamplaysagainstteam45(A, G).;false;false', '4;true,false;teamplaysinleague46(A, H), athleteplaysinleague47(I, H).;true;true', '4;true,false,true;athleteplayssport47(I, J).;false;false', '4;true,false,false;teamplaysagainstteam48(K, A).;false;false', '5;;teamplayssport50(A,B):- athleteledsportsteam51(C, A), athleteplayssport51(C, D);true;true', '5;true;athleteplayssport52(E, B), athleteledsportsteam53(E, F).;true;false', '5;true,true;teamplaysagainstteam53(A, F).;true;false', '5;true,true,true;teamalsoknownas54(G, A), teamalsoknownas55(G, F).;false;false', '5;false;athleteplayssport55(B, H).;true;false', '5;false,true;athleteplaysforteam56(H, I).;true;true', '5;false,true,true;teamplaysinleague57(J, A), athleteledsportsteam58(K, I).;false;false', '5;false,true,false;athleteplaysinleague58(H, L), teamplaysagainstteam59(M, A).;false;false', '6;;teamplayssport60(A,B):- athleteplayssport61(B, C), athleteplaysinleague61(C, D);true;true', '6;true;athleteledsportsteam62(E, A).;false;true', '6;true,false;teamplaysinleague63(A, F), teamplaysagainstteam64(A, G).;true;true', '6;true,false,true;athleteledsportsteam64(C, H), teamplaysinleague65(F, H).;false;false', '6;true,false,false;teamplaysagainstteam65(I, A), teamplaysinleague66(J, I).;false;false', '6;false;teamalsoknownas66(K, A), athleteplaysfor ...
# TRANSFER:  ['source: teamplayssport00(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport00(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport01(athlete,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplayssport01(A,B)=companyeconomicsector(A,B).', 'source: athleteledsportsteam02(athlete,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: athleteledsportsteam02(A,B)=companyalsoknownas(A,B).', 'source: teamplaysinleague03(sportsteam,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplaysinleague03(A,B)=companyeconomicsector(A,B).', 'source: teamplaysinleague04(sportsteam,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplaysinleague04(A,B)=companyeconomicsector(A,B).', 'source: athleteplaysforteam04(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteplaysforteam04(A,B)=bankboughtbank(A,B).', 'source: teamplaysagainstteam05(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamplaysagainstteam05(A,B)=acquired(A,B).', 'source: athleteplaysforteam06(athlete,sportsteam).', 'target: acquired(company,company).', 'setMap: athleteplaysforteam06(A,B)=acquired(A,B).', 'source: teamplaysagainstteam06(sportsteam,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: teamplaysagainstteam06(A,B)=bankboughtbank(A,B).', 'source: athleteplaysinleague07(athlete,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplaysinleague07(A,B)=economicsectorcompany(A,B).', 'source: athleteplaysforteam07(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteplaysforteam07(A,B)=bankboughtbank(A,B).', 'source: athleteplaysinleague08(athlete,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplaysinleague08(A,B)=economicsectorcompany(A,B).', 'source: teamalsoknownas08(sportsteam,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: teamalsoknownas08(A,B)=bankboughtbank(A,B).', 'source: teamplayssport10(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport10(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport11(athlete,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplayssport11(A,B)=companyeconomicsector(A,B).', 'source: athleteplaysinleague11(athlete,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplaysinleague11(A,B)=economicsectorcompany(A,B).', 'source: athleteledsportsteam12(athlete,sportsteam).', 'target: acquired(company,company).', 'setMap: athleteledsportsteam12(A,B)=acquired(A,B).', 'source: teamplaysagainstteam13(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamplaysagainstteam13(A,B)=companyalsoknownas(A,B).', 'source: teamalsoknownas14(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamalsoknownas14(A,B)=acquired(A,B).', 'source: teamplaysinleague14(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague14(A,B)=economicsectorcompany(A,B).', 'source: athleteplaysinleague15(athlete,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplaysinleague15(A,B)=companyeconomicsector(A,B).', 'source: teamplaysagainstteam15(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamplaysagainstteam15(A,B)=acquired(A,B).', 'source: teamplaysinleague16(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague16(A,B)=economicsectorcompany(A,B).', 'source: athleteplayssport17(athlete,sport).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplayssport17(A,B)=economicsectorcompany(A,B).', 'source: teamplaysagainstteam18(sportsteam,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: t ...
# ==========================
# INDIVIDUO  2
# REFINE:  ['0;;teamplayssport00(A,B):- athleteplayssport01(B, C);true;false', '0;true;athleteledsportsteam02(C, D).;true;true', '0;true,true;teamplaysinleague03(E, A), teamplaysinleague04(E, D).;true;true', '0;true,true,true;athleteplaysforteam04(C, D).;false;false', '0;true,true,false;teamplaysagainstteam05(A, F), athleteplaysforteam06(G, A).;false;false', '0;true,false;teamplaysagainstteam06(H, A), athleteplaysinleague07(I, C).;true;true', '0;true,false,true;athleteplaysforteam07(J, H), athleteplaysinleague08(J, I).;false;false', '0;true,false,false;teamalsoknownas08(K, A).;false;false', '1;;teamplayssport10(A,B):- athleteplayssport11(C, B), athleteplaysinleague11(D, C);true;true', '1;true;athleteledsportsteam12(C, E).;true;true', '1;true,true;teamplaysagainstteam13(F, A), teamalsoknownas14(G, F).;false;false', '1;true,false;teamplaysinleague14(A, H), athleteplaysinleague15(H, I).;true;false', '1;true,false,true;teamplaysagainstteam15(A, J).;false;false', '1;false;teamplaysinleague16(K, A).;false;true', '1;false,false;athleteplayssport17(L, B).;false;true', '1;false,false,false;teamplaysagainstteam18(A, M), teamalsoknownas19(A, N).;false;false', '2;;teamplayssport20(A,B):- athleteplayssport21(C, B), athleteplaysinleague21(D, C);true;true', '2;true;teamplaysagainstteam22(E, A), teamplaysinleague23(A, F).;false;true', '2;true,false;teamalsoknownas23(G, A), teamplaysinleague24(A, H).;false;true', '2;true,false,false;athleteledsportsteam24(C, I), teamplaysagainstteam25(A, J).;false;false', '2;false;teamalsoknownas25(K, A), teamalsoknownas26(L, K).;true;false', '2;false,true;teamplaysagainstteam26(A, L), athleteplaysforteam27(M, L).;true;true', '2;false,true,true;teamalsoknownas27(N, L).;false;false', '2;false,true,false;teamalsoknownas28(K, L).;false;false', '3;;teamplayssport30(A,B):- athleteplayssport31(B, C), athleteplaysinleague31(D, C);true;true', '3;true;athleteledsportsteam32(C, E).;true;false', '3;true,true;teamplaysinleague33(F, A), teamplaysinleague34(E, F).;false;true', '3;true,true,false;athleteplaysforteam34(C, G), teamalsoknownas35(E, G).;false;false', '3;false;teamplaysinleague35(A, H).;true;true', '3;false,true;teamalsoknownas36(I, A), athleteplaysforteam37(J, I).;false;false', '3;false,false;teamplaysagainstteam37(A, K), teamalsoknownas38(L, A).;false;true', '3;false,false,false;teamplaysagainstteam38(M, A).;false;false', '4;;teamplayssport40(A,B):- athleteplayssport41(C, B);true;false', '4;true;athleteledsportsteam42(C, D).;true;true', '4;true,true;athleteplaysforteam43(E, A), athleteledsportsteam44(E, F).;true;true', '4;true,true,true;teamplaysagainstteam44(A, D), athleteplaysforteam45(C, D).;false;false', '4;true,true,false;teamplaysagainstteam45(A, G).;false;false', '4;true,false;teamplaysinleague46(H, A), athleteplaysinleague47(I, H).;true;true', '4;true,false,true;athleteplayssport47(J, I).;false;false', '4;true,false,false;teamplaysagainstteam48(K, A).;false;false', '5;;teamplayssport50(A,B):- athleteledsportsteam51(C, A), athleteplayssport51(D, C);true;true', '5;true;athleteplayssport52(B, E), athleteledsportsteam53(E, F).;true;false', '5;true,true;teamplaysagainstteam53(A, F).;true;false', '5;true,true,true;teamalsoknownas54(G, A), teamalsoknownas55(G, F).;false;false', '5;false;athleteplayssport55(B, H).;true;false', '5;false,true;athleteplaysforteam56(H, I).;true;true', '5;false,true,true;teamplaysinleague57(A, J), athleteledsportsteam58(K, I).;false;false', '5;false,true,false;athleteplaysinleague58(L, H), teamplaysagainstteam59(M, A).;false;false', '6;;teamplayssport60(A,B):- athleteplayssport61(C, B), athleteplaysinleague61(C, D);true;true', '6;true;athleteledsportsteam62(E, A).;false;true', '6;true,false;teamplaysinleague63(A, F), teamplaysagainstteam64(A, G).;true;true', '6;true,false,true;athleteledsportsteam64(C, H), teamplaysinleague65(H, F).;false;false', '6;true,false,false;teamplaysagainstteam65(I, A), teamplaysinleague66(I, J).;false;false', '6;false;teamalsoknownas66(K, A), athleteplaysfor ...
# TRANSFER:  ['source: teamplayssport00(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport00(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport01(athlete,sport).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplayssport01(A,B)=economicsectorcompany(A,B).', 'source: athleteledsportsteam02(athlete,sportsteam).', 'target: acquired(company,company).', 'setMap: athleteledsportsteam02(A,B)=acquired(A,B).', 'source: teamplaysinleague03(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague03(A,B)=economicsectorcompany(A,B).', 'source: teamplaysinleague04(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague04(A,B)=economicsectorcompany(A,B).', 'source: athleteplaysforteam04(athlete,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: athleteplaysforteam04(A,B)=companyalsoknownas(A,B).', 'source: teamplaysagainstteam05(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamplaysagainstteam05(A,B)=companyalsoknownas(A,B).', 'source: athleteplaysforteam06(athlete,sportsteam).', 'target: acquired(company,company).', 'setMap: athleteplaysforteam06(A,B)=acquired(A,B).', 'source: teamplaysagainstteam06(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamplaysagainstteam06(A,B)=acquired(A,B).', 'source: athleteplaysinleague07(athlete,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplaysinleague07(A,B)=economicsectorcompany(A,B).', 'source: athleteplaysforteam07(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteplaysforteam07(A,B)=bankboughtbank(A,B).', 'source: athleteplaysinleague08(athlete,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplaysinleague08(A,B)=companyeconomicsector(A,B).', 'source: teamalsoknownas08(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamalsoknownas08(A,B)=companyalsoknownas(A,B).', 'source: teamplayssport10(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport10(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport11(athlete,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplayssport11(A,B)=companyeconomicsector(A,B).', 'source: athleteplaysinleague11(athlete,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplaysinleague11(A,B)=economicsectorcompany(A,B).', 'source: athleteledsportsteam12(athlete,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: athleteledsportsteam12(A,B)=companyalsoknownas(A,B).', 'source: teamplaysagainstteam13(sportsteam,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: teamplaysagainstteam13(A,B)=bankboughtbank(A,B).', 'source: teamalsoknownas14(sportsteam,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: teamalsoknownas14(A,B)=bankboughtbank(A,B).', 'source: teamplaysinleague14(sportsteam,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplaysinleague14(A,B)=companyeconomicsector(A,B).', 'source: athleteplaysinleague15(athlete,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplaysinleague15(A,B)=economicsectorcompany(A,B).', 'source: teamplaysagainstteam15(sportsteam,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: teamplaysagainstteam15(A,B)=bankboughtbank(A,B).', 'source: teamplaysinleague16(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague16(A,B)=economicsectorcompany(A,B).', 'source: athleteplayssport17(athlete,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplayssport17(A,B)=companyeconomicsector(A,B).', 'source: teamplaysagainstteam18(sportsteam,sportsteam).', 'target: compa ...
# ==========================
# INDIVIDUO  3
# REFINE:  ['0;;teamplayssport00(A,B):- athleteplayssport01(C, B);true;false', '0;true;athleteledsportsteam02(C, D).;true;true', '0;true,true;teamplaysinleague03(A, E), teamplaysinleague04(E, D).;true;true', '0;true,true,true;athleteplaysforteam04(C, D).;false;false', '0;true,true,false;teamplaysagainstteam05(A, F), athleteplaysforteam06(G, A).;false;false', '0;true,false;teamplaysagainstteam06(H, A), athleteplaysinleague07(C, I).;true;true', '0;true,false,true;athleteplaysforteam07(J, H), athleteplaysinleague08(J, I).;false;false', '0;true,false,false;teamalsoknownas08(K, A).;false;false', '1;;teamplayssport10(A,B):- athleteplayssport11(C, B), athleteplaysinleague11(D, C);true;true', '1;true;athleteledsportsteam12(C, E).;true;true', '1;true,true;teamplaysagainstteam13(F, A), teamalsoknownas14(G, F).;false;false', '1;true,false;teamplaysinleague14(H, A), athleteplaysinleague15(H, I).;true;false', '1;true,false,true;teamplaysagainstteam15(A, J).;false;false', '1;false;teamplaysinleague16(K, A).;false;true', '1;false,false;athleteplayssport17(B, L).;false;true', '1;false,false,false;teamplaysagainstteam18(A, M), teamalsoknownas19(A, N).;false;false', '2;;teamplayssport20(A,B):- athleteplayssport21(B, C), athleteplaysinleague21(C, D);true;true', '2;true;teamplaysagainstteam22(E, A), teamplaysinleague23(A, F).;false;true', '2;true,false;teamalsoknownas23(G, A), teamplaysinleague24(A, H).;false;true', '2;true,false,false;athleteledsportsteam24(C, I), teamplaysagainstteam25(A, J).;false;false', '2;false;teamalsoknownas25(K, A), teamalsoknownas26(L, K).;true;false', '2;false,true;teamplaysagainstteam26(A, L), athleteplaysforteam27(M, L).;true;true', '2;false,true,true;teamalsoknownas27(N, L).;false;false', '2;false,true,false;teamalsoknownas28(K, L).;false;false', '3;;teamplayssport30(A,B):- athleteplayssport31(C, B), athleteplaysinleague31(C, D);true;true', '3;true;athleteledsportsteam32(C, E).;true;false', '3;true,true;teamplaysinleague33(A, F), teamplaysinleague34(E, F).;false;true', '3;true,true,false;athleteplaysforteam34(C, G), teamalsoknownas35(E, G).;false;false', '3;false;teamplaysinleague35(H, A).;true;true', '3;false,true;teamalsoknownas36(I, A), athleteplaysforteam37(J, I).;false;false', '3;false,false;teamplaysagainstteam37(A, K), teamalsoknownas38(L, A).;false;true', '3;false,false,false;teamplaysagainstteam38(M, A).;false;false', '4;;teamplayssport40(A,B):- athleteplayssport41(C, B);true;false', '4;true;athleteledsportsteam42(C, D).;true;true', '4;true,true;athleteplaysforteam43(E, A), athleteledsportsteam44(E, F).;true;true', '4;true,true,true;teamplaysagainstteam44(A, D), athleteplaysforteam45(C, D).;false;false', '4;true,true,false;teamplaysagainstteam45(A, G).;false;false', '4;true,false;teamplaysinleague46(A, H), athleteplaysinleague47(H, I).;true;true', '4;true,false,true;athleteplayssport47(I, J).;false;false', '4;true,false,false;teamplaysagainstteam48(K, A).;false;false', '5;;teamplayssport50(A,B):- athleteledsportsteam51(C, A), athleteplayssport51(C, D);true;true', '5;true;athleteplayssport52(B, E), athleteledsportsteam53(E, F).;true;false', '5;true,true;teamplaysagainstteam53(A, F).;true;false', '5;true,true,true;teamalsoknownas54(G, A), teamalsoknownas55(G, F).;false;false', '5;false;athleteplayssport55(H, B).;true;false', '5;false,true;athleteplaysforteam56(H, I).;true;true', '5;false,true,true;teamplaysinleague57(J, A), athleteledsportsteam58(K, I).;false;false', '5;false,true,false;athleteplaysinleague58(H, L), teamplaysagainstteam59(M, A).;false;false', '6;;teamplayssport60(A,B):- athleteplayssport61(C, B), athleteplaysinleague61(D, C);true;true', '6;true;athleteledsportsteam62(E, A).;false;true', '6;true,false;teamplaysinleague63(F, A), teamplaysagainstteam64(A, G).;true;true', '6;true,false,true;athleteledsportsteam64(C, H), teamplaysinleague65(H, F).;false;false', '6;true,false,false;teamplaysagainstteam65(I, A), teamplaysinleague66(I, J).;false;false', '6;false;teamalsoknownas66(K, A), athleteplaysfor ...
# TRANSFER:  ['source: teamplayssport00(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport00(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport01(athlete,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplayssport01(A,B)=companyeconomicsector(A,B).', 'source: athleteledsportsteam02(athlete,sportsteam).', 'target: acquired(company,company).', 'setMap: athleteledsportsteam02(A,B)=acquired(A,B).', 'source: teamplaysinleague03(sportsteam,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplaysinleague03(A,B)=companyeconomicsector(A,B).', 'source: teamplaysinleague04(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague04(A,B)=economicsectorcompany(A,B).', 'source: athleteplaysforteam04(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteplaysforteam04(A,B)=bankboughtbank(A,B).', 'source: teamplaysagainstteam05(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamplaysagainstteam05(A,B)=acquired(A,B).', 'source: athleteplaysforteam06(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteplaysforteam06(A,B)=bankboughtbank(A,B).', 'source: teamplaysagainstteam06(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamplaysagainstteam06(A,B)=companyalsoknownas(A,B).', 'source: athleteplaysinleague07(athlete,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplaysinleague07(A,B)=companyeconomicsector(A,B).', 'source: athleteplaysforteam07(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteplaysforteam07(A,B)=bankboughtbank(A,B).', 'source: athleteplaysinleague08(athlete,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplaysinleague08(A,B)=companyeconomicsector(A,B).', 'source: teamalsoknownas08(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamalsoknownas08(A,B)=companyalsoknownas(A,B).', 'source: teamplayssport10(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport10(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport11(athlete,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplayssport11(A,B)=companyeconomicsector(A,B).', 'source: athleteplaysinleague11(athlete,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplaysinleague11(A,B)=economicsectorcompany(A,B).', 'source: athleteledsportsteam12(athlete,sportsteam).', 'target: acquired(company,company).', 'setMap: athleteledsportsteam12(A,B)=acquired(A,B).', 'source: teamplaysagainstteam13(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamplaysagainstteam13(A,B)=companyalsoknownas(A,B).', 'source: teamalsoknownas14(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamalsoknownas14(A,B)=acquired(A,B).', 'source: teamplaysinleague14(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague14(A,B)=economicsectorcompany(A,B).', 'source: athleteplaysinleague15(athlete,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplaysinleague15(A,B)=economicsectorcompany(A,B).', 'source: teamplaysagainstteam15(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamplaysagainstteam15(A,B)=companyalsoknownas(A,B).', 'source: teamplaysinleague16(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague16(A,B)=economicsectorcompany(A,B).', 'source: athleteplayssport17(athlete,sport).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplayssport17(A,B)=economicsectorcompany(A,B).', 'source: teamplaysagainstteam18(sportsteam,sportsteam).', 'target: acquired(company, ...
# ==========================

# %% [markdown]
# ## Aleatório

# %%
start = time.time()
res_a_c = genetic(new_src_struct, target, source, train_pos, 
                                         train_neg, train_facts, kb_source, kb_target, pred_target,
                                          NUM_GEN=14, pop_size=30, revision='random')
print("FIM DO GROOT GENETIC: ", time.time()-start)
# Out:
# GENERATION:  0
# MELHOR RESULTADO:  -0.24708988438268772
# estou nesse crossover
# BEST: {'m_auc_pr': 0.0368805, 'm_auc_roc': 0.9694309999999999, 'm_cll': -0.24432199999999998, 'm_rec': 0.8841915, 'm_pred': 0.26174675000000003, 'm_f1': 0.045771000000000006, 's_auc_pr': 0.0062875, 's_auc_roc': 0.0004909999999999637, 's_cll': 5.9999999999990616e-05, 's_rec': 0.020220499999999975, 's_prec': 0.238253519190562, 's_f1': 0.0009879999999999993}
# GENERATION:  1
# MELHOR RESULTADO:  -0.28682109052595833
# estou nesse crossover
# BEST: {'m_auc_pr': 0.08115449999999999, 'm_auc_roc': 0.9777415, 'm_cll': -0.27510049999999997, 'm_rec': 0.3970585, 'm_pred': 0.32243374999999996, 'm_f1': 0.212264, 's_auc_pr': 0.004139499999999997, 's_auc_roc': 0.0005364999999999953, 's_cll': 0.0011015000000000053, 's_rec': 0.003676499999999999, 's_prec': 0.177594096937898, 's_f1': 0.005301}
# GENERATION:  2
# MELHOR RESULTADO:  -0.3005812665528243
# estou nesse crossover
# BEST: {'m_auc_pr': 0.0117505, 'm_auc_roc': 0.941775, 'm_cll': -0.3003515, 'm_rec': 0.0, 'm_pred': nan, 'm_f1': nan, 's_auc_pr': 0.00034049999999999966, 's_auc_roc': 0.00047000000000002595, 's_cll': 0.0001855000000000051, 's_rec': 0.0, 's_prec': nan, 's_f1': nan}
# GENERATION:  3
# MELHOR RESULTADO:  -0.3005812665528243
# estou nesse crossover
# BEST: {'m_auc_pr': 0.0117505, 'm_auc_roc': 0.941775, 'm_cll': -0.3003515, 'm_rec': 0.0, 'm_pred': nan, 'm_f1': nan, 's_auc_pr': 0.00034049999999999966, 's_auc_roc': 0.00047000000000002595, 's_cll': 0.0001855000000000051, 's_rec': 0.0, 's_prec': nan, 's_f1': nan}
# GENERATION:  4
# MELHOR RESULTADO:  -0.3005812665528243
# estou nesse crossover
# BEST: {'m_auc_pr': 0.0117505, 'm_auc_roc': 0.941775, 'm_cll': -0.3003515, 'm_rec': 0.0, 'm_pred': nan, 'm_f1': nan, 's_auc_pr': 0.00034049999999999966, 's_auc_roc': 0.00047000000000002595, 's_cll': 0.0001855000000000051, 's_rec': 0.0, 's_prec': nan, 's_f1': nan}
# GENERATION:  5
# MELHOR RESULTADO:  -0.8945696161977837
# estou nesse crossover
# BEST: {'m_auc_pr': 0.8828445, 'm_auc_roc': 0.9991235, 'm_cll': -0.144362, 'm_rec': 1.0, 'm_pred': 0.26876925, 'm_f1': 0.0723605, 's_auc_pr': 0.018198500000000006, 's_auc_roc': 1.650000000003038e-05, 's_cll': 0.0004720000000000002, 's_rec': 0.0, 's_prec': 0.2312307681315086, 's_f1': 0.00024049999999999766}
# GENERATION:  6
# MELHOR RESULTADO:  -1.0101397485730625
# estou nesse crossover
# BEST: {'m_auc_pr': 0.992955, 'm_auc_roc': 0.9999895, 'm_cll': -0.18553350000000002, 'm_rec': 0.865809, 'm_pred': 0.74789025, 'm_f1': 0.9262565, 's_auc_pr': 0.007031999999999983, 's_auc_roc': 1.0500000000024379e-05, 's_cll': 0.00010449999999999349, 's_rec': 0.0018379999999999508, 's_prec': 0.2479082050582181, 's_f1': 0.002877500000000033}
# GENERATION:  7
# MELHOR RESULTADO:  -1.0101397485730625
# estou nesse crossover
# BEST: {'m_auc_pr': 0.992955, 'm_auc_roc': 0.9999895, 'm_cll': -0.18553350000000002, 'm_rec': 0.865809, 'm_pred': 0.74789025, 'm_f1': 0.9262565, 's_auc_pr': 0.007031999999999983, 's_auc_roc': 1.0500000000024379e-05, 's_cll': 0.00010449999999999349, 's_rec': 0.0018379999999999508, 's_prec': 0.2479082050582181, 's_f1': 0.002877500000000033}
# GENERATION:  8
# MELHOR RESULTADO:  -1.0101397485730625
# estou nesse crossover
# BEST: {'m_auc_pr': 0.992955, 'm_auc_roc': 0.9999895, 'm_cll': -0.18553350000000002, 'm_rec': 0.865809, 'm_pred': 0.74789025, 'm_f1': 0.9262565, 's_auc_pr': 0.007031999999999983, 's_auc_roc': 1.0500000000024379e-05, 's_cll': 0.00010449999999999349, 's_rec': 0.0018379999999999508, 's_prec': 0.2479082050582181, 's_f1': 0.002877500000000033}
# GENERATION:  9
# MELHOR RESULTADO:  -1.0101397485730625
# estou nesse crossover
# BEST: {'m_auc_pr': 0.992955, 'm_auc_roc': 0.9999895, 'm_cll': -0.18553350000000002, 'm_rec': 0.865809, 'm_pred': 0.74789025, 'm_f1': 0.9262565, 's_auc_pr': 0.007031999999999983, 's_auc_roc': 1.0500000000024379e-05, 's_cll': 0.00010449999999999349, 's_rec': 0.0018379999999999508, 's_prec': 0.2479082050582181, 's_f1': 0.002877500000000033}
# GENERATION:  10
# MELHOR RESULTADO:  -1.0101397485730625
# estou nesse crossover
# BEST: {'m_auc_pr': 0.992955, 'm_auc_roc': 0.9999895, 'm_cll': -0.18553350000000002, 'm_rec': 0.865809, 'm_pred': 0.74789025, 'm_f1': 0.9262565, 's_auc_pr': 0.007031999999999983, 's_auc_roc': 1.0500000000024379e-05, 's_cll': 0.00010449999999999349, 's_rec': 0.0018379999999999508, 's_prec': 0.2479082050582181, 's_f1': 0.002877500000000033}
# GENERATION:  11
# MELHOR RESULTADO:  -1.0101397485730625
# estou nesse crossover
# BEST: {'m_auc_pr': 0.992955, 'm_auc_roc': 0.9999895, 'm_cll': -0.18553350000000002, 'm_rec': 0.865809, 'm_pred': 0.74789025, 'm_f1': 0.9262565, 's_auc_pr': 0.007031999999999983, 's_auc_roc': 1.0500000000024379e-05, 's_cll': 0.00010449999999999349, 's_rec': 0.0018379999999999508, 's_prec': 0.2479082050582181, 's_f1': 0.002877500000000033}
# GENERATION:  12
# MELHOR RESULTADO:  -1.0101397485730625
# estou nesse crossover
# BEST: {'m_auc_pr': 0.992955, 'm_auc_roc': 0.9999895, 'm_cll': -0.18553350000000002, 'm_rec': 0.865809, 'm_pred': 0.74789025, 'm_f1': 0.9262565, 's_auc_pr': 0.007031999999999983, 's_auc_roc': 1.0500000000024379e-05, 's_cll': 0.00010449999999999349, 's_rec': 0.0018379999999999508, 's_prec': 0.2479082050582181, 's_f1': 0.002877500000000033}
# GENERATION:  13
# MELHOR RESULTADO:  -1.0101397485730625
# estou nesse crossover
# BEST: {'m_auc_pr': 0.992955, 'm_auc_roc': 0.9999895, 'm_cll': -0.18553350000000002, 'm_rec': 0.865809, 'm_pred': 0.74789025, 'm_f1': 0.9262565, 's_auc_pr': 0.007031999999999983, 's_auc_roc': 1.0500000000024379e-05, 's_cll': 0.00010449999999999349, 's_rec': 0.0018379999999999508, 's_prec': 0.2479082050582181, 's_f1': 0.002877500000000033}
# -1.0101397485730625 -1.0101397485730625
# -1.0101397485730625 -1.0101397485730625
# -1.0101397485730625 -1.0101397485730625
# -1.0101397485730625 -1.0101397485730625
# -1.0101397485730625 -1.0101397485730625
# -1.0101397485730625 -1.0101397485730625
# -1.0101397485730625 -1.0101397485730625
# [{'m_auc_pr': 0.992955, 'm_auc_roc': 0.9999895, 'm_cll': -0.18553350000000002, 'm_rec': 0.865809, 'm_pred': 0.74789025, 'm_f1': 0.9262565, 's_auc_pr': 0.007031999999999983, 's_auc_roc': 1.0500000000024379e-05, 's_cll': 0.00010449999999999349, 's_rec': 0.0018379999999999508, 's_prec': 0.2479082050582181, 's_f1': 0.002877500000000033}, {'m_auc_pr': 0.992955, 'm_auc_roc': 0.9999895, 'm_cll': -0.18553350000000002, 'm_rec': 0.865809, 'm_pred': 0.74789025, 'm_f1': 0.9262565, 's_auc_pr': 0.007031999999999983, 's_auc_roc': 1.0500000000024379e-05, 's_cll': 0.00010449999999999349, 's_rec': 0.0018379999999999508, 's_prec': 0.2479082050582181, 's_f1': 0.002877500000000033}, {'m_auc_pr': 0.992955, 'm_auc_roc': 0.9999895, 'm_cll': -0.18553350000000002, 'm_rec': 0.865809, 'm_pred': 0.74789025, 'm_f1': 0.9262565, 's_auc_pr': 0.007031999999999983, 's_auc_roc': 1.0500000000024379e-05, 's_cll': 0.00010449999999999349, 's_rec': 0.0018379999999999508, 's_prec': 0.2479082050582181, 's_f1': 0.002877500000000033}, {'m_auc_pr': 0.992955, 'm_auc_roc': 0.9999895, 'm_cll': -0.18553350000000002, 'm_rec': 0.865809, 'm_pred': 0.74789025, 'm_f1': 0.9262565, 's_auc_pr': 0.007031999999999983, 's_auc_roc': 1.0500000000024379e-05, 's_cll': 0.00010449999999999349, 's_rec': 0.0018379999999999508, 's_prec': 0.2479082050582181, 's_f1': 0.002877500000000033}, {'m_auc_pr': 0.992955, 'm_auc_roc': 0.9999895, 'm_cll': -0.18553350000000002, 'm_rec': 0.865809, 'm_pred': 0.74789025, 'm_f1': 0.9262565, 's_auc_pr': 0.007031999999999983, 's_auc_roc': 1.0500000000024379e-05, 's_cll': 0.00010449999999999349, 's_rec': 0.0018379999999999508, 's_prec': 0.2479082050582181, 's_f1': 0.002877500000000033}, {'m_auc_pr': 0.992955, 'm_auc_roc': 0.9999895, 'm_cll': -0.18553350000000002, 'm_rec': 0.865809, 'm_pred': 0.74789025, 'm_f1': 0.9262565, 's_auc_pr': 0.007031999999999983, 's_auc_roc': 1.0500000000024379e-05, 's_cll': 0.00010449999999999349, 's_rec': 0.0018379999999999508, 's_prec': 0.2479082050582181, 's_f1': 0.002877500000000033}, {'m_auc_pr': 0.992955, 'm_auc_roc': 0.9999895, 'm_cll': -0.18553350000000002, 'm_rec': 0.865809, 'm_pred': 0.74789025, 'm_f1': 0.9262565, 's_auc_pr': 0.007031999999999983, 's_auc_roc': 1.0500000000024379e-05, 's_cll': 0.00010449999999999349, 's_rec': 0.0018379999999999508, 's_prec': 0.2479082050582181, 's_f1': 0.002877500000000033}]
# RESULT: {'m_auc_pr': 0.992955, 'm_auc_roc': 0.9999895, 'm_cll': -0.18553350000000002, 'm_rec': 0.865809, 'm_pred': 0.74789025, 'm_f1': 0.9262565, 's_auc_pr': 0.007031999999999983, 's_auc_roc': 1.0500000000024379e-05, 's_cll': 0.00010449999999999349, 's_rec': 0.0018379999999999508, 's_prec': 0.2479082050582181, 's_f1': 0.002877500000000033}
# FIM DO GROOT GENETIC:  7919.4995040893555

# %%
res_a_c
# Out:
# (<src.s_genetic.population.Population at 0x7fa9b7ad4cc0>,
#  [-0.24708988438268772,
#   -0.28682109052595833,
#   -0.3005812665528243,
#   -0.3005812665528243,
#   -0.3005812665528243,
#   -0.8945696161977837,
#   -1.0101397485730625,
#   -1.0101397485730625,
#   -1.0101397485730625,
#   -1.0101397485730625,
#   -1.0101397485730625,
#   -1.0101397485730625,
#   -1.0101397485730625,
#   -1.0101397485730625,
#   -1.0101397485730625],
#  [{'m_auc_pr': 0.0368805,
#    'm_auc_roc': 0.9694309999999999,
#    'm_cll': -0.24432199999999998,
#    'm_rec': 0.8841915,
#    'm_pred': 0.26174675000000003,
#    'm_f1': 0.045771000000000006,
#    's_auc_pr': 0.0062875,
#    's_auc_roc': 0.0004909999999999637,
#    's_cll': 5.9999999999990616e-05,
#    's_rec': 0.020220499999999975,
#    's_prec': 0.238253519190562,
#    's_f1': 0.0009879999999999993},
#   {'m_auc_pr': 0.08115449999999999,
#    'm_auc_roc': 0.9777415,
#    'm_cll': -0.27510049999999997,
#    'm_rec': 0.3970585,
#    'm_pred': 0.32243374999999996,
#    'm_f1': 0.212264,
#    's_auc_pr': 0.004139499999999997,
#    's_auc_roc': 0.0005364999999999953,
#    's_cll': 0.0011015000000000053,
#    's_rec': 0.003676499999999999,
#    's_prec': 0.177594096937898,
#    's_f1': 0.005301},
#   {'m_auc_pr': 0.0117505,
#    'm_auc_roc': 0.941775,
#    'm_cll': -0.3003515,
#    'm_rec': 0.0,
#    'm_pred': nan,
#    'm_f1': nan,
#    's_auc_pr': 0.00034049999999999966,
#    's_auc_roc': 0.00047000000000002595,
#    's_cll': 0.0001855000000000051,
#    's_rec': 0.0,
#    's_prec': nan,
#    's_f1': nan},
#   {'m_auc_pr': 0.0117505,
#    'm_auc_roc': 0.941775,
#    'm_cll': -0.3003515,
#    'm_rec': 0.0,
#    'm_pred': nan,
#    'm_f1': nan,
#    's_auc_pr': 0.00034049999999999966,
#    's_auc_roc': 0.00047000000000002595,
#    's_cll': 0.0001855000000000051,
#    's_rec': 0.0,
#    's_prec': nan,
#    's_f1': nan},
#   {'m_auc_pr': 0.0117505,
#    'm_auc_roc': 0.941775,
#    'm_cll': -0.3003515,
#    'm_rec': 0.0,
#    'm_pred': nan,
#    'm_f1': nan,
#    's_auc_pr': 0.00034049999999999966,
#    's_auc_roc': 0.00047000000000002595,
#    's_cll': 0.0001855000000000051,
#    's_rec': 0.0,
#    's_prec': nan,
#    's_f1': nan},
#   {'m_auc_pr': 0.8828445,
#    'm_auc_roc': 0.9991235,
#    'm_cll': -0.144362,
#    'm_rec': 1.0,
#    'm_pred': 0.26876925,
#    'm_f1': 0.0723605,
#    's_auc_pr': 0.018198500000000006,
#    's_auc_roc': 1.650000000003038e-05,
#    's_cll': 0.0004720000000000002,
#    's_rec': 0.0,
#    's_prec': 0.2312307681315086,
#    's_f1': 0.00024049999999999766},
#   {'m_auc_pr': 0.992955,
#    'm_auc_roc': 0.9999895,
#    'm_cll': -0.18553350000000002,
#    'm_rec': 0.865809,
#    'm_pred': 0.74789025,
#    'm_f1': 0.9262565,
#    's_auc_pr': 0.007031999999999983,
#    's_auc_roc': 1.0500000000024379e-05,
#    's_cll': 0.00010449999999999349,
#    's_rec': 0.0018379999999999508,
#    's_prec': 0.2479082050582181,
#    's_f1': 0.002877500000000033},
#   {'m_auc_pr': 0.992955,
#    'm_auc_roc': 0.9999895,
#    'm_cll': -0.18553350000000002,
#    'm_rec': 0.865809,
#    'm_pred': 0.74789025,
#    'm_f1': 0.9262565,
#    's_auc_pr': 0.007031999999999983,
#    's_auc_roc': 1.0500000000024379e-05,
#    's_cll': 0.00010449999999999349,
#    's_rec': 0.0018379999999999508,
#    's_prec': 0.2479082050582181,
#    's_f1': 0.002877500000000033},
#   {'m_auc_pr': 0.992955,
#    'm_auc_roc': 0.9999895,
#    'm_cll': -0.18553350000000002,
#    'm_rec': 0.865809,
#    'm_pred': 0.74789025,
#    'm_f1': 0.9262565,
#    's_auc_pr': 0.007031999999999983,
#    's_auc_roc': 1.0500000000024379e-05,
#    's_cll': 0.00010449999999999349,
#    's_rec': 0.0018379999999999508,
#    's_prec': 0.2479082050582181,
#    's_f1': 0.002877500000000033},
#   {'m_auc_pr': 0.992955,
#    'm_auc_roc': 0.9999895,
#    'm_cll': -0.18553350000000002,
#    'm_rec': 0.865809,
#    'm_pred': 0.74789025,
#    'm_f1': 0.9262565,
#    's_auc_pr': 0.007031999999999983,
#    's_auc_roc': 1.0500000000024379e-05,
#    's_cll': 0.00010449999999999349,
#    's_rec': 0.0018379999999999508,
#    's_prec': 0.2479082050582181,
#    's_f1': 0.002877500000000033},
#   {'m_auc_pr': 0.992955,
#    'm_auc_roc': 0.9999895,
#    'm_cll': -0.18553350000000002,
#    'm_rec': 0.865809,
#    'm_pred': 0.74789025,
#    'm_f1': 0.9262565,
#    's_auc_pr': 0.007031999999999983,
#    's_auc_roc': 1.0500000000024379e-05,
#    's_cll': 0.00010449999999999349,
#    's_rec': 0.0018379999999999508,
#    's_prec': 0.2479082050582181,
#    's_f1': 0.002877500000000033},
#   {'m_auc_pr': 0.992955,
#    'm_auc_roc': 0.9999895,
#    'm_cll': -0.18553350000000002,
#    'm_rec': 0.865809,
#    'm_pred': 0.74789025,
#    'm_f1': 0.9262565,
#    's_auc_pr': 0.007031999999999983,
#    's_auc_roc': 1.0500000000024379e-05,
#    's_cll': 0.00010449999999999349,
#    's_rec': 0.0018379999999999508,
#    's_prec': 0.2479082050582181,
#    's_f1': 0.002877500000000033},
#   {'m_auc_pr': 0.992955,
#    'm_auc_roc': 0.9999895,
#    'm_cll': -0.18553350000000002,
#    'm_rec': 0.865809,
#    'm_pred': 0.74789025,
#    'm_f1': 0.9262565,
#    's_auc_pr': 0.007031999999999983,
#    's_auc_roc': 1.0500000000024379e-05,
#    's_cll': 0.00010449999999999349,
#    's_rec': 0.0018379999999999508,
#    's_prec': 0.2479082050582181,
#    's_f1': 0.002877500000000033},
#   {'m_auc_pr': 0.992955,
#    'm_auc_roc': 0.9999895,
#    'm_cll': -0.18553350000000002,
#    'm_rec': 0.865809,
#    'm_pred': 0.74789025,
#    'm_f1': 0.9262565,
#    's_auc_pr': 0.007031999999999983,
#    's_auc_roc': 1.0500000000024379e-05,
#    's_cll': 0.00010449999999999349,
#    's_rec': 0.0018379999999999508,
#    's_prec': 0.2479082050582181,
#    's_f1': 0.002877500000000033},
#   {'m_auc_pr': 0.992955,
#    'm_auc_roc': 0.9999895,
#    'm_cll': -0.18553350000000002,
#    'm_rec': 0.865809,
#    'm_pred': 0.74789025,
#    'm_f1': 0.9262565,
#    's_auc_pr': 0.007031999999999983,
#    's_auc_roc': 1.0500000000024379e-05,
#    's_cll': 0.00010449999999999349,
#    's_rec': 0.0018379999999999508,
#    's_prec': 0.2479082050582181,
#    's_f1': 0.002877500000000033}])

# %%
# final_results[f'groot_test:{source}->{target}'] = []
# final_results[f'groot_test_rev:{source}->{target}'] = []
# final_results[f'inf_res:{source}->{target}'] = []
# final_results[f'inf_res_rev:{source}->{target}'] = []

# uwcse_dataset = datasets.load('uwcse', kb_target, target=target, seed=441773)
# train_facts, train_pos, train_neg, test_facts, test_pos, test_neg = get_train_test(uwcse_dataset, 1)
# tr_train_pos = []
# tr_train_neg = []
# tr_train_facts = []

# for i in range(0, len(train_pos)):
#     tr_train_pos.extend(train_pos[i])
#     tr_train_neg.extend(train_neg[i])
#     tr_train_facts.extend(train_facts[i])

# train = [tr_train_pos, tr_train_neg, tr_train_facts]
test = [test_pos, test_neg, test_facts[0]]

individuals = get_k_best_individuals(res_a_c[0].population, 3)

n_ind = 1
for individual in individuals:
    print("INDIVIDUO ", n_ind)
    refine, transfer = get_refine_transfer(individual, source, target, 'nell_sports', 'nell_finances')
    for i in range(len(train_pos)):
        ttrain = [train_pos[i], train_neg[i][:len(train_pos[i])], train_facts[i]]
        res_ = test_refine_transfer(kb_target, target, refine, transfer, ttrain, test)
        print(res_)
#         final_results[f'groot_test:{source}->{target}'].append(res)
#         import os
    #     thisFile = f'boostsrl/best/test/results_{target.replace('recursion_', '')}.db'
    #     thisFile = f'boostsrl/best/test/results_{target}.db'
    #     base = os.path.splitext(thisFile)[0]
    #     os.rename(thisFile, base + ".txt")
    #     tt = open('boostsrl/best/test/results_advisedby.txt', 'r').readlines()
    #     final = []
    #     for i in tt:
    #         final.append(i.replace('\n', ''))
    #     final_results[f'inf_res:{source}->{target}'].append(final)
        print("===========================================================================")
#         break

    n_ind += 1
# Out:
# INDIVIDUO  1
# ({'AUC ROC': 0.999623, 'AUC PR': 0.973354, 'CLL': -0.265389, 'Precision': [0.882129, 0.5], 'Recall': 0.991453, 'F1': 0.933602}, <boostsrl.boostsrl.test object at 0x7fa9db4daeb8>)
# ===========================================================================
# ({'AUC ROC': 0.999652, 'AUC PR': 0.99174, 'CLL': -0.266361, 'Precision': [0.698795, 0.5], 'Recall': 0.991453, 'F1': 0.819788}, <boostsrl.boostsrl.test object at 0x7fa9db4da550>)
# ===========================================================================
# INDIVIDUO  2
# ({'AUC ROC': 0.999623, 'AUC PR': 0.973354, 'CLL': -0.265389, 'Precision': [0.882129, 0.5], 'Recall': 0.991453, 'F1': 0.933602}, <boostsrl.boostsrl.test object at 0x7fa98766b080>)
# ===========================================================================
# ({'AUC ROC': 0.999652, 'AUC PR': 0.99174, 'CLL': -0.266361, 'Precision': [0.698795, 0.5], 'Recall': 0.991453, 'F1': 0.819788}, <boostsrl.boostsrl.test object at 0x7fa9db4dacf8>)
# ===========================================================================
# INDIVIDUO  3
# ({'AUC ROC': 0.999623, 'AUC PR': 0.973354, 'CLL': -0.265389, 'Precision': [0.882129, 0.5], 'Recall': 0.991453, 'F1': 0.933602}, <boostsrl.boostsrl.test object at 0x7fa98766b080>)
# ===========================================================================
# ({'AUC ROC': 0.999652, 'AUC PR': 0.99174, 'CLL': -0.266361, 'Precision': [0.698795, 0.5], 'Recall': 0.991453, 'F1': 0.819788}, <boostsrl.boostsrl.test object at 0x7fa9db4daa20>)
# ===========================================================================

# %%
individuals_rc = get_k_best_individuals(res_a_c[0].population, 3)
n_i = 1
for ind in individuals_rc:
    refine, transfer = get_refine_transfer(ind, source, target, 'nell_sports', 'nell_finances')
    print("INDIVIDUO ", n_i)
    print("REFINE: ", refine)
    print("TRANSFER: ", transfer)
    print("==========================")
    n_i += 1
# Out:
# INDIVIDUO  1
# REFINE:  ['0;;teamplayssport00(A,B):- athleteplayssport01(C, B);true;false', '0;true;athleteledsportsteam02(C, D).;true;true', '0;true,true;teamplaysinleague03(A, E), teamplaysinleague04(D, E).;true;true', '0;true,true,true;athleteplaysforteam04(C, D).;false;true', '0;true,true,true,false;bankboughtbanktarget05(B, G), companyeconomicsectortarget06(K, B).;false;false', '0;true,true,false;teamplaysagainstteam06(A, F), athleteplaysforteam07(G, A).;false;false', '0;true,false;teamplaysagainstteam07(H, A), athleteplaysinleague08(C, I).;true;true', '0;true,false,true;athleteplaysforteam08(J, H), athleteplaysinleague09(J, I).;false;false', '0;true,false,false;teamalsoknownas09(K, A).;false;false', '1;;teamplayssport10(A,B):- athleteplayssport11(C, B), athleteplaysinleague11(C, D);true;true', '1;true;athleteledsportsteam12(C, E).;true;true', '1;true,true;teamplaysagainstteam13(F, A), teamalsoknownas14(G, F).;false;false', '1;true,false;teamplaysinleague14(A, H), athleteplaysinleague15(I, H).;true;false', '1;true,false,true;teamplaysagainstteam15(A, J).;false;false', '1;false;teamplaysinleague16(A, K).;false;true', '1;false,false;athleteplayssport17(L, B).;true;true', '1;false,false,true;countryhascompanyofficetarget18(W, B).;false;false', '1;false,false,false;teamplaysagainstteam19(A, M), teamalsoknownas110(A, N).;false;false', '2;;teamplayssport20(A,B):- athleteplayssport21(C, B), athleteplaysinleague21(C, D);true;true', '2;true;teamplaysagainstteam22(E, A), teamplaysinleague23(A, F).;false;true', '2;true,false;teamalsoknownas23(G, A), teamplaysinleague24(A, H).;false;true', '2;true,false,false;athleteledsportsteam24(C, I), teamplaysagainstteam25(A, J).;false;false', '2;false;teamalsoknownas25(K, A), teamalsoknownas26(L, K).;true;true', '2;false,false;companyeconomicsectortarget26(B, A).;false;false', '2;false,true;teamplaysagainstteam27(A, L), athleteplaysforteam28(M, L).;true;true', '2;false,true,true;teamalsoknownas28(N, L).;false;false', '2;false,true,false;teamalsoknownas29(K, L).;false;false', '3;;teamplayssport30(A,B):- athleteplayssport31(B, C), athleteplaysinleague31(C, D);false;false', '4;;teamplayssport40(A,B):- athleteplayssport41(B, C);true;false', '4;true;athleteledsportsteam42(C, D).;true;true', '4;true,true;athleteplaysforteam43(E, A), athleteledsportsteam44(E, F).;true;true', '4;true,true,true;teamplaysagainstteam44(A, D), athleteplaysforteam45(C, D).;false;false', '4;true,true,false;teamplaysagainstteam45(A, G).;false;false', '4;true,false;teamplaysinleague46(A, H), athleteplaysinleague47(I, H).;true;true', '4;true,false,true;athleteplayssport47(I, J).;false;true', '4;true,false,true,false;companyeconomicsectortarget48(A, P).;false;true', '4;true,false,true,false,false;companyalsoknownastarget49(S, P).;false;false', '4;true,false,false;teamplaysagainstteam410(K, A).;false;true', '4;true,false,false,false;companyeconomicsectortarget411(Y, G), bankboughtbanktarget412(E, Z).;false;false', '5;;teamplayssport50(A,B):- athleteledsportsteam51(C, A), athleteplayssport51(D, C);true;true', '5;true;athleteplayssport52(E, B), athleteledsportsteam53(E, F).;true;false', '5;true,true;teamplaysagainstteam53(A, F).;true;false', '5;true,true,true;teamalsoknownas54(G, A), teamalsoknownas55(G, F).;false;true', '5;true,true,true,false;countryhascompanyofficetarget55(Y, E).;false;false', '5;false;athleteplayssport56(H, B).;true;false', '5;false,true;athleteplaysforteam57(H, I).;true;true', '5;false,true,true;teamplaysinleague58(A, J), athleteledsportsteam59(K, I).;false;false', '5;false,true,false;athleteplaysinleague59(H, L), teamplaysagainstteam510(M, A).;false;false', '6;;teamplayssport60(A,B):- athleteplayssport61(C, B), athleteplaysinleague61(C, D);true;true', '6;true;athleteledsportsteam62(E, A).;false;true', '6;true,false;teamplaysinleague63(A, F), teamplaysagainstteam64(A, G).;true;true', '6;true,false,true;athleteledsportsteam64(C, H), teamplaysinleague65(H, F).;false;false', '6;true,false,false;teamplaysagainstteam65(I, A), tea ...
# TRANSFER:  ['source: teamplayssport00(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport00(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport01(athlete,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplayssport01(A,B)=companyeconomicsector(A,B).', 'source: athleteledsportsteam02(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteledsportsteam02(A,B)=bankboughtbank(A,B).', 'source: teamplaysinleague03(sportsteam,sportsleague).', 'target: companyalsoknownas(company,company).', 'setMap: teamplaysinleague03(A,B)=companyalsoknownas(A,B).', 'source: teamplaysinleague04(sportsteam,sportsleague).', 'target: bankboughtbank(company,company).', 'setMap: teamplaysinleague04(A,B)=bankboughtbank(A,B).', 'source: athleteplaysforteam04(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteplaysforteam04(A,B)=bankboughtbank(A,B).', 'source: bankboughtbanktarget05(bankboughtbanktype1,bankboughtbanktype2).', 'target: companyalsoknownas(company,company).', 'setMap: bankboughtbanktarget05(A,B)=companyalsoknownas(A,B).', 'source: companyeconomicsectortarget06(companyeconomicsectortype1,companyeconomicsectortype2).', 'target: economicsectorcompany(company,sector).', 'setMap: companyeconomicsectortarget06(A,B)=economicsectorcompany(A,B).', 'source: teamplaysagainstteam06(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamplaysagainstteam06(A,B)=acquired(A,B).', 'source: athleteplaysforteam07(athlete,sportsteam).', 'target: acquired(company,company).', 'setMap: athleteplaysforteam07(A,B)=acquired(A,B).', 'source: teamplaysagainstteam07(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamplaysagainstteam07(A,B)=companyalsoknownas(A,B).', 'source: athleteplaysinleague08(athlete,sportsleague).', 'target: companyalsoknownas(company,company).', 'setMap: athleteplaysinleague08(A,B)=companyalsoknownas(A,B).', 'source: athleteplaysforteam08(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteplaysforteam08(A,B)=bankboughtbank(A,B).', 'source: athleteplaysinleague09(athlete,sportsleague).', 'target: bankboughtbank(company,company).', 'setMap: athleteplaysinleague09(A,B)=bankboughtbank(A,B).', 'source: teamalsoknownas09(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamalsoknownas09(A,B)=companyalsoknownas(A,B).', 'source: teamplayssport10(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport10(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport11(athlete,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplayssport11(A,B)=companyeconomicsector(A,B).', 'source: athleteplaysinleague11(athlete,sportsleague).', 'target: acquired(company,company).', 'setMap: athleteplaysinleague11(A,B)=acquired(A,B).', 'source: athleteledsportsteam12(athlete,sportsteam).', 'target: acquired(company,company).', 'setMap: athleteledsportsteam12(A,B)=acquired(A,B).', 'source: teamplaysagainstteam13(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamplaysagainstteam13(A,B)=acquired(A,B).', 'source: teamalsoknownas14(sportsteam,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: teamalsoknownas14(A,B)=bankboughtbank(A,B).', 'source: teamplaysinleague14(sportsteam,sportsleague).', 'target: companyalsoknownas(company,company).', 'setMap: teamplaysinleague14(A,B)=companyalsoknownas(A,B).', 'source: athleteplaysinleague15(athlete,sportsleague).', 'target: bankboughtbank(company,company).', 'setMap: athleteplaysinleague15(A,B)=bankboughtbank(A,B).', 'source: teamplaysagainstteam15(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamplaysagainstteam15(A,B)=acquired(A,B).', 'source: teamplaysinleague16(sportsteam,sportsleague).', 'target: companyalsoknownas(company,company).', 'setMap:  ...
# ==========================
# INDIVIDUO  2
# REFINE:  ['0;;teamplayssport00(A,B):- athleteplayssport01(C, B);true;false', '0;true;athleteledsportsteam02(C, D).;true;true', '0;true,true;teamplaysinleague03(A, E), teamplaysinleague04(D, E).;true;true', '0;true,true,true;athleteplaysforteam04(C, D).;false;true', '0;true,true,true,false;bankboughtbanktarget05(B, G), companyeconomicsectortarget06(K, B).;false;false', '0;true,true,false;teamplaysagainstteam06(A, F), athleteplaysforteam07(G, A).;false;false', '0;true,false;teamplaysagainstteam07(H, A), athleteplaysinleague08(C, I).;true;true', '0;true,false,true;athleteplaysforteam08(J, H), athleteplaysinleague09(J, I).;false;false', '0;true,false,false;teamalsoknownas09(K, A).;false;false', '1;;teamplayssport10(A,B):- athleteplayssport11(C, B), athleteplaysinleague11(C, D);true;true', '1;true;athleteledsportsteam12(C, E).;true;true', '1;true,true;teamplaysagainstteam13(F, A), teamalsoknownas14(G, F).;false;false', '1;true,false;teamplaysinleague14(A, H), athleteplaysinleague15(I, H).;true;false', '1;true,false,true;teamplaysagainstteam15(A, J).;false;false', '1;false;teamplaysinleague16(A, K).;false;true', '1;false,false;athleteplayssport17(L, B).;true;true', '1;false,false,true;countryhascompanyofficetarget18(W, B).;false;false', '1;false,false,false;teamplaysagainstteam19(A, M), teamalsoknownas110(A, N).;false;false', '2;;teamplayssport20(A,B):- athleteplayssport21(C, B), athleteplaysinleague21(C, D);true;true', '2;true;teamplaysagainstteam22(E, A), teamplaysinleague23(A, F).;false;true', '2;true,false;teamalsoknownas23(G, A), teamplaysinleague24(A, H).;false;true', '2;true,false,false;athleteledsportsteam24(C, I), teamplaysagainstteam25(A, J).;false;false', '2;false;teamalsoknownas25(K, A), teamalsoknownas26(L, K).;true;true', '2;false,false;companyeconomicsectortarget26(B, A).;false;false', '2;false,true;teamplaysagainstteam27(A, L), athleteplaysforteam28(M, L).;true;true', '2;false,true,true;teamalsoknownas28(N, L).;false;false', '2;false,true,false;teamalsoknownas29(K, L).;false;false', '3;;teamplayssport30(A,B):- athleteplayssport31(B, C), athleteplaysinleague31(C, D);false;false', '4;;teamplayssport40(A,B):- athleteplayssport41(B, C);true;false', '4;true;athleteledsportsteam42(C, D).;true;true', '4;true,true;athleteplaysforteam43(E, A), athleteledsportsteam44(E, F).;true;true', '4;true,true,true;teamplaysagainstteam44(A, D), athleteplaysforteam45(C, D).;false;false', '4;true,true,false;teamplaysagainstteam45(A, G).;false;false', '4;true,false;teamplaysinleague46(A, H), athleteplaysinleague47(I, H).;true;true', '4;true,false,true;athleteplayssport47(I, J).;false;true', '4;true,false,true,false;companyeconomicsectortarget48(A, P).;false;true', '4;true,false,true,false,false;companyalsoknownastarget49(S, P).;false;false', '4;true,false,false;teamplaysagainstteam410(K, A).;false;true', '4;true,false,false,false;companyeconomicsectortarget411(Y, G), bankboughtbanktarget412(E, Z).;false;false', '5;;teamplayssport50(A,B):- athleteledsportsteam51(C, A), athleteplayssport51(D, C);true;true', '5;true;athleteplayssport52(E, B), athleteledsportsteam53(E, F).;true;false', '5;true,true;teamplaysagainstteam53(A, F).;true;false', '5;true,true,true;teamalsoknownas54(G, A), teamalsoknownas55(G, F).;false;true', '5;true,true,true,false;countryhascompanyofficetarget55(Y, E).;false;false', '5;false;athleteplayssport56(H, B).;true;false', '5;false,true;athleteplaysforteam57(H, I).;true;true', '5;false,true,true;teamplaysinleague58(A, J), athleteledsportsteam59(K, I).;false;false', '5;false,true,false;athleteplaysinleague59(H, L), teamplaysagainstteam510(M, A).;false;false', '6;;teamplayssport60(A,B):- athleteplayssport61(C, B), athleteplaysinleague61(C, D);true;true', '6;true;athleteledsportsteam62(E, A).;false;true', '6;true,false;teamplaysinleague63(A, F), teamplaysagainstteam64(A, G).;true;true', '6;true,false,true;athleteledsportsteam64(C, H), teamplaysinleague65(H, F).;false;false', '6;true,false,false;teamplaysagainstteam65(I, A), tea ...
# TRANSFER:  ['source: teamplayssport00(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport00(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport01(athlete,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplayssport01(A,B)=companyeconomicsector(A,B).', 'source: athleteledsportsteam02(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteledsportsteam02(A,B)=bankboughtbank(A,B).', 'source: teamplaysinleague03(sportsteam,sportsleague).', 'target: companyalsoknownas(company,company).', 'setMap: teamplaysinleague03(A,B)=companyalsoknownas(A,B).', 'source: teamplaysinleague04(sportsteam,sportsleague).', 'target: bankboughtbank(company,company).', 'setMap: teamplaysinleague04(A,B)=bankboughtbank(A,B).', 'source: athleteplaysforteam04(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteplaysforteam04(A,B)=bankboughtbank(A,B).', 'source: bankboughtbanktarget05(bankboughtbanktype1,bankboughtbanktype2).', 'target: companyalsoknownas(company,company).', 'setMap: bankboughtbanktarget05(A,B)=companyalsoknownas(A,B).', 'source: companyeconomicsectortarget06(companyeconomicsectortype1,companyeconomicsectortype2).', 'target: economicsectorcompany(company,sector).', 'setMap: companyeconomicsectortarget06(A,B)=economicsectorcompany(A,B).', 'source: teamplaysagainstteam06(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamplaysagainstteam06(A,B)=acquired(A,B).', 'source: athleteplaysforteam07(athlete,sportsteam).', 'target: acquired(company,company).', 'setMap: athleteplaysforteam07(A,B)=acquired(A,B).', 'source: teamplaysagainstteam07(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamplaysagainstteam07(A,B)=companyalsoknownas(A,B).', 'source: athleteplaysinleague08(athlete,sportsleague).', 'target: companyalsoknownas(company,company).', 'setMap: athleteplaysinleague08(A,B)=companyalsoknownas(A,B).', 'source: athleteplaysforteam08(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteplaysforteam08(A,B)=bankboughtbank(A,B).', 'source: athleteplaysinleague09(athlete,sportsleague).', 'target: bankboughtbank(company,company).', 'setMap: athleteplaysinleague09(A,B)=bankboughtbank(A,B).', 'source: teamalsoknownas09(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamalsoknownas09(A,B)=companyalsoknownas(A,B).', 'source: teamplayssport10(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport10(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport11(athlete,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplayssport11(A,B)=companyeconomicsector(A,B).', 'source: athleteplaysinleague11(athlete,sportsleague).', 'target: acquired(company,company).', 'setMap: athleteplaysinleague11(A,B)=acquired(A,B).', 'source: athleteledsportsteam12(athlete,sportsteam).', 'target: acquired(company,company).', 'setMap: athleteledsportsteam12(A,B)=acquired(A,B).', 'source: teamplaysagainstteam13(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamplaysagainstteam13(A,B)=acquired(A,B).', 'source: teamalsoknownas14(sportsteam,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: teamalsoknownas14(A,B)=bankboughtbank(A,B).', 'source: teamplaysinleague14(sportsteam,sportsleague).', 'target: companyalsoknownas(company,company).', 'setMap: teamplaysinleague14(A,B)=companyalsoknownas(A,B).', 'source: athleteplaysinleague15(athlete,sportsleague).', 'target: bankboughtbank(company,company).', 'setMap: athleteplaysinleague15(A,B)=bankboughtbank(A,B).', 'source: teamplaysagainstteam15(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamplaysagainstteam15(A,B)=acquired(A,B).', 'source: teamplaysinleague16(sportsteam,sportsleague).', 'target: companyalsoknownas(company,company).', 'setMap:  ...
# ==========================
# INDIVIDUO  3
# REFINE:  ['0;;teamplayssport00(A,B):- athleteplayssport01(C, B);true;false', '0;true;athleteledsportsteam02(C, D).;true;true', '0;true,true;teamplaysinleague03(A, E), teamplaysinleague04(D, E).;true;true', '0;true,true,true;athleteplaysforteam04(C, D).;false;true', '0;true,true,true,false;bankboughtbanktarget05(B, G), companyeconomicsectortarget06(K, B).;false;false', '0;true,true,false;teamplaysagainstteam06(A, F), athleteplaysforteam07(G, A).;false;false', '0;true,false;teamplaysagainstteam07(H, A), athleteplaysinleague08(C, I).;true;true', '0;true,false,true;athleteplaysforteam08(J, H), athleteplaysinleague09(J, I).;false;false', '0;true,false,false;teamalsoknownas09(K, A).;false;false', '1;;teamplayssport10(A,B):- athleteplayssport11(C, B), athleteplaysinleague11(C, D);true;true', '1;true;athleteledsportsteam12(C, E).;true;true', '1;true,true;teamplaysagainstteam13(F, A), teamalsoknownas14(G, F).;false;false', '1;true,false;teamplaysinleague14(A, H), athleteplaysinleague15(I, H).;true;false', '1;true,false,true;teamplaysagainstteam15(A, J).;false;false', '1;false;teamplaysinleague16(A, K).;false;true', '1;false,false;athleteplayssport17(L, B).;true;true', '1;false,false,true;countryhascompanyofficetarget18(W, B).;false;false', '1;false,false,false;teamplaysagainstteam19(A, M), teamalsoknownas110(A, N).;false;false', '2;;teamplayssport20(A,B):- athleteplayssport21(C, B), athleteplaysinleague21(C, D);true;true', '2;true;teamplaysagainstteam22(E, A), teamplaysinleague23(A, F).;false;true', '2;true,false;teamalsoknownas23(G, A), teamplaysinleague24(A, H).;false;true', '2;true,false,false;athleteledsportsteam24(C, I), teamplaysagainstteam25(A, J).;false;false', '2;false;teamalsoknownas25(K, A), teamalsoknownas26(L, K).;true;true', '2;false,false;companyeconomicsectortarget26(B, A).;false;false', '2;false,true;teamplaysagainstteam27(A, L), athleteplaysforteam28(M, L).;true;true', '2;false,true,true;teamalsoknownas28(N, L).;false;false', '2;false,true,false;teamalsoknownas29(K, L).;false;false', '3;;teamplayssport30(A,B):- athleteplayssport31(B, C), athleteplaysinleague31(C, D);false;false', '4;;teamplayssport40(A,B):- athleteplayssport41(B, C);true;false', '4;true;athleteledsportsteam42(C, D).;true;true', '4;true,true;athleteplaysforteam43(E, A), athleteledsportsteam44(E, F).;true;true', '4;true,true,true;teamplaysagainstteam44(A, D), athleteplaysforteam45(C, D).;false;false', '4;true,true,false;teamplaysagainstteam45(A, G).;false;false', '4;true,false;teamplaysinleague46(A, H), athleteplaysinleague47(I, H).;true;true', '4;true,false,true;athleteplayssport47(I, J).;false;true', '4;true,false,true,false;companyeconomicsectortarget48(A, P).;false;true', '4;true,false,true,false,false;companyalsoknownastarget49(S, P).;false;false', '4;true,false,false;teamplaysagainstteam410(K, A).;false;true', '4;true,false,false,false;companyeconomicsectortarget411(Y, G), bankboughtbanktarget412(E, Z).;false;false', '5;;teamplayssport50(A,B):- athleteledsportsteam51(C, A), athleteplayssport51(D, C);true;true', '5;true;athleteplayssport52(E, B), athleteledsportsteam53(E, F).;true;false', '5;true,true;teamplaysagainstteam53(A, F).;true;false', '5;true,true,true;teamalsoknownas54(G, A), teamalsoknownas55(G, F).;false;true', '5;true,true,true,false;countryhascompanyofficetarget55(Y, E).;false;false', '5;false;athleteplayssport56(H, B).;true;false', '5;false,true;athleteplaysforteam57(H, I).;true;true', '5;false,true,true;teamplaysinleague58(A, J), athleteledsportsteam59(K, I).;false;false', '5;false,true,false;athleteplaysinleague59(H, L), teamplaysagainstteam510(M, A).;false;false', '6;;teamplayssport60(A,B):- athleteplayssport61(C, B), athleteplaysinleague61(C, D);true;true', '6;true;athleteledsportsteam62(E, A).;false;true', '6;true,false;teamplaysinleague63(A, F), teamplaysagainstteam64(A, G).;true;true', '6;true,false,true;athleteledsportsteam64(C, H), teamplaysinleague65(H, F).;false;false', '6;true,false,false;teamplaysagainstteam65(I, A), tea ...
# TRANSFER:  ['source: teamplayssport00(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport00(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport01(athlete,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplayssport01(A,B)=companyeconomicsector(A,B).', 'source: athleteledsportsteam02(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteledsportsteam02(A,B)=bankboughtbank(A,B).', 'source: teamplaysinleague03(sportsteam,sportsleague).', 'target: companyalsoknownas(company,company).', 'setMap: teamplaysinleague03(A,B)=companyalsoknownas(A,B).', 'source: teamplaysinleague04(sportsteam,sportsleague).', 'target: bankboughtbank(company,company).', 'setMap: teamplaysinleague04(A,B)=bankboughtbank(A,B).', 'source: athleteplaysforteam04(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteplaysforteam04(A,B)=bankboughtbank(A,B).', 'source: bankboughtbanktarget05(bankboughtbanktype1,bankboughtbanktype2).', 'target: companyalsoknownas(company,company).', 'setMap: bankboughtbanktarget05(A,B)=companyalsoknownas(A,B).', 'source: companyeconomicsectortarget06(companyeconomicsectortype1,companyeconomicsectortype2).', 'target: economicsectorcompany(company,sector).', 'setMap: companyeconomicsectortarget06(A,B)=economicsectorcompany(A,B).', 'source: teamplaysagainstteam06(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamplaysagainstteam06(A,B)=acquired(A,B).', 'source: athleteplaysforteam07(athlete,sportsteam).', 'target: acquired(company,company).', 'setMap: athleteplaysforteam07(A,B)=acquired(A,B).', 'source: teamplaysagainstteam07(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamplaysagainstteam07(A,B)=companyalsoknownas(A,B).', 'source: athleteplaysinleague08(athlete,sportsleague).', 'target: companyalsoknownas(company,company).', 'setMap: athleteplaysinleague08(A,B)=companyalsoknownas(A,B).', 'source: athleteplaysforteam08(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteplaysforteam08(A,B)=bankboughtbank(A,B).', 'source: athleteplaysinleague09(athlete,sportsleague).', 'target: bankboughtbank(company,company).', 'setMap: athleteplaysinleague09(A,B)=bankboughtbank(A,B).', 'source: teamalsoknownas09(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamalsoknownas09(A,B)=companyalsoknownas(A,B).', 'source: teamplayssport10(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport10(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport11(athlete,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplayssport11(A,B)=companyeconomicsector(A,B).', 'source: athleteplaysinleague11(athlete,sportsleague).', 'target: acquired(company,company).', 'setMap: athleteplaysinleague11(A,B)=acquired(A,B).', 'source: athleteledsportsteam12(athlete,sportsteam).', 'target: acquired(company,company).', 'setMap: athleteledsportsteam12(A,B)=acquired(A,B).', 'source: teamplaysagainstteam13(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamplaysagainstteam13(A,B)=acquired(A,B).', 'source: teamalsoknownas14(sportsteam,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: teamalsoknownas14(A,B)=bankboughtbank(A,B).', 'source: teamplaysinleague14(sportsteam,sportsleague).', 'target: companyalsoknownas(company,company).', 'setMap: teamplaysinleague14(A,B)=companyalsoknownas(A,B).', 'source: athleteplaysinleague15(athlete,sportsleague).', 'target: bankboughtbank(company,company).', 'setMap: athleteplaysinleague15(A,B)=bankboughtbank(A,B).', 'source: teamplaysagainstteam15(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamplaysagainstteam15(A,B)=acquired(A,B).', 'source: teamplaysinleague16(sportsteam,sportsleague).', 'target: companyalsoknownas(company,company).', 'setMap:  ...
# ==========================

# %% [markdown]
# ## Guiado

# %%
start = time.time()
res_g_c = genetic(new_src_struct, target, source, train_pos, 
                                         train_neg, train_facts, kb_source, kb_target, pred_target,
                                          NUM_GEN=14, pop_size=30, revision='guided')
print("FIM DO GROOT GENETIC: ", time.time()-start)
# Out:
# GENERATION:  0
# MELHOR RESULTADO:  -0.2819677668639627
# estou nesse crossover
# BEST: {'m_auc_pr': 0.06917999999999999, 'm_auc_roc': 0.9763575, 'm_cll': -0.2733495, 'm_rec': 0.4007355, 'm_pred': 0.30346325, 'm_f1': 0.168786, 's_auc_pr': 0.0006220000000000045, 's_auc_roc': 0.0006205000000000238, 's_cll': 0.0007485000000000129, 's_rec': 0.003676499999999999, 's_prec': 0.1965427094315317, 's_f1': 0.002370999999999998}
# GENERATION:  1
# MELHOR RESULTADO:  -0.3489270846100945
# estou nesse crossover
# BEST: {'m_auc_pr': 0.2837465, 'm_auc_roc': 0.9838835, 'm_cll': -0.20307150000000002, 'm_rec': 0.8970585, 'm_pred': 0.26100650000000003, 'm_f1': 0.042972, 's_auc_pr': 0.0866205, 's_auc_roc': 0.0021645000000000136, 's_cll': 0.0013945000000000068, 's_rec': 0.011029500000000025, 's_prec': 0.2389937350230127, 's_f1': 0.0009160000000000001}
# GENERATION:  2
# MELHOR RESULTADO:  -0.3489270846100945
# estou nesse crossover
# BEST: {'m_auc_pr': 0.2837465, 'm_auc_roc': 0.9838835, 'm_cll': -0.20307150000000002, 'm_rec': 0.8970585, 'm_pred': 0.26100650000000003, 'm_f1': 0.042972, 's_auc_pr': 0.0866205, 's_auc_roc': 0.0021645000000000136, 's_cll': 0.0013945000000000068, 's_rec': 0.011029500000000025, 's_prec': 0.2389937350230127, 's_f1': 0.0009160000000000001}
# GENERATION:  3
# MELHOR RESULTADO:  -0.3489270846100945
# estou nesse crossover
# BEST: {'m_auc_pr': 0.2837465, 'm_auc_roc': 0.9838835, 'm_cll': -0.20307150000000002, 'm_rec': 0.8970585, 'm_pred': 0.26100650000000003, 'm_f1': 0.042972, 's_auc_pr': 0.0866205, 's_auc_roc': 0.0021645000000000136, 's_cll': 0.0013945000000000068, 's_rec': 0.011029500000000025, 's_prec': 0.2389937350230127, 's_f1': 0.0009160000000000001}
# GENERATION:  4
# MELHOR RESULTADO:  -0.36594611753815615
# estou nesse crossover
# BEST: {'m_auc_pr': 0.323271, 'm_auc_roc': 0.986076, 'm_cll': -0.1715005, 'm_rec': 0.9172795, 'm_pred': 0.26022449999999997, 'm_f1': 0.0400055, 's_auc_pr': 0.019008999999999998, 's_auc_roc': 0.0005620000000000069, 's_cll': 0.0020405000000000006, 's_rec': 0.009191500000000019, 's_prec': 0.239775591970388, 's_f1': 0.0005594999999999975}
# GENERATION:  5
# MELHOR RESULTADO:  -0.36594611753815615
# estou nesse crossover
# BEST: {'m_auc_pr': 0.323271, 'm_auc_roc': 0.986076, 'm_cll': -0.1715005, 'm_rec': 0.9172795, 'm_pred': 0.26022449999999997, 'm_f1': 0.0400055, 's_auc_pr': 0.019008999999999998, 's_auc_roc': 0.0005620000000000069, 's_cll': 0.0020405000000000006, 's_rec': 0.009191500000000019, 's_prec': 0.239775591970388, 's_f1': 0.0005594999999999975}
# GENERATION:  6
# MELHOR RESULTADO:  -0.36594611753815615
# estou nesse crossover
# BEST: {'m_auc_pr': 0.323271, 'm_auc_roc': 0.986076, 'm_cll': -0.1715005, 'm_rec': 0.9172795, 'm_pred': 0.26022449999999997, 'm_f1': 0.0400055, 's_auc_pr': 0.019008999999999998, 's_auc_roc': 0.0005620000000000069, 's_cll': 0.0020405000000000006, 's_rec': 0.009191500000000019, 's_prec': 0.239775591970388, 's_f1': 0.0005594999999999975}
# GENERATION:  7
# MELHOR RESULTADO:  -0.370876238475856
# estou nesse crossover
# BEST: {'m_auc_pr': 0.287929, 'm_auc_roc': 0.983121, 'm_cll': -0.233765, 'm_rec': 0.876838, 'm_pred': 0.26190424999999995, 'm_f1': 0.046353, 's_auc_pr': 0.021401000000000003, 's_auc_roc': 0.0003630000000000022, 's_cll': 9.699999999999986e-05, 's_rec': 0.0018380000000000063, 's_prec': 0.23809849709980846, 's_f1': 0.0030680000000000013}
# GENERATION:  8
# MELHOR RESULTADO:  -0.39040275374829264
# estou nesse crossover
# BEST: {'m_auc_pr': 0.3430905, 'm_auc_roc': 0.984221, 'm_cll': -0.186288, 'm_rec': 0.9191180000000001, 'm_pred': 0.259662, 'm_f1': 0.037853, 's_auc_pr': 0.024273500000000003, 's_auc_roc': 0.00046800000000002395, 's_cll': 0.0017009999999999942, 's_rec': 0.007352999999999998, 's_prec': 0.24033808808530538, 's_f1': 0.0005649999999999995}
# GENERATION:  9
# MELHOR RESULTADO:  -0.39040275374829264
# estou nesse crossover
# BEST: {'m_auc_pr': 0.3430905, 'm_auc_roc': 0.984221, 'm_cll': -0.186288, 'm_rec': 0.9191180000000001, 'm_pred': 0.259662, 'm_f1': 0.037853, 's_auc_pr': 0.024273500000000003, 's_auc_roc': 0.00046800000000002395, 's_cll': 0.0017009999999999942, 's_rec': 0.007352999999999998, 's_prec': 0.24033808808530538, 's_f1': 0.0005649999999999995}
# GENERATION:  10
# MELHOR RESULTADO:  -0.39040275374829264
# estou nesse crossover
# BEST: {'m_auc_pr': 0.3430905, 'm_auc_roc': 0.984221, 'm_cll': -0.186288, 'm_rec': 0.9191180000000001, 'm_pred': 0.259662, 'm_f1': 0.037853, 's_auc_pr': 0.024273500000000003, 's_auc_roc': 0.00046800000000002395, 's_cll': 0.0017009999999999942, 's_rec': 0.007352999999999998, 's_prec': 0.24033808808530538, 's_f1': 0.0005649999999999995}
# GENERATION:  11
# MELHOR RESULTADO:  -0.39040275374829264
# estou nesse crossover
# BEST: {'m_auc_pr': 0.3430905, 'm_auc_roc': 0.984221, 'm_cll': -0.186288, 'm_rec': 0.9191180000000001, 'm_pred': 0.259662, 'm_f1': 0.037853, 's_auc_pr': 0.024273500000000003, 's_auc_roc': 0.00046800000000002395, 's_cll': 0.0017009999999999942, 's_rec': 0.007352999999999998, 's_prec': 0.24033808808530538, 's_f1': 0.0005649999999999995}
# GENERATION:  12
# MELHOR RESULTADO:  -0.39040275374829264
# estou nesse crossover
# BEST: {'m_auc_pr': 0.3430905, 'm_auc_roc': 0.984221, 'm_cll': -0.186288, 'm_rec': 0.9191180000000001, 'm_pred': 0.259662, 'm_f1': 0.037853, 's_auc_pr': 0.024273500000000003, 's_auc_roc': 0.00046800000000002395, 's_cll': 0.0017009999999999942, 's_rec': 0.007352999999999998, 's_prec': 0.24033808808530538, 's_f1': 0.0005649999999999995}
# GENERATION:  13
# MELHOR RESULTADO:  -0.39040275374829264
# estou nesse crossover
# BEST: {'m_auc_pr': 0.3430905, 'm_auc_roc': 0.984221, 'm_cll': -0.186288, 'm_rec': 0.9191180000000001, 'm_pred': 0.259662, 'm_f1': 0.037853, 's_auc_pr': 0.024273500000000003, 's_auc_roc': 0.00046800000000002395, 's_cll': 0.0017009999999999942, 's_rec': 0.007352999999999998, 's_prec': 0.24033808808530538, 's_f1': 0.0005649999999999995}
# -0.39040275374829264 -0.39040275374829264
# -0.39040275374829264 -0.39040275374829264
# -0.39040275374829264 -0.39040275374829264
# [{'m_auc_pr': 0.3430905, 'm_auc_roc': 0.984221, 'm_cll': -0.186288, 'm_rec': 0.9191180000000001, 'm_pred': 0.259662, 'm_f1': 0.037853, 's_auc_pr': 0.024273500000000003, 's_auc_roc': 0.00046800000000002395, 's_cll': 0.0017009999999999942, 's_rec': 0.007352999999999998, 's_prec': 0.24033808808530538, 's_f1': 0.0005649999999999995}, {'m_auc_pr': 0.3430905, 'm_auc_roc': 0.984221, 'm_cll': -0.186288, 'm_rec': 0.9191180000000001, 'm_pred': 0.259662, 'm_f1': 0.037853, 's_auc_pr': 0.024273500000000003, 's_auc_roc': 0.00046800000000002395, 's_cll': 0.0017009999999999942, 's_rec': 0.007352999999999998, 's_prec': 0.24033808808530538, 's_f1': 0.0005649999999999995}, {'m_auc_pr': 0.3430905, 'm_auc_roc': 0.984221, 'm_cll': -0.186288, 'm_rec': 0.9191180000000001, 'm_pred': 0.259662, 'm_f1': 0.037853, 's_auc_pr': 0.024273500000000003, 's_auc_roc': 0.00046800000000002395, 's_cll': 0.0017009999999999942, 's_rec': 0.007352999999999998, 's_prec': 0.24033808808530538, 's_f1': 0.0005649999999999995}]
# RESULT: {'m_auc_pr': 0.3430905, 'm_auc_roc': 0.984221, 'm_cll': -0.186288, 'm_rec': 0.9191180000000001, 'm_pred': 0.259662, 'm_f1': 0.037853, 's_auc_pr': 0.024273500000000003, 's_auc_roc': 0.00046800000000002395, 's_cll': 0.0017009999999999942, 's_rec': 0.007352999999999998, 's_prec': 0.24033808808530538, 's_f1': 0.0005649999999999995}
# FIM DO GROOT GENETIC:  8333.498831987381

# %%
res_g_c
# Out:
# (<src.s_genetic.population.Population at 0x7fa98bc17828>,
#  [-0.2819677668639627,
#   -0.3489270846100945,
#   -0.3489270846100945,
#   -0.3489270846100945,
#   -0.36594611753815615,
#   -0.36594611753815615,
#   -0.36594611753815615,
#   -0.370876238475856,
#   -0.39040275374829264,
#   -0.39040275374829264,
#   -0.39040275374829264,
#   -0.39040275374829264,
#   -0.39040275374829264,
#   -0.39040275374829264,
#   -0.39040275374829264],
#  [{'m_auc_pr': 0.06917999999999999,
#    'm_auc_roc': 0.9763575,
#    'm_cll': -0.2733495,
#    'm_rec': 0.4007355,
#    'm_pred': 0.30346325,
#    'm_f1': 0.168786,
#    's_auc_pr': 0.0006220000000000045,
#    's_auc_roc': 0.0006205000000000238,
#    's_cll': 0.0007485000000000129,
#    's_rec': 0.003676499999999999,
#    's_prec': 0.1965427094315317,
#    's_f1': 0.002370999999999998},
#   {'m_auc_pr': 0.2837465,
#    'm_auc_roc': 0.9838835,
#    'm_cll': -0.20307150000000002,
#    'm_rec': 0.8970585,
#    'm_pred': 0.26100650000000003,
#    'm_f1': 0.042972,
#    's_auc_pr': 0.0866205,
#    's_auc_roc': 0.0021645000000000136,
#    's_cll': 0.0013945000000000068,
#    's_rec': 0.011029500000000025,
#    's_prec': 0.2389937350230127,
#    's_f1': 0.0009160000000000001},
#   {'m_auc_pr': 0.2837465,
#    'm_auc_roc': 0.9838835,
#    'm_cll': -0.20307150000000002,
#    'm_rec': 0.8970585,
#    'm_pred': 0.26100650000000003,
#    'm_f1': 0.042972,
#    's_auc_pr': 0.0866205,
#    's_auc_roc': 0.0021645000000000136,
#    's_cll': 0.0013945000000000068,
#    's_rec': 0.011029500000000025,
#    's_prec': 0.2389937350230127,
#    's_f1': 0.0009160000000000001},
#   {'m_auc_pr': 0.2837465,
#    'm_auc_roc': 0.9838835,
#    'm_cll': -0.20307150000000002,
#    'm_rec': 0.8970585,
#    'm_pred': 0.26100650000000003,
#    'm_f1': 0.042972,
#    's_auc_pr': 0.0866205,
#    's_auc_roc': 0.0021645000000000136,
#    's_cll': 0.0013945000000000068,
#    's_rec': 0.011029500000000025,
#    's_prec': 0.2389937350230127,
#    's_f1': 0.0009160000000000001},
#   {'m_auc_pr': 0.323271,
#    'm_auc_roc': 0.986076,
#    'm_cll': -0.1715005,
#    'm_rec': 0.9172795,
#    'm_pred': 0.26022449999999997,
#    'm_f1': 0.0400055,
#    's_auc_pr': 0.019008999999999998,
#    's_auc_roc': 0.0005620000000000069,
#    's_cll': 0.0020405000000000006,
#    's_rec': 0.009191500000000019,
#    's_prec': 0.239775591970388,
#    's_f1': 0.0005594999999999975},
#   {'m_auc_pr': 0.323271,
#    'm_auc_roc': 0.986076,
#    'm_cll': -0.1715005,
#    'm_rec': 0.9172795,
#    'm_pred': 0.26022449999999997,
#    'm_f1': 0.0400055,
#    's_auc_pr': 0.019008999999999998,
#    's_auc_roc': 0.0005620000000000069,
#    's_cll': 0.0020405000000000006,
#    's_rec': 0.009191500000000019,
#    's_prec': 0.239775591970388,
#    's_f1': 0.0005594999999999975},
#   {'m_auc_pr': 0.323271,
#    'm_auc_roc': 0.986076,
#    'm_cll': -0.1715005,
#    'm_rec': 0.9172795,
#    'm_pred': 0.26022449999999997,
#    'm_f1': 0.0400055,
#    's_auc_pr': 0.019008999999999998,
#    's_auc_roc': 0.0005620000000000069,
#    's_cll': 0.0020405000000000006,
#    's_rec': 0.009191500000000019,
#    's_prec': 0.239775591970388,
#    's_f1': 0.0005594999999999975},
#   {'m_auc_pr': 0.287929,
#    'm_auc_roc': 0.983121,
#    'm_cll': -0.233765,
#    'm_rec': 0.876838,
#    'm_pred': 0.26190424999999995,
#    'm_f1': 0.046353,
#    's_auc_pr': 0.021401000000000003,
#    's_auc_roc': 0.0003630000000000022,
#    's_cll': 9.699999999999986e-05,
#    's_rec': 0.0018380000000000063,
#    's_prec': 0.23809849709980846,
#    's_f1': 0.0030680000000000013},
#   {'m_auc_pr': 0.3430905,
#    'm_auc_roc': 0.984221,
#    'm_cll': -0.186288,
#    'm_rec': 0.9191180000000001,
#    'm_pred': 0.259662,
#    'm_f1': 0.037853,
#    's_auc_pr': 0.024273500000000003,
#    's_auc_roc': 0.00046800000000002395,
#    's_cll': 0.0017009999999999942,
#    's_rec': 0.007352999999999998,
#    's_prec': 0.24033808808530538,
#    's_f1': 0.0005649999999999995},
#   {'m_auc_pr': 0.3430905,
#    'm_auc_roc': 0.984221,
#    'm_cll': -0.186288,
#    'm_rec': 0.9191180000000001,
#    'm_pred': 0.259662,
#    'm_f1': 0.037853,
#    's_auc_pr': 0.024273500000000003,
#    's_auc_roc': 0.00046800000000002395,
#    's_cll': 0.0017009999999999942,
#    's_rec': 0.007352999999999998,
#    's_prec': 0.24033808808530538,
#    's_f1': 0.0005649999999999995},
#   {'m_auc_pr': 0.3430905,
#    'm_auc_roc': 0.984221,
#    'm_cll': -0.186288,
#    'm_rec': 0.9191180000000001,
#    'm_pred': 0.259662,
#    'm_f1': 0.037853,
#    's_auc_pr': 0.024273500000000003,
#    's_auc_roc': 0.00046800000000002395,
#    's_cll': 0.0017009999999999942,
#    's_rec': 0.007352999999999998,
#    's_prec': 0.24033808808530538,
#    's_f1': 0.0005649999999999995},
#   {'m_auc_pr': 0.3430905,
#    'm_auc_roc': 0.984221,
#    'm_cll': -0.186288,
#    'm_rec': 0.9191180000000001,
#    'm_pred': 0.259662,
#    'm_f1': 0.037853,
#    's_auc_pr': 0.024273500000000003,
#    's_auc_roc': 0.00046800000000002395,
#    's_cll': 0.0017009999999999942,
#    's_rec': 0.007352999999999998,
#    's_prec': 0.24033808808530538,
#    's_f1': 0.0005649999999999995},
#   {'m_auc_pr': 0.3430905,
#    'm_auc_roc': 0.984221,
#    'm_cll': -0.186288,
#    'm_rec': 0.9191180000000001,
#    'm_pred': 0.259662,
#    'm_f1': 0.037853,
#    's_auc_pr': 0.024273500000000003,
#    's_auc_roc': 0.00046800000000002395,
#    's_cll': 0.0017009999999999942,
#    's_rec': 0.007352999999999998,
#    's_prec': 0.24033808808530538,
#    's_f1': 0.0005649999999999995},
#   {'m_auc_pr': 0.3430905,
#    'm_auc_roc': 0.984221,
#    'm_cll': -0.186288,
#    'm_rec': 0.9191180000000001,
#    'm_pred': 0.259662,
#    'm_f1': 0.037853,
#    's_auc_pr': 0.024273500000000003,
#    's_auc_roc': 0.00046800000000002395,
#    's_cll': 0.0017009999999999942,
#    's_rec': 0.007352999999999998,
#    's_prec': 0.24033808808530538,
#    's_f1': 0.0005649999999999995},
#   {'m_auc_pr': 0.3430905,
#    'm_auc_roc': 0.984221,
#    'm_cll': -0.186288,
#    'm_rec': 0.9191180000000001,
#    'm_pred': 0.259662,
#    'm_f1': 0.037853,
#    's_auc_pr': 0.024273500000000003,
#    's_auc_roc': 0.00046800000000002395,
#    's_cll': 0.0017009999999999942,
#    's_rec': 0.007352999999999998,
#    's_prec': 0.24033808808530538,
#    's_f1': 0.0005649999999999995}])

# %%
# final_results[f'groot_test:{source}->{target}'] = []
# final_results[f'groot_test_rev:{source}->{target}'] = []
# final_results[f'inf_res:{source}->{target}'] = []
# final_results[f'inf_res_rev:{source}->{target}'] = []

# uwcse_dataset = datasets.load('uwcse', kb_target, target=target, seed=441773)
# train_facts, train_pos, train_neg, test_facts, test_pos, test_neg = get_train_test(uwcse_dataset, 1)
# tr_train_pos = []
# tr_train_neg = []
# tr_train_facts = []

# for i in range(0, len(train_pos)):
#     tr_train_pos.extend(train_pos[i])
#     tr_train_neg.extend(train_neg[i])
#     tr_train_facts.extend(train_facts[i])

# train = [tr_train_pos, tr_train_neg, tr_train_facts]
test = [test_pos, test_neg, test_facts[0]]

individuals = get_k_best_individuals(res_g_c[0].population, 3)

n_ind = 1
for individual in individuals:
    print("INDIVIDUO ", n_ind)
    refine, transfer = get_refine_transfer(individual, source, target, 'nell_sports', 'nell_finances')
    for i in range(len(train_pos)):
        ttrain = [train_pos[i], train_neg[i][:len(train_pos[i])], train_facts[i]]
        res_ = test_refine_transfer(kb_target, target, refine, transfer, ttrain, test)
        print(res_)
#         final_results[f'groot_test:{source}->{target}'].append(res)
#         import os
    #     thisFile = f'boostsrl/best/test/results_{target.replace('recursion_', '')}.db'
    #     thisFile = f'boostsrl/best/test/results_{target}.db'
    #     base = os.path.splitext(thisFile)[0]
    #     os.rename(thisFile, base + ".txt")
    #     tt = open('boostsrl/best/test/results_advisedby.txt', 'r').readlines()
    #     final = []
    #     for i in tt:
    #         final.append(i.replace('\n', ''))
    #     final_results[f'inf_res:{source}->{target}'].append(final)
        print("===========================================================================")
#         break

    n_ind += 1
# Out:
# INDIVIDUO  1
# ({'AUC ROC': 0.984544, 'AUC PR': 0.276557, 'CLL': -0.238492, 'Precision': [0.012286, 0.5], 'Recall': 1.0, 'F1': 0.024274}, <boostsrl.boostsrl.test object at 0x7fa9db458390>)
# ===========================================================================
# ({'AUC ROC': 0.98422, 'AUC PR': 0.390778, 'CLL': -0.238931, 'Precision': [0.012352, 0.5], 'Recall': 1.0, 'F1': 0.024402}, <boostsrl.boostsrl.test object at 0x7fa98bc2d780>)
# ===========================================================================
# INDIVIDUO  2
# ({'AUC ROC': 0.984544, 'AUC PR': 0.276557, 'CLL': -0.238492, 'Precision': [0.012286, 0.5], 'Recall': 1.0, 'F1': 0.024274}, <boostsrl.boostsrl.test object at 0x7fa98bc2da90>)
# ===========================================================================
# ({'AUC ROC': 0.98422, 'AUC PR': 0.390778, 'CLL': -0.238931, 'Precision': [0.012352, 0.5], 'Recall': 1.0, 'F1': 0.024402}, <boostsrl.boostsrl.test object at 0x7fa9db458390>)
# ===========================================================================
# INDIVIDUO  3
# ({'AUC ROC': 0.984544, 'AUC PR': 0.276557, 'CLL': -0.238492, 'Precision': [0.012286, 0.5], 'Recall': 1.0, 'F1': 0.024274}, <boostsrl.boostsrl.test object at 0x7fa9db4daa20>)
# ===========================================================================
# ({'AUC ROC': 0.98422, 'AUC PR': 0.390778, 'CLL': -0.238931, 'Precision': [0.012352, 0.5], 'Recall': 1.0, 'F1': 0.024402}, <boostsrl.boostsrl.test object at 0x7fa9db4583c8>)
# ===========================================================================

# %%
individuals_rc = get_k_best_individuals(res_g_c[0].population, 3)
n_i = 1
for ind in individuals_rc:
    refine, transfer = get_refine_transfer(ind, source, target, 'nell_sports', 'nell_finances')
    print("INDIVIDUO ", n_i)
    print("REFINE: ", refine)
    print("TRANSFER: ", transfer)
    print("==========================")
    n_i += 1
# Out:
# INDIVIDUO  1
# REFINE:  ['0;;teamplayssport00(A,B):- athleteplayssport01(B, C);true;false', '0;true;athleteledsportsteam02(C, D).;true;true', '0;true,true;teamplaysinleague03(E, A), teamplaysinleague04(E, D).;true;true', '0;true,true,true;athleteplaysforteam04(C, D).;false;false', '0;true,true,false;teamplaysagainstteam05(A, F), athleteplaysforteam06(G, A).;false;false', '0;true,false;teamplaysagainstteam06(H, A), athleteplaysinleague07(C, I).;true;false', '0;true,false,true;athleteplaysforteam07(J, H), athleteplaysinleague08(J, I).;false;false', '1;;teamplayssport10(A,B):- athleteplayssport11(C, B), athleteplaysinleague11(C, D);true;true', '1;true;athleteledsportsteam12(C, E).;true;true', '1;true,true;teamplaysagainstteam13(F, A), teamalsoknownas14(G, F).;false;false', '1;true,false;teamplaysinleague14(H, A), athleteplaysinleague15(I, H).;true;false', '1;true,false,true;teamplaysagainstteam15(A, J).;false;false', '1;false;teamplaysinleague16(K, A).;false;true', '1;false,false;athleteplayssport17(L, B).;false;true', '1;false,false,false;teamplaysagainstteam18(A, M), teamalsoknownas19(A, N).;false;false', '2;;teamplayssport20(A,B):- athleteplayssport21(C, B), athleteplaysinleague21(D, C);true;true', '2;true;teamplaysagainstteam22(E, A), teamplaysinleague23(F, A).;false;true', '2;true,false;teamalsoknownas23(G, A), teamplaysinleague24(A, H).;false;true', '2;true,false,false;athleteledsportsteam24(C, I), teamplaysagainstteam25(A, J).;false;false', '2;false;teamalsoknownas25(K, A), teamalsoknownas26(L, K).;true;false', '2;false,true;teamplaysagainstteam26(A, L), athleteplaysforteam27(M, L).;true;true', '2;false,true,true;teamalsoknownas27(N, L).;false;false', '2;false,true,false;teamalsoknownas28(K, L).;false;false', '3;;teamplayssport30(A,B):- athleteplayssport31(B, C), athleteplaysinleague31(D, C);true;true', '3;true;athleteledsportsteam32(C, E).;true;false', '3;true,true;teamplaysinleague33(F, A), teamplaysinleague34(F, E).;false;true', '3;true,true,false;athleteplaysforteam34(C, G), teamalsoknownas35(E, G).;false;false', '3;false;teamplaysinleague35(A, H).;true;true', '3;false,true;teamalsoknownas36(I, A), athleteplaysforteam37(J, I).;false;false', '3;false,false;teamplaysagainstteam37(A, K), teamalsoknownas38(L, A).;false;false', '4;;teamplayssport40(A,B):- athleteplayssport41(B, C);true;false', '4;true;athleteledsportsteam42(C, D).;true;true', '4;true,true;athleteplaysforteam43(E, A), athleteledsportsteam44(E, F).;true;true', '4;true,true,true;teamplaysagainstteam44(A, D), athleteplaysforteam45(C, D).;false;false', '4;true,true,false;teamplaysagainstteam45(A, G).;false;true', '4;true,true,false,false;countryhascompanyofficetarget46(D, A).;false;false', '4;true,false;teamplaysinleague47(H, A), athleteplaysinleague48(I, H).;true;true', '4;true,false,true;athleteplayssport48(J, I).;false;false', '4;true,false,false;teamplaysagainstteam49(K, A).;false;false', '5;;teamplayssport50(A,B):- athleteledsportsteam51(C, A), athleteplayssport51(C, D);true;true', '5;true;athleteplayssport52(E, B), athleteledsportsteam53(E, F).;true;false', '5;true,true;teamplaysagainstteam53(A, F).;true;false', '5;true,true,true;teamalsoknownas54(G, A), teamalsoknownas55(G, F).;false;false', '5;false;athleteplayssport55(B, H).;true;false', '5;false,true;athleteplaysforteam56(H, I).;true;true', '5;false,true,true;teamplaysinleague57(J, A), athleteledsportsteam58(K, I).;false;false', '5;false,true,false;athleteplaysinleague58(H, L), teamplaysagainstteam59(M, A).;false;false', '6;;teamplayssport60(A,B):- athleteplayssport61(C, B), athleteplaysinleague61(D, C);true;true', '6;true;athleteledsportsteam62(E, A).;false;true', '6;true,false;teamplaysinleague63(A, F), teamplaysagainstteam64(A, G).;true;true', '6;true,false,true;athleteledsportsteam64(C, H), teamplaysinleague65(H, F).;false;false', '6;true,false,false;teamplaysagainstteam65(I, A), teamplaysinleague66(I, J).;false;false', '6;false;teamalsoknownas66(K, A), athleteplaysforteam67(L, K).;true;false', '6;false,true;team ...
# TRANSFER:  ['source: teamplayssport00(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport00(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport01(athlete,sport).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplayssport01(A,B)=economicsectorcompany(A,B).', 'source: athleteledsportsteam02(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteledsportsteam02(A,B)=bankboughtbank(A,B).', 'source: teamplaysinleague03(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague03(A,B)=economicsectorcompany(A,B).', 'source: teamplaysinleague04(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague04(A,B)=economicsectorcompany(A,B).', 'source: athleteplaysforteam04(athlete,sportsteam).', 'target: acquired(company,company).', 'setMap: athleteplaysforteam04(A,B)=acquired(A,B).', 'source: teamplaysagainstteam05(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamplaysagainstteam05(A,B)=acquired(A,B).', 'source: athleteplaysforteam06(athlete,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: athleteplaysforteam06(A,B)=companyalsoknownas(A,B).', 'source: teamplaysagainstteam06(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamplaysagainstteam06(A,B)=companyalsoknownas(A,B).', 'source: athleteplaysinleague07(athlete,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplaysinleague07(A,B)=companyeconomicsector(A,B).', 'source: athleteplaysforteam07(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteplaysforteam07(A,B)=bankboughtbank(A,B).', 'source: athleteplaysinleague08(athlete,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplaysinleague08(A,B)=companyeconomicsector(A,B).', 'source: teamplayssport10(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport10(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport11(athlete,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplayssport11(A,B)=companyeconomicsector(A,B).', 'source: athleteplaysinleague11(athlete,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplaysinleague11(A,B)=companyeconomicsector(A,B).', 'source: athleteledsportsteam12(athlete,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: athleteledsportsteam12(A,B)=companyalsoknownas(A,B).', 'source: teamplaysagainstteam13(sportsteam,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: teamplaysagainstteam13(A,B)=bankboughtbank(A,B).', 'source: teamalsoknownas14(sportsteam,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: teamalsoknownas14(A,B)=bankboughtbank(A,B).', 'source: teamplaysinleague14(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague14(A,B)=economicsectorcompany(A,B).', 'source: athleteplaysinleague15(athlete,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplaysinleague15(A,B)=companyeconomicsector(A,B).', 'source: teamplaysagainstteam15(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamplaysagainstteam15(A,B)=companyalsoknownas(A,B).', 'source: teamplaysinleague16(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague16(A,B)=economicsectorcompany(A,B).', 'source: athleteplayssport17(athlete,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplayssport17(A,B)=companyeconomicsector(A,B).', 'source: teamplaysagainstteam18(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamplaysagainstteam18(A,B)=companyalsoknownas(A,B).', 'source: teamalsoknownas19(sportsteam,spor ...
# ==========================
# INDIVIDUO  2
# REFINE:  ['0;;teamplayssport00(A,B):- athleteplayssport01(B, C);true;false', '0;true;athleteledsportsteam02(C, D).;true;true', '0;true,true;teamplaysinleague03(E, A), teamplaysinleague04(E, D).;true;true', '0;true,true,true;athleteplaysforteam04(C, D).;false;false', '0;true,true,false;teamplaysagainstteam05(A, F), athleteplaysforteam06(G, A).;false;false', '0;true,false;teamplaysagainstteam06(H, A), athleteplaysinleague07(C, I).;true;false', '0;true,false,true;athleteplaysforteam07(J, H), athleteplaysinleague08(J, I).;false;false', '1;;teamplayssport10(A,B):- athleteplayssport11(C, B), athleteplaysinleague11(C, D);true;true', '1;true;athleteledsportsteam12(C, E).;true;true', '1;true,true;teamplaysagainstteam13(F, A), teamalsoknownas14(G, F).;false;false', '1;true,false;teamplaysinleague14(H, A), athleteplaysinleague15(I, H).;true;false', '1;true,false,true;teamplaysagainstteam15(A, J).;false;false', '1;false;teamplaysinleague16(K, A).;false;true', '1;false,false;athleteplayssport17(L, B).;false;true', '1;false,false,false;teamplaysagainstteam18(A, M), teamalsoknownas19(A, N).;false;false', '2;;teamplayssport20(A,B):- athleteplayssport21(C, B), athleteplaysinleague21(D, C);true;true', '2;true;teamplaysagainstteam22(E, A), teamplaysinleague23(F, A).;false;true', '2;true,false;teamalsoknownas23(G, A), teamplaysinleague24(A, H).;false;true', '2;true,false,false;athleteledsportsteam24(C, I), teamplaysagainstteam25(A, J).;false;false', '2;false;teamalsoknownas25(K, A), teamalsoknownas26(L, K).;true;false', '2;false,true;teamplaysagainstteam26(A, L), athleteplaysforteam27(M, L).;true;true', '2;false,true,true;teamalsoknownas27(N, L).;false;false', '2;false,true,false;teamalsoknownas28(K, L).;false;false', '3;;teamplayssport30(A,B):- athleteplayssport31(B, C), athleteplaysinleague31(D, C);true;true', '3;true;athleteledsportsteam32(C, E).;true;false', '3;true,true;teamplaysinleague33(F, A), teamplaysinleague34(F, E).;false;true', '3;true,true,false;athleteplaysforteam34(C, G), teamalsoknownas35(E, G).;false;false', '3;false;teamplaysinleague35(A, H).;true;true', '3;false,true;teamalsoknownas36(I, A), athleteplaysforteam37(J, I).;false;false', '3;false,false;teamplaysagainstteam37(A, K), teamalsoknownas38(L, A).;false;false', '4;;teamplayssport40(A,B):- athleteplayssport41(B, C);true;false', '4;true;athleteledsportsteam42(C, D).;true;true', '4;true,true;athleteplaysforteam43(E, A), athleteledsportsteam44(E, F).;true;true', '4;true,true,true;teamplaysagainstteam44(A, D), athleteplaysforteam45(C, D).;false;false', '4;true,true,false;teamplaysagainstteam45(A, G).;false;true', '4;true,true,false,false;countryhascompanyofficetarget46(D, A).;false;false', '4;true,false;teamplaysinleague47(H, A), athleteplaysinleague48(I, H).;true;true', '4;true,false,true;athleteplayssport48(J, I).;false;false', '4;true,false,false;teamplaysagainstteam49(K, A).;false;false', '5;;teamplayssport50(A,B):- athleteledsportsteam51(C, A), athleteplayssport51(C, D);true;true', '5;true;athleteplayssport52(E, B), athleteledsportsteam53(E, F).;true;false', '5;true,true;teamplaysagainstteam53(A, F).;true;false', '5;true,true,true;teamalsoknownas54(G, A), teamalsoknownas55(G, F).;false;false', '5;false;athleteplayssport55(B, H).;true;false', '5;false,true;athleteplaysforteam56(H, I).;true;true', '5;false,true,true;teamplaysinleague57(J, A), athleteledsportsteam58(K, I).;false;false', '5;false,true,false;athleteplaysinleague58(H, L), teamplaysagainstteam59(M, A).;false;false', '6;;teamplayssport60(A,B):- athleteplayssport61(C, B), athleteplaysinleague61(D, C);true;true', '6;true;athleteledsportsteam62(E, A).;false;true', '6;true,false;teamplaysinleague63(A, F), teamplaysagainstteam64(A, G).;true;true', '6;true,false,true;athleteledsportsteam64(C, H), teamplaysinleague65(H, F).;false;false', '6;true,false,false;teamplaysagainstteam65(I, A), teamplaysinleague66(I, J).;false;false', '6;false;teamalsoknownas66(K, A), athleteplaysforteam67(L, K).;true;false', '6;false,true;team ...
# TRANSFER:  ['source: teamplayssport00(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport00(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport01(athlete,sport).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplayssport01(A,B)=economicsectorcompany(A,B).', 'source: athleteledsportsteam02(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteledsportsteam02(A,B)=bankboughtbank(A,B).', 'source: teamplaysinleague03(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague03(A,B)=economicsectorcompany(A,B).', 'source: teamplaysinleague04(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague04(A,B)=economicsectorcompany(A,B).', 'source: athleteplaysforteam04(athlete,sportsteam).', 'target: acquired(company,company).', 'setMap: athleteplaysforteam04(A,B)=acquired(A,B).', 'source: teamplaysagainstteam05(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamplaysagainstteam05(A,B)=acquired(A,B).', 'source: athleteplaysforteam06(athlete,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: athleteplaysforteam06(A,B)=companyalsoknownas(A,B).', 'source: teamplaysagainstteam06(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamplaysagainstteam06(A,B)=companyalsoknownas(A,B).', 'source: athleteplaysinleague07(athlete,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplaysinleague07(A,B)=companyeconomicsector(A,B).', 'source: athleteplaysforteam07(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteplaysforteam07(A,B)=bankboughtbank(A,B).', 'source: athleteplaysinleague08(athlete,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplaysinleague08(A,B)=companyeconomicsector(A,B).', 'source: teamplayssport10(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport10(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport11(athlete,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplayssport11(A,B)=companyeconomicsector(A,B).', 'source: athleteplaysinleague11(athlete,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplaysinleague11(A,B)=companyeconomicsector(A,B).', 'source: athleteledsportsteam12(athlete,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: athleteledsportsteam12(A,B)=companyalsoknownas(A,B).', 'source: teamplaysagainstteam13(sportsteam,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: teamplaysagainstteam13(A,B)=bankboughtbank(A,B).', 'source: teamalsoknownas14(sportsteam,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: teamalsoknownas14(A,B)=bankboughtbank(A,B).', 'source: teamplaysinleague14(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague14(A,B)=economicsectorcompany(A,B).', 'source: athleteplaysinleague15(athlete,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplaysinleague15(A,B)=companyeconomicsector(A,B).', 'source: teamplaysagainstteam15(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamplaysagainstteam15(A,B)=companyalsoknownas(A,B).', 'source: teamplaysinleague16(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague16(A,B)=economicsectorcompany(A,B).', 'source: athleteplayssport17(athlete,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplayssport17(A,B)=companyeconomicsector(A,B).', 'source: teamplaysagainstteam18(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamplaysagainstteam18(A,B)=companyalsoknownas(A,B).', 'source: teamalsoknownas19(sportsteam,spor ...
# ==========================
# INDIVIDUO  3
# REFINE:  ['0;;teamplayssport00(A,B):- athleteplayssport01(B, C);true;false', '0;true;athleteledsportsteam02(C, D).;true;true', '0;true,true;teamplaysinleague03(E, A), teamplaysinleague04(E, D).;true;true', '0;true,true,true;athleteplaysforteam04(C, D).;false;false', '0;true,true,false;teamplaysagainstteam05(A, F), athleteplaysforteam06(G, A).;false;false', '0;true,false;teamplaysagainstteam06(H, A), athleteplaysinleague07(C, I).;true;false', '0;true,false,true;athleteplaysforteam07(J, H), athleteplaysinleague08(J, I).;false;false', '1;;teamplayssport10(A,B):- athleteplayssport11(C, B), athleteplaysinleague11(C, D);true;true', '1;true;athleteledsportsteam12(C, E).;true;true', '1;true,true;teamplaysagainstteam13(F, A), teamalsoknownas14(G, F).;false;false', '1;true,false;teamplaysinleague14(H, A), athleteplaysinleague15(I, H).;true;false', '1;true,false,true;teamplaysagainstteam15(A, J).;false;false', '1;false;teamplaysinleague16(K, A).;false;true', '1;false,false;athleteplayssport17(L, B).;false;true', '1;false,false,false;teamplaysagainstteam18(A, M), teamalsoknownas19(A, N).;false;false', '2;;teamplayssport20(A,B):- athleteplayssport21(C, B), athleteplaysinleague21(D, C);true;true', '2;true;teamplaysagainstteam22(E, A), teamplaysinleague23(F, A).;false;true', '2;true,false;teamalsoknownas23(G, A), teamplaysinleague24(A, H).;false;true', '2;true,false,false;athleteledsportsteam24(C, I), teamplaysagainstteam25(A, J).;false;false', '2;false;teamalsoknownas25(K, A), teamalsoknownas26(L, K).;true;false', '2;false,true;teamplaysagainstteam26(A, L), athleteplaysforteam27(M, L).;true;true', '2;false,true,true;teamalsoknownas27(N, L).;false;false', '2;false,true,false;teamalsoknownas28(K, L).;false;false', '3;;teamplayssport30(A,B):- athleteplayssport31(B, C), athleteplaysinleague31(D, C);true;true', '3;true;athleteledsportsteam32(C, E).;true;false', '3;true,true;teamplaysinleague33(F, A), teamplaysinleague34(F, E).;false;true', '3;true,true,false;athleteplaysforteam34(C, G), teamalsoknownas35(E, G).;false;false', '3;false;teamplaysinleague35(A, H).;true;true', '3;false,true;teamalsoknownas36(I, A), athleteplaysforteam37(J, I).;false;false', '3;false,false;teamplaysagainstteam37(A, K), teamalsoknownas38(L, A).;false;false', '4;;teamplayssport40(A,B):- athleteplayssport41(B, C);true;false', '4;true;athleteledsportsteam42(C, D).;true;true', '4;true,true;athleteplaysforteam43(E, A), athleteledsportsteam44(E, F).;true;true', '4;true,true,true;teamplaysagainstteam44(A, D), athleteplaysforteam45(C, D).;false;false', '4;true,true,false;teamplaysagainstteam45(A, G).;false;true', '4;true,true,false,false;countryhascompanyofficetarget46(D, A).;false;false', '4;true,false;teamplaysinleague47(H, A), athleteplaysinleague48(I, H).;true;true', '4;true,false,true;athleteplayssport48(J, I).;false;false', '4;true,false,false;teamplaysagainstteam49(K, A).;false;false', '5;;teamplayssport50(A,B):- athleteledsportsteam51(C, A), athleteplayssport51(C, D);true;true', '5;true;athleteplayssport52(E, B), athleteledsportsteam53(E, F).;true;false', '5;true,true;teamplaysagainstteam53(A, F).;true;false', '5;true,true,true;teamalsoknownas54(G, A), teamalsoknownas55(G, F).;false;false', '5;false;athleteplayssport55(B, H).;true;false', '5;false,true;athleteplaysforteam56(H, I).;true;true', '5;false,true,true;teamplaysinleague57(J, A), athleteledsportsteam58(K, I).;false;false', '5;false,true,false;athleteplaysinleague58(H, L), teamplaysagainstteam59(M, A).;false;false', '6;;teamplayssport60(A,B):- athleteplayssport61(C, B), athleteplaysinleague61(D, C);true;true', '6;true;athleteledsportsteam62(E, A).;false;true', '6;true,false;teamplaysinleague63(A, F), teamplaysagainstteam64(A, G).;true;true', '6;true,false,true;athleteledsportsteam64(C, H), teamplaysinleague65(H, F).;false;false', '6;true,false,false;teamplaysagainstteam65(I, A), teamplaysinleague66(I, J).;false;false', '6;false;teamalsoknownas66(K, A), athleteplaysforteam67(L, K).;true;false', '6;false,true;team ...
# TRANSFER:  ['source: teamplayssport00(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport00(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport01(athlete,sport).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplayssport01(A,B)=economicsectorcompany(A,B).', 'source: athleteledsportsteam02(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteledsportsteam02(A,B)=bankboughtbank(A,B).', 'source: teamplaysinleague03(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague03(A,B)=economicsectorcompany(A,B).', 'source: teamplaysinleague04(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague04(A,B)=economicsectorcompany(A,B).', 'source: athleteplaysforteam04(athlete,sportsteam).', 'target: acquired(company,company).', 'setMap: athleteplaysforteam04(A,B)=acquired(A,B).', 'source: teamplaysagainstteam05(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamplaysagainstteam05(A,B)=acquired(A,B).', 'source: athleteplaysforteam06(athlete,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: athleteplaysforteam06(A,B)=companyalsoknownas(A,B).', 'source: teamplaysagainstteam06(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamplaysagainstteam06(A,B)=companyalsoknownas(A,B).', 'source: athleteplaysinleague07(athlete,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplaysinleague07(A,B)=companyeconomicsector(A,B).', 'source: athleteplaysforteam07(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteplaysforteam07(A,B)=bankboughtbank(A,B).', 'source: athleteplaysinleague08(athlete,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplaysinleague08(A,B)=companyeconomicsector(A,B).', 'source: teamplayssport10(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport10(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport11(athlete,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplayssport11(A,B)=companyeconomicsector(A,B).', 'source: athleteplaysinleague11(athlete,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplaysinleague11(A,B)=companyeconomicsector(A,B).', 'source: athleteledsportsteam12(athlete,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: athleteledsportsteam12(A,B)=companyalsoknownas(A,B).', 'source: teamplaysagainstteam13(sportsteam,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: teamplaysagainstteam13(A,B)=bankboughtbank(A,B).', 'source: teamalsoknownas14(sportsteam,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: teamalsoknownas14(A,B)=bankboughtbank(A,B).', 'source: teamplaysinleague14(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague14(A,B)=economicsectorcompany(A,B).', 'source: athleteplaysinleague15(athlete,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplaysinleague15(A,B)=companyeconomicsector(A,B).', 'source: teamplaysagainstteam15(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamplaysagainstteam15(A,B)=companyalsoknownas(A,B).', 'source: teamplaysinleague16(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague16(A,B)=economicsectorcompany(A,B).', 'source: athleteplayssport17(athlete,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplayssport17(A,B)=companyeconomicsector(A,B).', 'source: teamplaysagainstteam18(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamplaysagainstteam18(A,B)=companyalsoknownas(A,B).', 'source: teamalsoknownas19(sportsteam,spor ...
# ==========================

# %% [markdown]
# ## Mixed

# %%
start = time.time()
res_m_c = genetic(new_src_struct, target, source, train_pos, 
                                         train_neg, train_facts, kb_source, kb_target, pred_target,
                                          NUM_GEN=14, pop_size=30, revision='mixed')
print("FIM DO GROOT GENETIC: ", time.time()-start)
# Out:
# GENERATION:  0
# MELHOR RESULTADO:  -0.30192878944877055
# estou nesse crossover
# BEST: {'m_auc_pr': 0.23717700000000003, 'm_auc_roc': 0.9858585, 'm_cll': -0.186837, 'm_rec': 0.9136029999999999, 'm_pred': 0.26042125000000005, 'm_f1': 0.040751, 's_auc_pr': 0.013710000000000014, 's_auc_roc': 0.0007125000000000048, 's_cll': 0.0020459999999999923, 's_rec': 0.012868000000000046, 's_prec': 0.2395802165386105, 's_f1': 0.002253999999999999}
# GENERATION:  1
# MELHOR RESULTADO:  -0.30528036851392854
# estou nesse crossover
# BEST: {'m_auc_pr': 0.217146, 'm_auc_roc': 0.9846524999999999, 'm_cll': -0.214578, 'm_rec': 0.8694855, 'm_pred': 0.261291, 'm_f1': 0.044019, 's_auc_pr': 0.003282000000000007, 's_auc_roc': 0.0011905000000000387, 's_cll': 0.0005570000000000019, 's_rec': 0.03492649999999997, 's_prec': 0.23870900005131773, 's_f1': 3.099999999999978e-05}
# GENERATION:  2
# MELHOR RESULTADO:  -0.31585605581736126
# estou nesse crossover
# BEST: {'m_auc_pr': 0.2296095, 'm_auc_roc': 0.9847085, 'm_cll': -0.21689750000000002, 'm_rec': 0.8180145, 'm_pred': 0.28078925, 'm_f1': 0.11055999999999999, 's_auc_pr': 0.007279499999999994, 's_auc_roc': 0.0010844999999999883, 's_cll': 0.0018274999999999958, 's_rec': 0.06801449999999998, 's_prec': 0.2210111090119397, 's_f1': 0.068074}
# GENERATION:  3
# MELHOR RESULTADO:  -0.31585605581736126
# estou nesse crossover
# BEST: {'m_auc_pr': 0.2296095, 'm_auc_roc': 0.9847085, 'm_cll': -0.21689750000000002, 'm_rec': 0.8180145, 'm_pred': 0.28078925, 'm_f1': 0.11055999999999999, 's_auc_pr': 0.007279499999999994, 's_auc_roc': 0.0010844999999999883, 's_cll': 0.0018274999999999958, 's_rec': 0.06801449999999998, 's_prec': 0.2210111090119397, 's_f1': 0.068074}
# GENERATION:  4
# MELHOR RESULTADO:  -0.3692372036499708
# estou nesse crossover
# BEST: {'m_auc_pr': 0.001413, 'm_auc_roc': 0.5050325, 'm_cll': -0.3692345, 'm_rec': 0.0, 'm_pred': nan, 'm_f1': nan, 's_auc_pr': 5.600000000000006e-05, 's_auc_roc': 0.0130015, 's_cll': 0.0005924999999999958, 's_rec': 0.0, 's_prec': nan, 's_f1': nan}
# GENERATION:  5
# MELHOR RESULTADO:  -0.3692372036499708
# estou nesse crossover
# BEST: {'m_auc_pr': 0.001413, 'm_auc_roc': 0.5050325, 'm_cll': -0.3692345, 'm_rec': 0.0, 'm_pred': nan, 'm_f1': nan, 's_auc_pr': 5.600000000000006e-05, 's_auc_roc': 0.0130015, 's_cll': 0.0005924999999999958, 's_rec': 0.0, 's_prec': nan, 's_f1': nan}
# GENERATION:  6
# MELHOR RESULTADO:  -0.3692372036499708
# estou nesse crossover
# BEST: {'m_auc_pr': 0.001413, 'm_auc_roc': 0.5050325, 'm_cll': -0.3692345, 'm_rec': 0.0, 'm_pred': nan, 'm_f1': nan, 's_auc_pr': 5.600000000000006e-05, 's_auc_roc': 0.0130015, 's_cll': 0.0005924999999999958, 's_rec': 0.0, 's_prec': nan, 's_f1': nan}
# GENERATION:  7
# MELHOR RESULTADO:  -0.37451722135470616
# estou nesse crossover
# BEST: {'m_auc_pr': 0.304873, 'm_auc_roc': 0.982958, 'm_cll': -0.21752149999999998, 'm_rec': 0.9889705, 'm_pred': 0.25681275, 'm_f1': 0.026881, 's_auc_pr': 0.03467500000000001, 's_auc_roc': 0.0011160000000000059, 's_cll': 0.00019149999999999723, 's_rec': 0.011029500000000025, 's_prec': 0.24318742407593263, 's_f1': 0.0008050000000000002}
# GENERATION:  8
# MELHOR RESULTADO:  -0.37451722135470616
# estou nesse crossover
# BEST: {'m_auc_pr': 0.304873, 'm_auc_roc': 0.982958, 'm_cll': -0.21752149999999998, 'm_rec': 0.9889705, 'm_pred': 0.25681275, 'm_f1': 0.026881, 's_auc_pr': 0.03467500000000001, 's_auc_roc': 0.0011160000000000059, 's_cll': 0.00019149999999999723, 's_rec': 0.011029500000000025, 's_prec': 0.24318742407593263, 's_f1': 0.0008050000000000002}
# GENERATION:  9
# MELHOR RESULTADO:  -0.37451722135470616
# estou nesse crossover
# BEST: {'m_auc_pr': 0.304873, 'm_auc_roc': 0.982958, 'm_cll': -0.21752149999999998, 'm_rec': 0.9889705, 'm_pred': 0.25681275, 'm_f1': 0.026881, 's_auc_pr': 0.03467500000000001, 's_auc_roc': 0.0011160000000000059, 's_cll': 0.00019149999999999723, 's_rec': 0.011029500000000025, 's_prec': 0.24318742407593263, 's_f1': 0.0008050000000000002}
# GENERATION:  10
# MELHOR RESULTADO:  -0.37451722135470616
# estou nesse crossover
# BEST: {'m_auc_pr': 0.304873, 'm_auc_roc': 0.982958, 'm_cll': -0.21752149999999998, 'm_rec': 0.9889705, 'm_pred': 0.25681275, 'm_f1': 0.026881, 's_auc_pr': 0.03467500000000001, 's_auc_roc': 0.0011160000000000059, 's_cll': 0.00019149999999999723, 's_rec': 0.011029500000000025, 's_prec': 0.24318742407593263, 's_f1': 0.0008050000000000002}
# GENERATION:  11
# MELHOR RESULTADO:  -0.37451722135470616
# estou nesse crossover
# BEST: {'m_auc_pr': 0.304873, 'm_auc_roc': 0.982958, 'm_cll': -0.21752149999999998, 'm_rec': 0.9889705, 'm_pred': 0.25681275, 'm_f1': 0.026881, 's_auc_pr': 0.03467500000000001, 's_auc_roc': 0.0011160000000000059, 's_cll': 0.00019149999999999723, 's_rec': 0.011029500000000025, 's_prec': 0.24318742407593263, 's_f1': 0.0008050000000000002}
# GENERATION:  12
# MELHOR RESULTADO:  -0.37451722135470616
# estou nesse crossover
# BEST: {'m_auc_pr': 0.304873, 'm_auc_roc': 0.982958, 'm_cll': -0.21752149999999998, 'm_rec': 0.9889705, 'm_pred': 0.25681275, 'm_f1': 0.026881, 's_auc_pr': 0.03467500000000001, 's_auc_roc': 0.0011160000000000059, 's_cll': 0.00019149999999999723, 's_rec': 0.011029500000000025, 's_prec': 0.24318742407593263, 's_f1': 0.0008050000000000002}
# GENERATION:  13
# MELHOR RESULTADO:  -0.37451722135470616
# estou nesse crossover
# BEST: {'m_auc_pr': 0.304873, 'm_auc_roc': 0.982958, 'm_cll': -0.21752149999999998, 'm_rec': 0.9889705, 'm_pred': 0.25681275, 'm_f1': 0.026881, 's_auc_pr': 0.03467500000000001, 's_auc_roc': 0.0011160000000000059, 's_cll': 0.00019149999999999723, 's_rec': 0.011029500000000025, 's_prec': 0.24318742407593263, 's_f1': 0.0008050000000000002}
# -0.37451722135470616 -0.37451722135470616
# -0.37451722135470616 -0.37451722135470616
# -0.37451722135470616 -0.37451722135470616
# -0.37451722135470616 -0.37451722135470616
# -0.37451722135470616 -0.37451722135470616
# -0.37451722135470616 -0.37451722135470616
# -0.37451722135470616 -0.37451722135470616
# [{'m_auc_pr': 0.304873, 'm_auc_roc': 0.982958, 'm_cll': -0.21752149999999998, 'm_rec': 0.9889705, 'm_pred': 0.25681275, 'm_f1': 0.026881, 's_auc_pr': 0.03467500000000001, 's_auc_roc': 0.0011160000000000059, 's_cll': 0.00019149999999999723, 's_rec': 0.011029500000000025, 's_prec': 0.24318742407593263, 's_f1': 0.0008050000000000002}, {'m_auc_pr': 0.304873, 'm_auc_roc': 0.982958, 'm_cll': -0.21752149999999998, 'm_rec': 0.9889705, 'm_pred': 0.25681275, 'm_f1': 0.026881, 's_auc_pr': 0.03467500000000001, 's_auc_roc': 0.0011160000000000059, 's_cll': 0.00019149999999999723, 's_rec': 0.011029500000000025, 's_prec': 0.24318742407593263, 's_f1': 0.0008050000000000002}, {'m_auc_pr': 0.304873, 'm_auc_roc': 0.982958, 'm_cll': -0.21752149999999998, 'm_rec': 0.9889705, 'm_pred': 0.25681275, 'm_f1': 0.026881, 's_auc_pr': 0.03467500000000001, 's_auc_roc': 0.0011160000000000059, 's_cll': 0.00019149999999999723, 's_rec': 0.011029500000000025, 's_prec': 0.24318742407593263, 's_f1': 0.0008050000000000002}, {'m_auc_pr': 0.304873, 'm_auc_roc': 0.982958, 'm_cll': -0.21752149999999998, 'm_rec': 0.9889705, 'm_pred': 0.25681275, 'm_f1': 0.026881, 's_auc_pr': 0.03467500000000001, 's_auc_roc': 0.0011160000000000059, 's_cll': 0.00019149999999999723, 's_rec': 0.011029500000000025, 's_prec': 0.24318742407593263, 's_f1': 0.0008050000000000002}, {'m_auc_pr': 0.304873, 'm_auc_roc': 0.982958, 'm_cll': -0.21752149999999998, 'm_rec': 0.9889705, 'm_pred': 0.25681275, 'm_f1': 0.026881, 's_auc_pr': 0.03467500000000001, 's_auc_roc': 0.0011160000000000059, 's_cll': 0.00019149999999999723, 's_rec': 0.011029500000000025, 's_prec': 0.24318742407593263, 's_f1': 0.0008050000000000002}, {'m_auc_pr': 0.304873, 'm_auc_roc': 0.982958, 'm_cll': -0.21752149999999998, 'm_rec': 0.9889705, 'm_pred': 0.25681275, 'm_f1': 0.026881, 's_auc_pr': 0.03467500000000001, 's_auc_roc': 0.0011160000000000059, 's_cll': 0.00019149999999999723, 's_rec': 0.011029500000000025, 's_prec': 0.24318742407593263, 's_f1': 0.0008050000000000002}, {'m_auc_pr': 0.304873, 'm_auc_roc': 0.982958, 'm_cll': -0.21752149999999998, 'm_rec': 0.9889705, 'm_pred': 0.25681275, 'm_f1': 0.026881, 's_auc_pr': 0.03467500000000001, 's_auc_roc': 0.0011160000000000059, 's_cll': 0.00019149999999999723, 's_rec': 0.011029500000000025, 's_prec': 0.24318742407593263, 's_f1': 0.0008050000000000002}]
# RESULT: {'m_auc_pr': 0.304873, 'm_auc_roc': 0.982958, 'm_cll': -0.21752149999999998, 'm_rec': 0.9889705, 'm_pred': 0.25681275, 'm_f1': 0.026881, 's_auc_pr': 0.03467500000000001, 's_auc_roc': 0.0011160000000000059, 's_cll': 0.00019149999999999723, 's_rec': 0.011029500000000025, 's_prec': 0.24318742407593263, 's_f1': 0.0008050000000000002}
# FIM DO GROOT GENETIC:  11330.125427007675

# %%
res_m_c
# Out:
# (<src.s_genetic.population.Population at 0x7fa97bdba390>,
#  [-0.30192878944877055,
#   -0.30528036851392854,
#   -0.31585605581736126,
#   -0.31585605581736126,
#   -0.3692372036499708,
#   -0.3692372036499708,
#   -0.3692372036499708,
#   -0.37451722135470616,
#   -0.37451722135470616,
#   -0.37451722135470616,
#   -0.37451722135470616,
#   -0.37451722135470616,
#   -0.37451722135470616,
#   -0.37451722135470616,
#   -0.37451722135470616],
#  [{'m_auc_pr': 0.23717700000000003,
#    'm_auc_roc': 0.9858585,
#    'm_cll': -0.186837,
#    'm_rec': 0.9136029999999999,
#    'm_pred': 0.26042125000000005,
#    'm_f1': 0.040751,
#    's_auc_pr': 0.013710000000000014,
#    's_auc_roc': 0.0007125000000000048,
#    's_cll': 0.0020459999999999923,
#    's_rec': 0.012868000000000046,
#    's_prec': 0.2395802165386105,
#    's_f1': 0.002253999999999999},
#   {'m_auc_pr': 0.217146,
#    'm_auc_roc': 0.9846524999999999,
#    'm_cll': -0.214578,
#    'm_rec': 0.8694855,
#    'm_pred': 0.261291,
#    'm_f1': 0.044019,
#    's_auc_pr': 0.003282000000000007,
#    's_auc_roc': 0.0011905000000000387,
#    's_cll': 0.0005570000000000019,
#    's_rec': 0.03492649999999997,
#    's_prec': 0.23870900005131773,
#    's_f1': 3.099999999999978e-05},
#   {'m_auc_pr': 0.2296095,
#    'm_auc_roc': 0.9847085,
#    'm_cll': -0.21689750000000002,
#    'm_rec': 0.8180145,
#    'm_pred': 0.28078925,
#    'm_f1': 0.11055999999999999,
#    's_auc_pr': 0.007279499999999994,
#    's_auc_roc': 0.0010844999999999883,
#    's_cll': 0.0018274999999999958,
#    's_rec': 0.06801449999999998,
#    's_prec': 0.2210111090119397,
#    's_f1': 0.068074},
#   {'m_auc_pr': 0.2296095,
#    'm_auc_roc': 0.9847085,
#    'm_cll': -0.21689750000000002,
#    'm_rec': 0.8180145,
#    'm_pred': 0.28078925,
#    'm_f1': 0.11055999999999999,
#    's_auc_pr': 0.007279499999999994,
#    's_auc_roc': 0.0010844999999999883,
#    's_cll': 0.0018274999999999958,
#    's_rec': 0.06801449999999998,
#    's_prec': 0.2210111090119397,
#    's_f1': 0.068074},
#   {'m_auc_pr': 0.001413,
#    'm_auc_roc': 0.5050325,
#    'm_cll': -0.3692345,
#    'm_rec': 0.0,
#    'm_pred': nan,
#    'm_f1': nan,
#    's_auc_pr': 5.600000000000006e-05,
#    's_auc_roc': 0.0130015,
#    's_cll': 0.0005924999999999958,
#    's_rec': 0.0,
#    's_prec': nan,
#    's_f1': nan},
#   {'m_auc_pr': 0.001413,
#    'm_auc_roc': 0.5050325,
#    'm_cll': -0.3692345,
#    'm_rec': 0.0,
#    'm_pred': nan,
#    'm_f1': nan,
#    's_auc_pr': 5.600000000000006e-05,
#    's_auc_roc': 0.0130015,
#    's_cll': 0.0005924999999999958,
#    's_rec': 0.0,
#    's_prec': nan,
#    's_f1': nan},
#   {'m_auc_pr': 0.001413,
#    'm_auc_roc': 0.5050325,
#    'm_cll': -0.3692345,
#    'm_rec': 0.0,
#    'm_pred': nan,
#    'm_f1': nan,
#    's_auc_pr': 5.600000000000006e-05,
#    's_auc_roc': 0.0130015,
#    's_cll': 0.0005924999999999958,
#    's_rec': 0.0,
#    's_prec': nan,
#    's_f1': nan},
#   {'m_auc_pr': 0.304873,
#    'm_auc_roc': 0.982958,
#    'm_cll': -0.21752149999999998,
#    'm_rec': 0.9889705,
#    'm_pred': 0.25681275,
#    'm_f1': 0.026881,
#    's_auc_pr': 0.03467500000000001,
#    's_auc_roc': 0.0011160000000000059,
#    's_cll': 0.00019149999999999723,
#    's_rec': 0.011029500000000025,
#    's_prec': 0.24318742407593263,
#    's_f1': 0.0008050000000000002},
#   {'m_auc_pr': 0.304873,
#    'm_auc_roc': 0.982958,
#    'm_cll': -0.21752149999999998,
#    'm_rec': 0.9889705,
#    'm_pred': 0.25681275,
#    'm_f1': 0.026881,
#    's_auc_pr': 0.03467500000000001,
#    's_auc_roc': 0.0011160000000000059,
#    's_cll': 0.00019149999999999723,
#    's_rec': 0.011029500000000025,
#    's_prec': 0.24318742407593263,
#    's_f1': 0.0008050000000000002},
#   {'m_auc_pr': 0.304873,
#    'm_auc_roc': 0.982958,
#    'm_cll': -0.21752149999999998,
#    'm_rec': 0.9889705,
#    'm_pred': 0.25681275,
#    'm_f1': 0.026881,
#    's_auc_pr': 0.03467500000000001,
#    's_auc_roc': 0.0011160000000000059,
#    's_cll': 0.00019149999999999723,
#    's_rec': 0.011029500000000025,
#    's_prec': 0.24318742407593263,
#    's_f1': 0.0008050000000000002},
#   {'m_auc_pr': 0.304873,
#    'm_auc_roc': 0.982958,
#    'm_cll': -0.21752149999999998,
#    'm_rec': 0.9889705,
#    'm_pred': 0.25681275,
#    'm_f1': 0.026881,
#    's_auc_pr': 0.03467500000000001,
#    's_auc_roc': 0.0011160000000000059,
#    's_cll': 0.00019149999999999723,
#    's_rec': 0.011029500000000025,
#    's_prec': 0.24318742407593263,
#    's_f1': 0.0008050000000000002},
#   {'m_auc_pr': 0.304873,
#    'm_auc_roc': 0.982958,
#    'm_cll': -0.21752149999999998,
#    'm_rec': 0.9889705,
#    'm_pred': 0.25681275,
#    'm_f1': 0.026881,
#    's_auc_pr': 0.03467500000000001,
#    's_auc_roc': 0.0011160000000000059,
#    's_cll': 0.00019149999999999723,
#    's_rec': 0.011029500000000025,
#    's_prec': 0.24318742407593263,
#    's_f1': 0.0008050000000000002},
#   {'m_auc_pr': 0.304873,
#    'm_auc_roc': 0.982958,
#    'm_cll': -0.21752149999999998,
#    'm_rec': 0.9889705,
#    'm_pred': 0.25681275,
#    'm_f1': 0.026881,
#    's_auc_pr': 0.03467500000000001,
#    's_auc_roc': 0.0011160000000000059,
#    's_cll': 0.00019149999999999723,
#    's_rec': 0.011029500000000025,
#    's_prec': 0.24318742407593263,
#    's_f1': 0.0008050000000000002},
#   {'m_auc_pr': 0.304873,
#    'm_auc_roc': 0.982958,
#    'm_cll': -0.21752149999999998,
#    'm_rec': 0.9889705,
#    'm_pred': 0.25681275,
#    'm_f1': 0.026881,
#    's_auc_pr': 0.03467500000000001,
#    's_auc_roc': 0.0011160000000000059,
#    's_cll': 0.00019149999999999723,
#    's_rec': 0.011029500000000025,
#    's_prec': 0.24318742407593263,
#    's_f1': 0.0008050000000000002},
#   {'m_auc_pr': 0.304873,
#    'm_auc_roc': 0.982958,
#    'm_cll': -0.21752149999999998,
#    'm_rec': 0.9889705,
#    'm_pred': 0.25681275,
#    'm_f1': 0.026881,
#    's_auc_pr': 0.03467500000000001,
#    's_auc_roc': 0.0011160000000000059,
#    's_cll': 0.00019149999999999723,
#    's_rec': 0.011029500000000025,
#    's_prec': 0.24318742407593263,
#    's_f1': 0.0008050000000000002}])

# %%
# final_results[f'groot_test:{source}->{target}'] = []
# final_results[f'groot_test_rev:{source}->{target}'] = []
# final_results[f'inf_res:{source}->{target}'] = []
# final_results[f'inf_res_rev:{source}->{target}'] = []

# uwcse_dataset = datasets.load('uwcse', kb_target, target=target, seed=441773)
# train_facts, train_pos, train_neg, test_facts, test_pos, test_neg = get_train_test(uwcse_dataset, 1)
# tr_train_pos = []
# tr_train_neg = []
# tr_train_facts = []

# for i in range(0, len(train_pos)):
#     tr_train_pos.extend(train_pos[i])
#     tr_train_neg.extend(train_neg[i])
#     tr_train_facts.extend(train_facts[i])

# train = [tr_train_pos, tr_train_neg, tr_train_facts]
test = [test_pos, test_neg, test_facts[0]]

individuals = get_k_best_individuals(res_m_c[0].population, 3)

n_ind = 1
for individual in individuals:
    print("INDIVIDUO ", n_ind)
    refine, transfer = get_refine_transfer(individual, source, target, 'yago2s', 'nell_finances')
    for i in range(len(train_pos)):
        ttrain = [train_pos[i], train_neg[i][:2*len(train_pos[i])], train_facts[i]]
        res_ = test_refine_transfer(kb_target, target, refine, transfer, ttrain, test)
        print(res_)
#         final_results[f'groot_test:{source}->{target}'].append(res)
#         import os
    #     thisFile = f'boostsrl/best/test/results_{target.replace('recursion_', '')}.db'
    #     thisFile = f'boostsrl/best/test/results_{target}.db'
    #     base = os.path.splitext(thisFile)[0]
    #     os.rename(thisFile, base + ".txt")
    #     tt = open('boostsrl/best/test/results_advisedby.txt', 'r').readlines()
    #     final = []
    #     for i in tt:
    #         final.append(i.replace('\n', ''))
    #     final_results[f'inf_res:{source}->{target}'].append(final)
        print("===========================================================================")
#         break

    n_ind += 1
# Out:
# INDIVIDUO  1
# ({'AUC ROC': 0.983252, 'AUC PR': 0.321372, 'CLL': -0.212376, 'Precision': [0.020038, 0.5], 'Recall': 0.905983, 'F1': 0.039208}, <boostsrl.boostsrl.test object at 0x7fa987609048>)
# ===========================================================================
# ({'AUC ROC': 0.983915, 'AUC PR': 0.197609, 'CLL': -0.212649, 'Precision': [0.018523, 0.5], 'Recall': 0.931624, 'F1': 0.036324}, <boostsrl.boostsrl.test object at 0x7fa98bc0cc50>)
# ===========================================================================
# INDIVIDUO  2
# ({'AUC ROC': 0.983252, 'AUC PR': 0.321372, 'CLL': -0.212376, 'Precision': [0.020038, 0.5], 'Recall': 0.905983, 'F1': 0.039208}, <boostsrl.boostsrl.test object at 0x7fa987609048>)
# ===========================================================================
# ({'AUC ROC': 0.983915, 'AUC PR': 0.197609, 'CLL': -0.212649, 'Precision': [0.018523, 0.5], 'Recall': 0.931624, 'F1': 0.036324}, <boostsrl.boostsrl.test object at 0x7fa98bc0c940>)
# ===========================================================================
# INDIVIDUO  3
# ({'AUC ROC': 0.983252, 'AUC PR': 0.321372, 'CLL': -0.212376, 'Precision': [0.020038, 0.5], 'Recall': 0.905983, 'F1': 0.039208}, <boostsrl.boostsrl.test object at 0x7fa987609048>)
# ===========================================================================
# ({'AUC ROC': 0.983915, 'AUC PR': 0.197609, 'CLL': -0.212649, 'Precision': [0.018523, 0.5], 'Recall': 0.931624, 'F1': 0.036324}, <boostsrl.boostsrl.test object at 0x7fa98bc0c4a8>)
# ===========================================================================

# %%
individuals_rc = get_k_best_individuals(res_m_c[0].population, 3)
n_i = 1
for ind in individuals_rc:
    refine, transfer = get_refine_transfer(ind, source, target, 'nell_sports', 'nell_finances')
    print("INDIVIDUO ", n_i)
    print("REFINE: ", refine)
    print("TRANSFER: ", transfer)
    print("==========================")
    n_i += 1
# Out:
# INDIVIDUO  1
# REFINE:  ['0;;teamplayssport00(A,B):- athleteplayssport01(B, C);true;false', '0;true;athleteledsportsteam02(C, D).;true;true', '0;true,true;teamplaysinleague03(E, A), teamplaysinleague04(E, D).;true;true', '0;true,true,true;athleteplaysforteam04(C, D).;false;false', '0;true,true,false;teamplaysagainstteam05(A, F), athleteplaysforteam06(G, A).;false;false', '0;true,false;teamplaysagainstteam06(H, A), athleteplaysinleague07(C, I).;true;true', '0;true,false,true;athleteplaysforteam07(J, H), athleteplaysinleague08(I, J).;false;false', '0;true,false,false;teamalsoknownas08(K, A).;false;false', '1;;teamplayssport10(A,B):- athleteplayssport11(C, B), athleteplaysinleague11(D, C);true;true', '1;true;athleteledsportsteam12(C, E).;true;true', '1;true,true;teamplaysagainstteam13(F, A), teamalsoknownas14(G, F).;false;false', '1;true,false;teamplaysinleague14(H, A), athleteplaysinleague15(I, H).;true;false', '1;true,false,true;teamplaysagainstteam15(A, J).;false;false', '1;false;teamplaysinleague16(A, K).;false;true', '1;false,false;athleteplayssport17(L, B).;false;true', '1;false,false,false;teamplaysagainstteam18(A, M), teamalsoknownas19(A, N).;false;true', '1;false,false,false,false;bankboughtbanktarget19(I, R).;false;false', '2;;teamplayssport20(A,B):- athleteplayssport21(B, C), athleteplaysinleague21(C, D);true;true', '2;true;teamplaysagainstteam22(E, A), teamplaysinleague23(F, A).;false;false', '2;false;teamalsoknownas23(K, A), teamalsoknownas24(L, K).;true;false', '2;false,true;teamplaysagainstteam24(A, L), athleteplaysforteam25(M, L).;true;true', '2;false,true,true;teamalsoknownas25(N, L).;false;false', '2;false,true,false;teamalsoknownas26(K, L).;false;false', '3;;teamplayssport30(A,B):- athleteplayssport31(C, B), athleteplaysinleague31(C, D);true;true', '3;true;athleteledsportsteam32(C, E).;true;false', '3;true,true;teamplaysinleague33(F, A), teamplaysinleague34(F, E).;false;false', '3;false;teamplaysinleague34(A, H).;true;true', '3;false,true;teamalsoknownas35(I, A), athleteplaysforteam36(J, I).;false;false', '3;false,false;teamplaysagainstteam36(A, K), teamalsoknownas37(L, A).;false;true', '3;false,false,false;teamplaysagainstteam37(M, A).;false;false', '4;;teamplayssport40(A,B):- athleteplayssport41(C, B);true;false', '4;true;athleteledsportsteam42(C, D).;true;false', '4;true,true;athleteplaysforteam43(E, A), athleteledsportsteam44(E, F).;true;true', '4;true,true,true;teamplaysagainstteam44(A, D), athleteplaysforteam45(C, D).;false;false', '4;true,true,false;teamplaysagainstteam45(A, G).;false;false', '5;;teamplayssport50(A,B):- athleteledsportsteam51(C, A), athleteplayssport51(D, C);true;true', '5;true;athleteplayssport52(E, B), athleteledsportsteam53(E, F).;true;false', '5;true,true;teamplaysagainstteam53(A, F).;true;false', '5;true,true,true;teamalsoknownas54(G, A), teamalsoknownas55(G, F).;false;false', '5;false;athleteplayssport55(B, H).;true;true', '5;false,false;economicsectorcompanytarget56(E, Q), companyceotarget57(E, G).;false;false', '5;false,true;athleteplaysforteam57(H, I).;true;true', '5;false,true,true;teamplaysinleague58(J, A), athleteledsportsteam59(K, I).;false;false', '5;false,true,false;athleteplaysinleague59(H, L), teamplaysagainstteam510(M, A).;false;false', '6;;teamplayssport60(A,B):- athleteplayssport61(B, C), athleteplaysinleague61(D, C);true;true', '6;true;athleteledsportsteam62(E, A).;true;true', '6;true,true;bankbankincountrytarget63(A, C).;false;false', '6;true,false;teamplaysinleague64(A, F), teamplaysagainstteam65(A, G).;true;true', '6;true,false,true;athleteledsportsteam65(C, H), teamplaysinleague66(H, F).;false;false', '6;true,false,false;teamplaysagainstteam66(I, A), teamplaysinleague67(I, J).;false;false', '6;false;teamalsoknownas67(K, A), athleteplaysforteam68(L, K).;true;false', '6;false,true;teamplaysagainstteam68(M, A), teamplaysagainstteam69(M, K).;false;true', '6;false,true,false;athleteledsportsteam69(L, K).;false;false', '7;;teamplayssport70(A,B):- athleteplayssport71(B, C), athletepla ...
# TRANSFER:  ['source: teamplayssport00(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport00(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport01(athlete,sport).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplayssport01(A,B)=economicsectorcompany(A,B).', 'source: athleteledsportsteam02(athlete,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: athleteledsportsteam02(A,B)=companyalsoknownas(A,B).', 'source: teamplaysinleague03(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague03(A,B)=economicsectorcompany(A,B).', 'source: teamplaysinleague04(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague04(A,B)=economicsectorcompany(A,B).', 'source: athleteplaysforteam04(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteplaysforteam04(A,B)=bankboughtbank(A,B).', 'source: teamplaysagainstteam05(sportsteam,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: teamplaysagainstteam05(A,B)=bankboughtbank(A,B).', 'source: athleteplaysforteam06(athlete,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: athleteplaysforteam06(A,B)=companyalsoknownas(A,B).', 'source: teamplaysagainstteam06(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamplaysagainstteam06(A,B)=companyalsoknownas(A,B).', 'source: athleteplaysinleague07(athlete,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplaysinleague07(A,B)=companyeconomicsector(A,B).', 'source: athleteplaysforteam07(athlete,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: athleteplaysforteam07(A,B)=companyalsoknownas(A,B).', 'source: athleteplaysinleague08(athlete,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplaysinleague08(A,B)=economicsectorcompany(A,B).', 'source: teamalsoknownas08(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamalsoknownas08(A,B)=acquired(A,B).', 'source: teamplayssport10(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport10(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport11(athlete,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplayssport11(A,B)=companyeconomicsector(A,B).', 'source: athleteplaysinleague11(athlete,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplaysinleague11(A,B)=economicsectorcompany(A,B).', 'source: athleteledsportsteam12(athlete,sportsteam).', 'target: acquired(company,company).', 'setMap: athleteledsportsteam12(A,B)=acquired(A,B).', 'source: teamplaysagainstteam13(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamplaysagainstteam13(A,B)=acquired(A,B).', 'source: teamalsoknownas14(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamalsoknownas14(A,B)=companyalsoknownas(A,B).', 'source: teamplaysinleague14(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague14(A,B)=economicsectorcompany(A,B).', 'source: athleteplaysinleague15(athlete,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplaysinleague15(A,B)=companyeconomicsector(A,B).', 'source: teamplaysagainstteam15(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamplaysagainstteam15(A,B)=companyalsoknownas(A,B).', 'source: teamplaysinleague16(sportsteam,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplaysinleague16(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport17(athlete,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplayssport17(A,B)=companyeconomicsector(A,B).', 'source: teamplaysagainstteam18(sportsteam,sportsteam).' ...
# ==========================
# INDIVIDUO  2
# REFINE:  ['0;;teamplayssport00(A,B):- athleteplayssport01(B, C);true;false', '0;true;athleteledsportsteam02(C, D).;true;true', '0;true,true;teamplaysinleague03(E, A), teamplaysinleague04(E, D).;true;true', '0;true,true,true;athleteplaysforteam04(C, D).;false;false', '0;true,true,false;teamplaysagainstteam05(A, F), athleteplaysforteam06(G, A).;false;false', '0;true,false;teamplaysagainstteam06(H, A), athleteplaysinleague07(C, I).;true;true', '0;true,false,true;athleteplaysforteam07(J, H), athleteplaysinleague08(I, J).;false;false', '0;true,false,false;teamalsoknownas08(K, A).;false;false', '1;;teamplayssport10(A,B):- athleteplayssport11(C, B), athleteplaysinleague11(D, C);true;true', '1;true;athleteledsportsteam12(C, E).;true;true', '1;true,true;teamplaysagainstteam13(F, A), teamalsoknownas14(G, F).;false;false', '1;true,false;teamplaysinleague14(H, A), athleteplaysinleague15(I, H).;true;false', '1;true,false,true;teamplaysagainstteam15(A, J).;false;false', '1;false;teamplaysinleague16(A, K).;false;true', '1;false,false;athleteplayssport17(L, B).;false;true', '1;false,false,false;teamplaysagainstteam18(A, M), teamalsoknownas19(A, N).;false;true', '1;false,false,false,false;bankboughtbanktarget19(I, R).;false;false', '2;;teamplayssport20(A,B):- athleteplayssport21(B, C), athleteplaysinleague21(C, D);true;true', '2;true;teamplaysagainstteam22(E, A), teamplaysinleague23(F, A).;false;false', '2;false;teamalsoknownas23(K, A), teamalsoknownas24(L, K).;true;false', '2;false,true;teamplaysagainstteam24(A, L), athleteplaysforteam25(M, L).;true;true', '2;false,true,true;teamalsoknownas25(N, L).;false;false', '2;false,true,false;teamalsoknownas26(K, L).;false;false', '3;;teamplayssport30(A,B):- athleteplayssport31(C, B), athleteplaysinleague31(C, D);true;true', '3;true;athleteledsportsteam32(C, E).;true;false', '3;true,true;teamplaysinleague33(F, A), teamplaysinleague34(F, E).;false;false', '3;false;teamplaysinleague34(A, H).;true;true', '3;false,true;teamalsoknownas35(I, A), athleteplaysforteam36(J, I).;false;false', '3;false,false;teamplaysagainstteam36(A, K), teamalsoknownas37(L, A).;false;true', '3;false,false,false;teamplaysagainstteam37(M, A).;false;false', '4;;teamplayssport40(A,B):- athleteplayssport41(C, B);true;false', '4;true;athleteledsportsteam42(C, D).;true;false', '4;true,true;athleteplaysforteam43(E, A), athleteledsportsteam44(E, F).;true;true', '4;true,true,true;teamplaysagainstteam44(A, D), athleteplaysforteam45(C, D).;false;false', '4;true,true,false;teamplaysagainstteam45(A, G).;false;false', '5;;teamplayssport50(A,B):- athleteledsportsteam51(C, A), athleteplayssport51(D, C);true;true', '5;true;athleteplayssport52(E, B), athleteledsportsteam53(E, F).;true;false', '5;true,true;teamplaysagainstteam53(A, F).;true;false', '5;true,true,true;teamalsoknownas54(G, A), teamalsoknownas55(G, F).;false;false', '5;false;athleteplayssport55(B, H).;true;true', '5;false,false;economicsectorcompanytarget56(E, Q), companyceotarget57(E, G).;false;false', '5;false,true;athleteplaysforteam57(H, I).;true;true', '5;false,true,true;teamplaysinleague58(J, A), athleteledsportsteam59(K, I).;false;false', '5;false,true,false;athleteplaysinleague59(H, L), teamplaysagainstteam510(M, A).;false;false', '6;;teamplayssport60(A,B):- athleteplayssport61(B, C), athleteplaysinleague61(D, C);true;true', '6;true;athleteledsportsteam62(E, A).;true;true', '6;true,true;bankbankincountrytarget63(A, C).;false;false', '6;true,false;teamplaysinleague64(A, F), teamplaysagainstteam65(A, G).;true;true', '6;true,false,true;athleteledsportsteam65(C, H), teamplaysinleague66(H, F).;false;false', '6;true,false,false;teamplaysagainstteam66(I, A), teamplaysinleague67(I, J).;false;false', '6;false;teamalsoknownas67(K, A), athleteplaysforteam68(L, K).;true;false', '6;false,true;teamplaysagainstteam68(M, A), teamplaysagainstteam69(M, K).;false;true', '6;false,true,false;athleteledsportsteam69(L, K).;false;false', '7;;teamplayssport70(A,B):- athleteplayssport71(B, C), athletepla ...
# TRANSFER:  ['source: teamplayssport00(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport00(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport01(athlete,sport).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplayssport01(A,B)=economicsectorcompany(A,B).', 'source: athleteledsportsteam02(athlete,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: athleteledsportsteam02(A,B)=companyalsoknownas(A,B).', 'source: teamplaysinleague03(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague03(A,B)=economicsectorcompany(A,B).', 'source: teamplaysinleague04(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague04(A,B)=economicsectorcompany(A,B).', 'source: athleteplaysforteam04(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteplaysforteam04(A,B)=bankboughtbank(A,B).', 'source: teamplaysagainstteam05(sportsteam,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: teamplaysagainstteam05(A,B)=bankboughtbank(A,B).', 'source: athleteplaysforteam06(athlete,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: athleteplaysforteam06(A,B)=companyalsoknownas(A,B).', 'source: teamplaysagainstteam06(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamplaysagainstteam06(A,B)=companyalsoknownas(A,B).', 'source: athleteplaysinleague07(athlete,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplaysinleague07(A,B)=companyeconomicsector(A,B).', 'source: athleteplaysforteam07(athlete,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: athleteplaysforteam07(A,B)=companyalsoknownas(A,B).', 'source: athleteplaysinleague08(athlete,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplaysinleague08(A,B)=economicsectorcompany(A,B).', 'source: teamalsoknownas08(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamalsoknownas08(A,B)=acquired(A,B).', 'source: teamplayssport10(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport10(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport11(athlete,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplayssport11(A,B)=companyeconomicsector(A,B).', 'source: athleteplaysinleague11(athlete,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplaysinleague11(A,B)=economicsectorcompany(A,B).', 'source: athleteledsportsteam12(athlete,sportsteam).', 'target: acquired(company,company).', 'setMap: athleteledsportsteam12(A,B)=acquired(A,B).', 'source: teamplaysagainstteam13(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamplaysagainstteam13(A,B)=acquired(A,B).', 'source: teamalsoknownas14(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamalsoknownas14(A,B)=companyalsoknownas(A,B).', 'source: teamplaysinleague14(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague14(A,B)=economicsectorcompany(A,B).', 'source: athleteplaysinleague15(athlete,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplaysinleague15(A,B)=companyeconomicsector(A,B).', 'source: teamplaysagainstteam15(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamplaysagainstteam15(A,B)=companyalsoknownas(A,B).', 'source: teamplaysinleague16(sportsteam,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplaysinleague16(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport17(athlete,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplayssport17(A,B)=companyeconomicsector(A,B).', 'source: teamplaysagainstteam18(sportsteam,sportsteam).' ...
# ==========================
# INDIVIDUO  3
# REFINE:  ['0;;teamplayssport00(A,B):- athleteplayssport01(B, C);true;false', '0;true;athleteledsportsteam02(C, D).;true;true', '0;true,true;teamplaysinleague03(E, A), teamplaysinleague04(E, D).;true;true', '0;true,true,true;athleteplaysforteam04(C, D).;false;false', '0;true,true,false;teamplaysagainstteam05(A, F), athleteplaysforteam06(G, A).;false;false', '0;true,false;teamplaysagainstteam06(H, A), athleteplaysinleague07(C, I).;true;true', '0;true,false,true;athleteplaysforteam07(J, H), athleteplaysinleague08(I, J).;false;false', '0;true,false,false;teamalsoknownas08(K, A).;false;false', '1;;teamplayssport10(A,B):- athleteplayssport11(C, B), athleteplaysinleague11(D, C);true;true', '1;true;athleteledsportsteam12(C, E).;true;true', '1;true,true;teamplaysagainstteam13(F, A), teamalsoknownas14(G, F).;false;false', '1;true,false;teamplaysinleague14(H, A), athleteplaysinleague15(I, H).;true;false', '1;true,false,true;teamplaysagainstteam15(A, J).;false;false', '1;false;teamplaysinleague16(A, K).;false;true', '1;false,false;athleteplayssport17(L, B).;false;true', '1;false,false,false;teamplaysagainstteam18(A, M), teamalsoknownas19(A, N).;false;true', '1;false,false,false,false;bankboughtbanktarget19(I, R).;false;false', '2;;teamplayssport20(A,B):- athleteplayssport21(B, C), athleteplaysinleague21(C, D);true;true', '2;true;teamplaysagainstteam22(E, A), teamplaysinleague23(F, A).;false;false', '2;false;teamalsoknownas23(K, A), teamalsoknownas24(L, K).;true;false', '2;false,true;teamplaysagainstteam24(A, L), athleteplaysforteam25(M, L).;true;true', '2;false,true,true;teamalsoknownas25(N, L).;false;false', '2;false,true,false;teamalsoknownas26(K, L).;false;false', '3;;teamplayssport30(A,B):- athleteplayssport31(C, B), athleteplaysinleague31(C, D);true;true', '3;true;athleteledsportsteam32(C, E).;true;false', '3;true,true;teamplaysinleague33(F, A), teamplaysinleague34(F, E).;false;false', '3;false;teamplaysinleague34(A, H).;true;true', '3;false,true;teamalsoknownas35(I, A), athleteplaysforteam36(J, I).;false;false', '3;false,false;teamplaysagainstteam36(A, K), teamalsoknownas37(L, A).;false;true', '3;false,false,false;teamplaysagainstteam37(M, A).;false;false', '4;;teamplayssport40(A,B):- athleteplayssport41(C, B);true;false', '4;true;athleteledsportsteam42(C, D).;true;false', '4;true,true;athleteplaysforteam43(E, A), athleteledsportsteam44(E, F).;true;true', '4;true,true,true;teamplaysagainstteam44(A, D), athleteplaysforteam45(C, D).;false;false', '4;true,true,false;teamplaysagainstteam45(A, G).;false;false', '5;;teamplayssport50(A,B):- athleteledsportsteam51(C, A), athleteplayssport51(D, C);true;true', '5;true;athleteplayssport52(E, B), athleteledsportsteam53(E, F).;true;false', '5;true,true;teamplaysagainstteam53(A, F).;true;false', '5;true,true,true;teamalsoknownas54(G, A), teamalsoknownas55(G, F).;false;false', '5;false;athleteplayssport55(B, H).;true;true', '5;false,false;economicsectorcompanytarget56(E, Q), companyceotarget57(E, G).;false;false', '5;false,true;athleteplaysforteam57(H, I).;true;true', '5;false,true,true;teamplaysinleague58(J, A), athleteledsportsteam59(K, I).;false;false', '5;false,true,false;athleteplaysinleague59(H, L), teamplaysagainstteam510(M, A).;false;false', '6;;teamplayssport60(A,B):- athleteplayssport61(B, C), athleteplaysinleague61(D, C);true;true', '6;true;athleteledsportsteam62(E, A).;true;true', '6;true,true;bankbankincountrytarget63(A, C).;false;false', '6;true,false;teamplaysinleague64(A, F), teamplaysagainstteam65(A, G).;true;true', '6;true,false,true;athleteledsportsteam65(C, H), teamplaysinleague66(H, F).;false;false', '6;true,false,false;teamplaysagainstteam66(I, A), teamplaysinleague67(I, J).;false;false', '6;false;teamalsoknownas67(K, A), athleteplaysforteam68(L, K).;true;false', '6;false,true;teamplaysagainstteam68(M, A), teamplaysagainstteam69(M, K).;false;true', '6;false,true,false;athleteledsportsteam69(L, K).;false;false', '7;;teamplayssport70(A,B):- athleteplayssport71(B, C), athletepla ...
# TRANSFER:  ['source: teamplayssport00(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport00(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport01(athlete,sport).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplayssport01(A,B)=economicsectorcompany(A,B).', 'source: athleteledsportsteam02(athlete,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: athleteledsportsteam02(A,B)=companyalsoknownas(A,B).', 'source: teamplaysinleague03(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague03(A,B)=economicsectorcompany(A,B).', 'source: teamplaysinleague04(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague04(A,B)=economicsectorcompany(A,B).', 'source: athleteplaysforteam04(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteplaysforteam04(A,B)=bankboughtbank(A,B).', 'source: teamplaysagainstteam05(sportsteam,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: teamplaysagainstteam05(A,B)=bankboughtbank(A,B).', 'source: athleteplaysforteam06(athlete,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: athleteplaysforteam06(A,B)=companyalsoknownas(A,B).', 'source: teamplaysagainstteam06(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamplaysagainstteam06(A,B)=companyalsoknownas(A,B).', 'source: athleteplaysinleague07(athlete,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplaysinleague07(A,B)=companyeconomicsector(A,B).', 'source: athleteplaysforteam07(athlete,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: athleteplaysforteam07(A,B)=companyalsoknownas(A,B).', 'source: athleteplaysinleague08(athlete,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplaysinleague08(A,B)=economicsectorcompany(A,B).', 'source: teamalsoknownas08(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamalsoknownas08(A,B)=acquired(A,B).', 'source: teamplayssport10(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport10(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport11(athlete,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplayssport11(A,B)=companyeconomicsector(A,B).', 'source: athleteplaysinleague11(athlete,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplaysinleague11(A,B)=economicsectorcompany(A,B).', 'source: athleteledsportsteam12(athlete,sportsteam).', 'target: acquired(company,company).', 'setMap: athleteledsportsteam12(A,B)=acquired(A,B).', 'source: teamplaysagainstteam13(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamplaysagainstteam13(A,B)=acquired(A,B).', 'source: teamalsoknownas14(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamalsoknownas14(A,B)=companyalsoknownas(A,B).', 'source: teamplaysinleague14(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague14(A,B)=economicsectorcompany(A,B).', 'source: athleteplaysinleague15(athlete,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplaysinleague15(A,B)=companyeconomicsector(A,B).', 'source: teamplaysagainstteam15(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamplaysagainstteam15(A,B)=companyalsoknownas(A,B).', 'source: teamplaysinleague16(sportsteam,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplaysinleague16(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport17(athlete,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplayssport17(A,B)=companyeconomicsector(A,B).', 'source: teamplaysagainstteam18(sportsteam,sportsteam).' ...
# ==========================

# %% [markdown]
# # Crossover modificado

# %% [markdown]
# ## sem revisão

# %%
start = time.time()
res_cc_r = genetic(new_src_struct, target, source, train_pos, 
                                         train_neg, train_facts, kb_source, kb_target, pred_target,
                                          NUM_GEN=14, pop_size=30, crossover_type='tree')
print("FIM DO GROOT GENETIC: ", time.time()-start)
# Out:
# GENERATION:  0
# MELHOR RESULTADO:  -0.23687381455112339
# entrei aqui
# BEST: {'m_auc_pr': 0.095494, 'm_auc_roc': 0.980745, 'm_cll': -0.216772, 'm_rec': 0.849265, 'm_pred': 0.26653024999999997, 'm_f1': 0.063643, 's_auc_pr': 0.00519, 's_auc_roc': 0.00026399999999998647, 's_cll': 0.0010570000000000024, 's_rec': 0.0, 's_prec': 0.2334697913460915, 's_f1': 0.00036399999999999627}
# GENERATION:  1
# MELHOR RESULTADO:  -0.30413267025798135
# entrei aqui
# BEST: {'m_auc_pr': 0.063646, 'm_auc_roc': 0.9354495, 'm_cll': -0.2973985, 'm_rec': 0.001838, 'm_pred': nan, 'm_f1': nan, 's_auc_pr': 0.0011380000000000001, 's_auc_roc': 0.00893550000000004, 's_cll': 0.001067499999999999, 's_rec': 0.001838, 's_prec': nan, 's_f1': nan}
# GENERATION:  2
# MELHOR RESULTADO:  -0.30413267025798135
# entrei aqui
# BEST: {'m_auc_pr': 0.063646, 'm_auc_roc': 0.9354495, 'm_cll': -0.2973985, 'm_rec': 0.001838, 'm_pred': nan, 'm_f1': nan, 's_auc_pr': 0.0011380000000000001, 's_auc_roc': 0.00893550000000004, 's_cll': 0.001067499999999999, 's_rec': 0.001838, 's_prec': nan, 's_f1': nan}
# GENERATION:  3
# MELHOR RESULTADO:  -0.30413267025798135
# entrei aqui
# BEST: {'m_auc_pr': 0.063646, 'm_auc_roc': 0.9354495, 'm_cll': -0.2973985, 'm_rec': 0.001838, 'm_pred': nan, 'm_f1': nan, 's_auc_pr': 0.0011380000000000001, 's_auc_roc': 0.00893550000000004, 's_cll': 0.001067499999999999, 's_rec': 0.001838, 's_prec': nan, 's_f1': nan}
# GENERATION:  4
# MELHOR RESULTADO:  -0.30413267025798135
# entrei aqui
# BEST: {'m_auc_pr': 0.063646, 'm_auc_roc': 0.9354495, 'm_cll': -0.2973985, 'm_rec': 0.001838, 'm_pred': nan, 'm_f1': nan, 's_auc_pr': 0.0011380000000000001, 's_auc_roc': 0.00893550000000004, 's_cll': 0.001067499999999999, 's_rec': 0.001838, 's_prec': nan, 's_f1': nan}
# GENERATION:  5
# MELHOR RESULTADO:  -0.30413267025798135
# entrei aqui
# BEST: {'m_auc_pr': 0.063646, 'm_auc_roc': 0.9354495, 'm_cll': -0.2973985, 'm_rec': 0.001838, 'm_pred': nan, 'm_f1': nan, 's_auc_pr': 0.0011380000000000001, 's_auc_roc': 0.00893550000000004, 's_cll': 0.001067499999999999, 's_rec': 0.001838, 's_prec': nan, 's_f1': nan}
# GENERATION:  6
# MELHOR RESULTADO:  -0.30413267025798135
# entrei aqui
# BEST: {'m_auc_pr': 0.063646, 'm_auc_roc': 0.9354495, 'm_cll': -0.2973985, 'm_rec': 0.001838, 'm_pred': nan, 'm_f1': nan, 's_auc_pr': 0.0011380000000000001, 's_auc_roc': 0.00893550000000004, 's_cll': 0.001067499999999999, 's_rec': 0.001838, 's_prec': nan, 's_f1': nan}
# GENERATION:  7
# MELHOR RESULTADO:  -0.30413267025798135
# entrei aqui
# BEST: {'m_auc_pr': 0.063646, 'm_auc_roc': 0.9354495, 'm_cll': -0.2973985, 'm_rec': 0.001838, 'm_pred': nan, 'm_f1': nan, 's_auc_pr': 0.0011380000000000001, 's_auc_roc': 0.00893550000000004, 's_cll': 0.001067499999999999, 's_rec': 0.001838, 's_prec': nan, 's_f1': nan}
# GENERATION:  8
# MELHOR RESULTADO:  -0.348570733553464
# entrei aqui
# BEST: {'m_auc_pr': 0.293437, 'm_auc_roc': 0.9871045, 'm_cll': -0.188139, 'm_rec': 0.9172795, 'm_pred': 0.260329, 'm_f1': 0.0404055, 's_auc_pr': 0.022421000000000024, 's_auc_roc': 0.00035849999999998383, 's_cll': 0.0022880000000000122, 's_rec': 0.005514499999999978, 's_prec': 0.239671634619118, 's_f1': 0.001497500000000002}
# GENERATION:  9
# MELHOR RESULTADO:  -0.348570733553464
# entrei aqui
# BEST: {'m_auc_pr': 0.293437, 'm_auc_roc': 0.9871045, 'm_cll': -0.188139, 'm_rec': 0.9172795, 'm_pred': 0.260329, 'm_f1': 0.0404055, 's_auc_pr': 0.022421000000000024, 's_auc_roc': 0.00035849999999998383, 's_cll': 0.0022880000000000122, 's_rec': 0.005514499999999978, 's_prec': 0.239671634619118, 's_f1': 0.001497500000000002}
# GENERATION:  10
# MELHOR RESULTADO:  -0.348570733553464
# entrei aqui
# BEST: {'m_auc_pr': 0.293437, 'm_auc_roc': 0.9871045, 'm_cll': -0.188139, 'm_rec': 0.9172795, 'm_pred': 0.260329, 'm_f1': 0.0404055, 's_auc_pr': 0.022421000000000024, 's_auc_roc': 0.00035849999999998383, 's_cll': 0.0022880000000000122, 's_rec': 0.005514499999999978, 's_prec': 0.239671634619118, 's_f1': 0.001497500000000002}
# GENERATION:  11
# MELHOR RESULTADO:  -0.348570733553464
# entrei aqui
# BEST: {'m_auc_pr': 0.293437, 'm_auc_roc': 0.9871045, 'm_cll': -0.188139, 'm_rec': 0.9172795, 'm_pred': 0.260329, 'm_f1': 0.0404055, 's_auc_pr': 0.022421000000000024, 's_auc_roc': 0.00035849999999998383, 's_cll': 0.0022880000000000122, 's_rec': 0.005514499999999978, 's_prec': 0.239671634619118, 's_f1': 0.001497500000000002}
# GENERATION:  12
# MELHOR RESULTADO:  -0.348570733553464
# entrei aqui
# BEST: {'m_auc_pr': 0.293437, 'm_auc_roc': 0.9871045, 'm_cll': -0.188139, 'm_rec': 0.9172795, 'm_pred': 0.260329, 'm_f1': 0.0404055, 's_auc_pr': 0.022421000000000024, 's_auc_roc': 0.00035849999999998383, 's_cll': 0.0022880000000000122, 's_rec': 0.005514499999999978, 's_prec': 0.239671634619118, 's_f1': 0.001497500000000002}
# GENERATION:  13
# MELHOR RESULTADO:  -0.36957717827167036
# entrei aqui
# BEST: {'m_auc_pr': 0.001407, 'm_auc_roc': 0.5023420000000001, 'm_cll': -0.36957450000000003, 'm_rec': 0.0, 'm_pred': nan, 'm_f1': nan, 's_auc_pr': 5.199999999999996e-05, 's_auc_roc': 0.01388600000000001, 's_cll': 3.149999999998987e-05, 's_rec': 0.0, 's_prec': nan, 's_f1': nan}
# -0.36957717827167036 -0.36957717827167036
# -0.36957717827167036 -0.36957717827167036
# [{'m_auc_pr': 0.001407, 'm_auc_roc': 0.5023420000000001, 'm_cll': -0.36957450000000003, 'm_rec': 0.0, 'm_pred': nan, 'm_f1': nan, 's_auc_pr': 5.199999999999996e-05, 's_auc_roc': 0.01388600000000001, 's_cll': 3.149999999998987e-05, 's_rec': 0.0, 's_prec': nan, 's_f1': nan}, {'m_auc_pr': 0.001407, 'm_auc_roc': 0.5023420000000001, 'm_cll': -0.36957450000000003, 'm_rec': 0.0, 'm_pred': nan, 'm_f1': nan, 's_auc_pr': 5.199999999999996e-05, 's_auc_roc': 0.01388600000000001, 's_cll': 3.149999999998987e-05, 's_rec': 0.0, 's_prec': nan, 's_f1': nan}]
# RESULT: {'m_auc_pr': 0.001407, 'm_auc_roc': 0.5023420000000001, 'm_cll': -0.36957450000000003, 'm_rec': 0.0, 'm_pred': nan, 'm_f1': nan, 's_auc_pr': 5.199999999999996e-05, 's_auc_roc': 0.01388600000000001, 's_cll': 3.149999999998987e-05, 's_rec': 0.0, 's_prec': nan, 's_f1': nan}
# FIM DO GROOT GENETIC:  8355.796676158905

# %%
res_cc_r
# Out:
# (<src.s_genetic.population.Population at 0x7fa9b7b315c0>,
#  [-0.23687381455112339,
#   -0.30413267025798135,
#   -0.30413267025798135,
#   -0.30413267025798135,
#   -0.30413267025798135,
#   -0.30413267025798135,
#   -0.30413267025798135,
#   -0.30413267025798135,
#   -0.348570733553464,
#   -0.348570733553464,
#   -0.348570733553464,
#   -0.348570733553464,
#   -0.348570733553464,
#   -0.36957717827167036,
#   -0.36957717827167036],
#  [{'m_auc_pr': 0.095494,
#    'm_auc_roc': 0.980745,
#    'm_cll': -0.216772,
#    'm_rec': 0.849265,
#    'm_pred': 0.26653024999999997,
#    'm_f1': 0.063643,
#    's_auc_pr': 0.00519,
#    's_auc_roc': 0.00026399999999998647,
#    's_cll': 0.0010570000000000024,
#    's_rec': 0.0,
#    's_prec': 0.2334697913460915,
#    's_f1': 0.00036399999999999627},
#   {'m_auc_pr': 0.063646,
#    'm_auc_roc': 0.9354495,
#    'm_cll': -0.2973985,
#    'm_rec': 0.001838,
#    'm_pred': nan,
#    'm_f1': nan,
#    's_auc_pr': 0.0011380000000000001,
#    's_auc_roc': 0.00893550000000004,
#    's_cll': 0.001067499999999999,
#    's_rec': 0.001838,
#    's_prec': nan,
#    's_f1': nan},
#   {'m_auc_pr': 0.063646,
#    'm_auc_roc': 0.9354495,
#    'm_cll': -0.2973985,
#    'm_rec': 0.001838,
#    'm_pred': nan,
#    'm_f1': nan,
#    's_auc_pr': 0.0011380000000000001,
#    's_auc_roc': 0.00893550000000004,
#    's_cll': 0.001067499999999999,
#    's_rec': 0.001838,
#    's_prec': nan,
#    's_f1': nan},
#   {'m_auc_pr': 0.063646,
#    'm_auc_roc': 0.9354495,
#    'm_cll': -0.2973985,
#    'm_rec': 0.001838,
#    'm_pred': nan,
#    'm_f1': nan,
#    's_auc_pr': 0.0011380000000000001,
#    's_auc_roc': 0.00893550000000004,
#    's_cll': 0.001067499999999999,
#    's_rec': 0.001838,
#    's_prec': nan,
#    's_f1': nan},
#   {'m_auc_pr': 0.063646,
#    'm_auc_roc': 0.9354495,
#    'm_cll': -0.2973985,
#    'm_rec': 0.001838,
#    'm_pred': nan,
#    'm_f1': nan,
#    's_auc_pr': 0.0011380000000000001,
#    's_auc_roc': 0.00893550000000004,
#    's_cll': 0.001067499999999999,
#    's_rec': 0.001838,
#    's_prec': nan,
#    's_f1': nan},
#   {'m_auc_pr': 0.063646,
#    'm_auc_roc': 0.9354495,
#    'm_cll': -0.2973985,
#    'm_rec': 0.001838,
#    'm_pred': nan,
#    'm_f1': nan,
#    's_auc_pr': 0.0011380000000000001,
#    's_auc_roc': 0.00893550000000004,
#    's_cll': 0.001067499999999999,
#    's_rec': 0.001838,
#    's_prec': nan,
#    's_f1': nan},
#   {'m_auc_pr': 0.063646,
#    'm_auc_roc': 0.9354495,
#    'm_cll': -0.2973985,
#    'm_rec': 0.001838,
#    'm_pred': nan,
#    'm_f1': nan,
#    's_auc_pr': 0.0011380000000000001,
#    's_auc_roc': 0.00893550000000004,
#    's_cll': 0.001067499999999999,
#    's_rec': 0.001838,
#    's_prec': nan,
#    's_f1': nan},
#   {'m_auc_pr': 0.063646,
#    'm_auc_roc': 0.9354495,
#    'm_cll': -0.2973985,
#    'm_rec': 0.001838,
#    'm_pred': nan,
#    'm_f1': nan,
#    's_auc_pr': 0.0011380000000000001,
#    's_auc_roc': 0.00893550000000004,
#    's_cll': 0.001067499999999999,
#    's_rec': 0.001838,
#    's_prec': nan,
#    's_f1': nan},
#   {'m_auc_pr': 0.293437,
#    'm_auc_roc': 0.9871045,
#    'm_cll': -0.188139,
#    'm_rec': 0.9172795,
#    'm_pred': 0.260329,
#    'm_f1': 0.0404055,
#    's_auc_pr': 0.022421000000000024,
#    's_auc_roc': 0.00035849999999998383,
#    's_cll': 0.0022880000000000122,
#    's_rec': 0.005514499999999978,
#    's_prec': 0.239671634619118,
#    's_f1': 0.001497500000000002},
#   {'m_auc_pr': 0.293437,
#    'm_auc_roc': 0.9871045,
#    'm_cll': -0.188139,
#    'm_rec': 0.9172795,
#    'm_pred': 0.260329,
#    'm_f1': 0.0404055,
#    's_auc_pr': 0.022421000000000024,
#    's_auc_roc': 0.00035849999999998383,
#    's_cll': 0.0022880000000000122,
#    's_rec': 0.005514499999999978,
#    's_prec': 0.239671634619118,
#    's_f1': 0.001497500000000002},
#   {'m_auc_pr': 0.293437,
#    'm_auc_roc': 0.9871045,
#    'm_cll': -0.188139,
#    'm_rec': 0.9172795,
#    'm_pred': 0.260329,
#    'm_f1': 0.0404055,
#    's_auc_pr': 0.022421000000000024,
#    's_auc_roc': 0.00035849999999998383,
#    's_cll': 0.0022880000000000122,
#    's_rec': 0.005514499999999978,
#    's_prec': 0.239671634619118,
#    's_f1': 0.001497500000000002},
#   {'m_auc_pr': 0.293437,
#    'm_auc_roc': 0.9871045,
#    'm_cll': -0.188139,
#    'm_rec': 0.9172795,
#    'm_pred': 0.260329,
#    'm_f1': 0.0404055,
#    's_auc_pr': 0.022421000000000024,
#    's_auc_roc': 0.00035849999999998383,
#    's_cll': 0.0022880000000000122,
#    's_rec': 0.005514499999999978,
#    's_prec': 0.239671634619118,
#    's_f1': 0.001497500000000002},
#   {'m_auc_pr': 0.293437,
#    'm_auc_roc': 0.9871045,
#    'm_cll': -0.188139,
#    'm_rec': 0.9172795,
#    'm_pred': 0.260329,
#    'm_f1': 0.0404055,
#    's_auc_pr': 0.022421000000000024,
#    's_auc_roc': 0.00035849999999998383,
#    's_cll': 0.0022880000000000122,
#    's_rec': 0.005514499999999978,
#    's_prec': 0.239671634619118,
#    's_f1': 0.001497500000000002},
#   {'m_auc_pr': 0.001407,
#    'm_auc_roc': 0.5023420000000001,
#    'm_cll': -0.36957450000000003,
#    'm_rec': 0.0,
#    'm_pred': nan,
#    'm_f1': nan,
#    's_auc_pr': 5.199999999999996e-05,
#    's_auc_roc': 0.01388600000000001,
#    's_cll': 3.149999999998987e-05,
#    's_rec': 0.0,
#    's_prec': nan,
#    's_f1': nan},
#   {'m_auc_pr': 0.001407,
#    'm_auc_roc': 0.5023420000000001,
#    'm_cll': -0.36957450000000003,
#    'm_rec': 0.0,
#    'm_pred': nan,
#    'm_f1': nan,
#    's_auc_pr': 5.199999999999996e-05,
#    's_auc_roc': 0.01388600000000001,
#    's_cll': 3.149999999998987e-05,
#    's_rec': 0.0,
#    's_prec': nan,
#    's_f1': nan}])

# %%
# final_results[f'groot_test:{source}->{target}'] = []
# final_results[f'groot_test_rev:{source}->{target}'] = []
# final_results[f'inf_res:{source}->{target}'] = []
# final_results[f'inf_res_rev:{source}->{target}'] = []

# uwcse_dataset = datasets.load('uwcse', kb_target, target=target, seed=441773)
# train_facts, train_pos, train_neg, test_facts, test_pos, test_neg = get_train_test(uwcse_dataset, 1)
# tr_train_pos = []
# tr_train_neg = []
# tr_train_facts = []

# for i in range(0, len(train_pos)):
#     tr_train_pos.extend(train_pos[i])
#     tr_train_neg.extend(train_neg[i])
#     tr_train_facts.extend(train_facts[i])

# train = [tr_train_pos, tr_train_neg, tr_train_facts]
test = [test_pos, test_neg, test_facts[0]]

individuals = get_k_best_individuals(res_cc_r[0].population, 3)

n_ind = 1
for individual in individuals:
    print("INDIVIDUO ", n_ind)
    refine, transfer = get_refine_transfer(individual, source, target, 'yago2s', 'nell_finances')
    for i in range(len(train_pos)):
        ttrain = [train_pos[i], train_neg[i][:2*len(train_pos[i])], train_facts[i]]
        res_ = test_refine_transfer(kb_target, target, refine, transfer, ttrain, test)
        print(res_)
#         final_results[f'groot_test:{source}->{target}'].append(res)
#         import os
    #     thisFile = f'boostsrl/best/test/results_{target.replace('recursion_', '')}.db'
    #     thisFile = f'boostsrl/best/test/results_{target}.db'
    #     base = os.path.splitext(thisFile)[0]
    #     os.rename(thisFile, base + ".txt")
    #     tt = open('boostsrl/best/test/results_advisedby.txt', 'r').readlines()
    #     final = []
    #     for i in tt:
    #         final.append(i.replace('\n', ''))
    #     final_results[f'inf_res:{source}->{target}'].append(final)
        print("===========================================================================")
#         break

    n_ind += 1
# Out:
# INDIVIDUO  1
# ({'AUC ROC': 0.511051, 'AUC PR': 0.001515, 'CLL': -0.369659, 'Precision': [nan, 0.5], 'Recall': 0.0, 'F1': nan}, <boostsrl.boostsrl.test object at 0x7fa98bc137b8>)
# ===========================================================================
# ({'AUC ROC': 0.479859, 'AUC PR': 0.001369, 'CLL': -0.36912, 'Precision': [nan, 0.5], 'Recall': 0.0, 'F1': nan}, <boostsrl.boostsrl.test object at 0x7fa97780a3c8>)
# ===========================================================================
# INDIVIDUO  2
# ({'AUC ROC': 0.511051, 'AUC PR': 0.001515, 'CLL': -0.369659, 'Precision': [nan, 0.5], 'Recall': 0.0, 'F1': nan}, <boostsrl.boostsrl.test object at 0x7fa97780a278>)
# ===========================================================================
# ({'AUC ROC': 0.479859, 'AUC PR': 0.001369, 'CLL': -0.36912, 'Precision': [nan, 0.5], 'Recall': 0.0, 'F1': nan}, <boostsrl.boostsrl.test object at 0x7fa98bc13518>)
# ===========================================================================
# INDIVIDUO  3
# ({'AUC ROC': 0.509384, 'AUC PR': 0.001508, 'CLL': -0.369929, 'Precision': [nan, 0.5], 'Recall': 0.0, 'F1': nan}, <boostsrl.boostsrl.test object at 0x7fa98bc0c4a8>)
# ===========================================================================
# ({'AUC ROC': 0.480959, 'AUC PR': 0.001355, 'CLL': -0.36898, 'Precision': [nan, 0.5], 'Recall': 0.0, 'F1': nan}, <boostsrl.boostsrl.test object at 0x7fa98bc13588>)
# ===========================================================================

# %%
individuals_rc = get_k_best_individuals(res_cc_r[0].population, 3)
n_i = 1
for ind in individuals_rc:
    refine, transfer = get_refine_transfer(ind, source, target, 'nell_sports', 'nell_finances')
    print("INDIVIDUO ", n_i)
    print("REFINE: ", refine)
    print("TRANSFER: ", transfer)
    print("==========================")
    n_i += 1
# Out:
# INDIVIDUO  1
# REFINE:  ['0;;teamplayssport00(A,B):- athleteplayssport01(C, B);true;false', '0;true;athleteledsportsteam02(C, D).;true;true', '0;true,true;teamplaysinleague03(A, E), teamplaysinleague04(D, E).;true;true', '0;true,true,true;athleteplaysforteam04(C, D).;false;false', '0;true,true,false;teamplaysagainstteam05(A, F), athleteplaysforteam06(G, A).;false;false', '0;true,false;teamalsoknownas06(J, D).;false;false', '1;;teamplayssport10(A,B):- athleteplayssport11(C, B), athleteplaysinleague11(D, C);true;true', '1;true;athleteledsportsteam12(C, E).;true;true', '1;true,true;teamplaysagainstteam13(F, A), teamalsoknownas14(G, F).;false;false', '1;true,false;teamplaysinleague14(H, A), athleteplaysinleague15(H, I).;true;false', '1;true,false,true;teamplaysagainstteam15(A, J).;false;false', '1;false;teamplaysinleague16(F, A), teamplaysagainstteam17(A, G).;true;true', '1;false,true;athleteledsportsteam17(C, H), teamplaysinleague18(F, H).;false;false', '1;false,false;teamplaysagainstteam18(I, A), teamplaysinleague19(I, J).;false;false', '2;;teamplayssport20(A,B):- athleteplayssport21(C, B), athleteplaysinleague21(D, C);true;true', '2;true;athleteledsportsteam22(C, D), teamalsoknownas23(D, I).;false;false', '2;false;teamalsoknownas23(K, A), teamalsoknownas24(L, K).;true;false', '2;false,true;teamplaysagainstteam24(A, L), athleteplaysforteam25(M, L).;true;true', '2;false,true,true;teamalsoknownas25(N, L).;false;false', '2;false,true,false;teamalsoknownas26(K, L).;false;false', '3;;teamplayssport30(A,B):- athleteplayssport31(B, C), athleteplaysinleague31(C, D);true;true', '3;true;athleteledsportsteam32(C, E).;true;false', '3;true,true;teamplaysinleague33(F, A), teamplaysinleague34(F, E).;false;true', '3;true,true,false;athleteplayssport34(I, J).;false;false', '3;false;teamplaysinleague35(H, A).;true;true', '3;false,true;teamalsoknownas36(I, A), athleteplaysforteam37(J, I).;false;false', '3;false,false;teamplaysagainstteam37(A, K), teamalsoknownas38(L, A).;false;true', '3;false,false,false;teamplaysagainstteam38(M, A).;false;false', '4;;teamplayssport40(A,B):- athleteplayssport41(C, B);true;false', '4;true;athleteledsportsteam42(C, D).;true;true', '4;true,true;athleteplaysforteam43(E, A), athleteledsportsteam44(E, F).;true;true', '4;true,true,true;teamplaysagainstteam44(A, D), athleteplaysforteam45(C, D).;false;false', '4;true,true,false;teamplaysagainstteam45(A, G).;false;false', '4;true,false;teamplaysinleague46(H, A), athleteplaysinleague47(I, H).;true;true', '4;true,false,true;athleteplaysforteam47(C, G), teamalsoknownas48(E, G).;false;false', '4;true,false,false;teamplaysagainstteam48(K, A).;false;false', '5;;teamplayssport50(A,B):- athleteledsportsteam51(C, A), athleteplayssport51(D, C);true;true', '5;true;athleteplayssport52(E, B), athleteledsportsteam53(E, F).;true;false', '5;true,true;teamplaysagainstteam53(A, F).;true;false', '5;true,true,true;teamalsoknownas54(G, A), teamalsoknownas55(G, F).;false;false', '5;false;athleteplayssport55(H, B).;true;false', '5;false,true;athleteplaysforteam56(H, I).;true;true', '5;false,true,true;teamplaysinleague57(J, A), athleteledsportsteam58(K, I).;false;false', '5;false,true,false;athleteplaysinleague58(L, H), teamplaysagainstteam59(M, A).;false;false', '6;;teamplayssport60(A,B):- athleteplayssport61(B, C), athleteplaysinleague61(C, D);true;true', '6;true;athleteledsportsteam62(E, A).;false;true', '6;true,false;teamplaysinleague63(K, A).;false;true', '6;true,false,false;athleteplayssport64(L, B).;false;true', '6;true,false,false,false;teamplaysagainstteam65(A, M), teamalsoknownas66(A, N).;false;false', '6;false;teamalsoknownas66(K, A), athleteplaysforteam67(L, K).;true;false', '6;false,true;teamplaysagainstteam67(M, A), teamplaysagainstteam68(M, K).;false;true', '6;false,true,false;athleteledsportsteam68(L, K).;false;false', '7;;teamplayssport70(A,B):- athleteplayssport71(C, B), athleteplaysinleague71(D, C);true;true', '7;true;teamplaysinleague72(E, A), athleteplaysinleague73(F, E).;true;false', '7;tru ...
# TRANSFER:  ['source: teamplayssport00(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport00(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport01(athlete,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplayssport01(A,B)=companyeconomicsector(A,B).', 'source: athleteledsportsteam02(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteledsportsteam02(A,B)=bankboughtbank(A,B).', 'source: teamplaysinleague03(sportsteam,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplaysinleague03(A,B)=companyeconomicsector(A,B).', 'source: teamplaysinleague04(sportsteam,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplaysinleague04(A,B)=companyeconomicsector(A,B).', 'source: athleteplaysforteam04(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteplaysforteam04(A,B)=bankboughtbank(A,B).', 'source: teamplaysagainstteam05(sportsteam,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: teamplaysagainstteam05(A,B)=bankboughtbank(A,B).', 'source: athleteplaysforteam06(athlete,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: athleteplaysforteam06(A,B)=companyalsoknownas(A,B).', 'source: teamalsoknownas06(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamalsoknownas06(A,B)=companyalsoknownas(A,B).', 'source: teamplayssport10(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport10(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport11(athlete,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplayssport11(A,B)=companyeconomicsector(A,B).', 'source: athleteplaysinleague11(athlete,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplaysinleague11(A,B)=economicsectorcompany(A,B).', 'source: athleteledsportsteam12(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteledsportsteam12(A,B)=bankboughtbank(A,B).', 'source: teamplaysagainstteam13(sportsteam,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: teamplaysagainstteam13(A,B)=bankboughtbank(A,B).', 'source: teamalsoknownas14(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamalsoknownas14(A,B)=companyalsoknownas(A,B).', 'source: teamplaysinleague14(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague14(A,B)=economicsectorcompany(A,B).', 'source: athleteplaysinleague15(athlete,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplaysinleague15(A,B)=economicsectorcompany(A,B).', 'source: teamplaysagainstteam15(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamplaysagainstteam15(A,B)=acquired(A,B).', 'source: teamplaysinleague16(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague16(A,B)=economicsectorcompany(A,B).', 'source: teamplaysagainstteam17(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamplaysagainstteam17(A,B)=acquired(A,B).', 'source: athleteledsportsteam17(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteledsportsteam17(A,B)=bankboughtbank(A,B).', 'source: teamplaysinleague18(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague18(A,B)=economicsectorcompany(A,B).', 'source: teamplaysagainstteam18(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamplaysagainstteam18(A,B)=companyalsoknownas(A,B).', 'source: teamplaysinleague19(sportsteam,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplaysinleague19(A,B)=companyeconomicsector(A,B).', 'source: teamplayssport20(sportsteam,sport).', 'target: company ...
# ==========================
# INDIVIDUO  2
# REFINE:  ['0;;teamplayssport00(A,B):- athleteplayssport01(C, B);true;false', '0;true;athleteledsportsteam02(C, D).;true;true', '0;true,true;teamplaysinleague03(A, E), teamplaysinleague04(D, E).;true;true', '0;true,true,true;athleteplaysforteam04(C, D).;false;false', '0;true,true,false;teamplaysagainstteam05(A, F), athleteplaysforteam06(G, A).;false;false', '0;true,false;teamalsoknownas06(J, D).;false;false', '1;;teamplayssport10(A,B):- athleteplayssport11(C, B), athleteplaysinleague11(D, C);true;true', '1;true;athleteledsportsteam12(C, E).;true;true', '1;true,true;teamplaysagainstteam13(F, A), teamalsoknownas14(G, F).;false;false', '1;true,false;teamplaysinleague14(H, A), athleteplaysinleague15(H, I).;true;false', '1;true,false,true;teamplaysagainstteam15(A, J).;false;false', '1;false;teamplaysinleague16(F, A), teamplaysagainstteam17(A, G).;true;true', '1;false,true;athleteledsportsteam17(C, H), teamplaysinleague18(F, H).;false;false', '1;false,false;teamplaysagainstteam18(I, A), teamplaysinleague19(I, J).;false;false', '2;;teamplayssport20(A,B):- athleteplayssport21(C, B), athleteplaysinleague21(D, C);true;true', '2;true;athleteledsportsteam22(C, D), teamalsoknownas23(D, I).;false;false', '2;false;teamalsoknownas23(K, A), teamalsoknownas24(L, K).;true;false', '2;false,true;teamplaysagainstteam24(A, L), athleteplaysforteam25(M, L).;true;true', '2;false,true,true;teamalsoknownas25(N, L).;false;false', '2;false,true,false;teamalsoknownas26(K, L).;false;false', '3;;teamplayssport30(A,B):- athleteplayssport31(B, C), athleteplaysinleague31(C, D);true;true', '3;true;athleteledsportsteam32(C, E).;true;false', '3;true,true;teamplaysinleague33(F, A), teamplaysinleague34(F, E).;false;true', '3;true,true,false;athleteplayssport34(I, J).;false;false', '3;false;teamplaysinleague35(H, A).;true;true', '3;false,true;teamalsoknownas36(I, A), athleteplaysforteam37(J, I).;false;false', '3;false,false;teamplaysagainstteam37(A, K), teamalsoknownas38(L, A).;false;true', '3;false,false,false;teamplaysagainstteam38(M, A).;false;false', '4;;teamplayssport40(A,B):- athleteplayssport41(C, B);true;false', '4;true;athleteledsportsteam42(C, D).;true;true', '4;true,true;athleteplaysforteam43(E, A), athleteledsportsteam44(E, F).;true;true', '4;true,true,true;teamplaysagainstteam44(A, D), athleteplaysforteam45(C, D).;false;false', '4;true,true,false;teamplaysagainstteam45(A, G).;false;false', '4;true,false;teamplaysinleague46(H, A), athleteplaysinleague47(I, H).;true;true', '4;true,false,true;athleteplaysforteam47(C, G), teamalsoknownas48(E, G).;false;false', '4;true,false,false;teamplaysagainstteam48(K, A).;false;false', '5;;teamplayssport50(A,B):- athleteledsportsteam51(C, A), athleteplayssport51(D, C);true;true', '5;true;athleteplayssport52(E, B), athleteledsportsteam53(E, F).;true;false', '5;true,true;teamplaysagainstteam53(A, F).;true;false', '5;true,true,true;teamalsoknownas54(G, A), teamalsoknownas55(G, F).;false;false', '5;false;athleteplayssport55(H, B).;true;false', '5;false,true;athleteplaysforteam56(H, I).;true;true', '5;false,true,true;teamplaysinleague57(J, A), athleteledsportsteam58(K, I).;false;false', '5;false,true,false;athleteplaysinleague58(L, H), teamplaysagainstteam59(M, A).;false;false', '6;;teamplayssport60(A,B):- athleteplayssport61(B, C), athleteplaysinleague61(C, D);true;true', '6;true;athleteledsportsteam62(E, A).;false;true', '6;true,false;teamplaysinleague63(K, A).;false;true', '6;true,false,false;athleteplayssport64(L, B).;false;true', '6;true,false,false,false;teamplaysagainstteam65(A, M), teamalsoknownas66(A, N).;false;false', '6;false;teamalsoknownas66(K, A), athleteplaysforteam67(L, K).;true;false', '6;false,true;teamplaysagainstteam67(M, A), teamplaysagainstteam68(M, K).;false;true', '6;false,true,false;athleteledsportsteam68(L, K).;false;false', '7;;teamplayssport70(A,B):- athleteplayssport71(C, B), athleteplaysinleague71(D, C);true;true', '7;true;teamplaysinleague72(E, A), athleteplaysinleague73(F, E).;true;false', '7;tru ...
# TRANSFER:  ['source: teamplayssport00(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport00(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport01(athlete,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplayssport01(A,B)=companyeconomicsector(A,B).', 'source: athleteledsportsteam02(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteledsportsteam02(A,B)=bankboughtbank(A,B).', 'source: teamplaysinleague03(sportsteam,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplaysinleague03(A,B)=companyeconomicsector(A,B).', 'source: teamplaysinleague04(sportsteam,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplaysinleague04(A,B)=companyeconomicsector(A,B).', 'source: athleteplaysforteam04(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteplaysforteam04(A,B)=bankboughtbank(A,B).', 'source: teamplaysagainstteam05(sportsteam,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: teamplaysagainstteam05(A,B)=bankboughtbank(A,B).', 'source: athleteplaysforteam06(athlete,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: athleteplaysforteam06(A,B)=companyalsoknownas(A,B).', 'source: teamalsoknownas06(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamalsoknownas06(A,B)=companyalsoknownas(A,B).', 'source: teamplayssport10(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport10(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport11(athlete,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplayssport11(A,B)=companyeconomicsector(A,B).', 'source: athleteplaysinleague11(athlete,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplaysinleague11(A,B)=economicsectorcompany(A,B).', 'source: athleteledsportsteam12(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteledsportsteam12(A,B)=bankboughtbank(A,B).', 'source: teamplaysagainstteam13(sportsteam,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: teamplaysagainstteam13(A,B)=bankboughtbank(A,B).', 'source: teamalsoknownas14(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamalsoknownas14(A,B)=companyalsoknownas(A,B).', 'source: teamplaysinleague14(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague14(A,B)=economicsectorcompany(A,B).', 'source: athleteplaysinleague15(athlete,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplaysinleague15(A,B)=economicsectorcompany(A,B).', 'source: teamplaysagainstteam15(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamplaysagainstteam15(A,B)=acquired(A,B).', 'source: teamplaysinleague16(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague16(A,B)=economicsectorcompany(A,B).', 'source: teamplaysagainstteam17(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamplaysagainstteam17(A,B)=acquired(A,B).', 'source: athleteledsportsteam17(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteledsportsteam17(A,B)=bankboughtbank(A,B).', 'source: teamplaysinleague18(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague18(A,B)=economicsectorcompany(A,B).', 'source: teamplaysagainstteam18(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamplaysagainstteam18(A,B)=companyalsoknownas(A,B).', 'source: teamplaysinleague19(sportsteam,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplaysinleague19(A,B)=companyeconomicsector(A,B).', 'source: teamplayssport20(sportsteam,sport).', 'target: company ...
# ==========================
# INDIVIDUO  3
# REFINE:  ['0;;teamplayssport00(A,B):- athleteplayssport01(C, B);true;false', '0;true;athleteledsportsteam02(C, D).;true;true', '0;true,true;teamplaysinleague03(E, A), teamplaysinleague04(D, E).;true;true', '0;true,true,true;athleteplaysforteam04(C, D).;false;false', '0;true,true,false;teamplaysagainstteam05(A, F), athleteplaysforteam06(G, A).;false;false', '0;true,false;teamalsoknownas06(J, D).;false;false', '1;;teamplayssport10(A,B):- athleteplayssport11(B, C), athleteplaysinleague11(C, D);true;true', '1;true;athleteledsportsteam12(C, E).;true;true', '1;true,true;teamplaysagainstteam13(F, A), teamalsoknownas14(G, F).;false;false', '1;true,false;teamplaysinleague14(A, H), athleteplaysinleague15(H, I).;true;false', '1;true,false,true;teamplaysagainstteam15(A, J).;false;false', '1;false;teamplaysinleague16(A, F), teamplaysagainstteam17(A, G).;true;true', '1;false,true;athleteledsportsteam17(C, H), teamplaysinleague18(F, H).;false;false', '1;false,false;teamplaysagainstteam18(I, A), teamplaysinleague19(I, J).;false;false', '2;;teamplayssport20(A,B):- athleteplayssport21(C, B), athleteplaysinleague21(D, C);true;true', '2;true;teamplaysagainstteam22(E, A), teamplaysinleague23(A, F).;false;true', '2;true,false;teamalsoknownas23(G, A), teamplaysinleague24(A, H).;false;true', '2;true,false,false;teamalsoknownas24(G, A), teamplaysinleague25(H, A).;false;true', '2;true,false,false,false;athleteledsportsteam25(C, I), teamplaysagainstteam26(A, J).;false;false', '2;false;teamalsoknownas26(K, A), teamalsoknownas27(L, K).;true;false', '2;false,true;teamplaysagainstteam27(A, L), athleteplaysforteam28(M, L).;true;true', '2;false,true,true;teamalsoknownas28(N, L).;false;false', '2;false,true,false;teamalsoknownas29(K, L).;false;false', '3;;teamplayssport30(A,B):- athleteplayssport31(C, B), athleteplaysinleague31(C, D);true;true', '3;true;athleteledsportsteam32(C, E).;true;false', '3;true,true;teamplaysinleague33(J, A), athleteledsportsteam34(K, I).;false;false', '3;false;teamplaysinleague34(H, A).;true;true', '3;false,true;teamalsoknownas35(I, A), athleteplaysforteam36(J, I).;false;false', '3;false,false;teamplaysagainstteam36(A, K), teamalsoknownas37(L, A).;false;true', '3;false,false,false;teamplaysagainstteam37(M, A).;false;false', '4;;teamplayssport40(A,B):- athleteplayssport41(C, B);true;false', '4;true;athleteledsportsteam42(C, D).;true;true', '4;true,true;athleteplaysforteam43(E, A), athleteledsportsteam44(E, F).;true;true', '4;true,true,true;teamplaysagainstteam44(A, D), athleteplaysforteam45(C, D).;false;false', '4;true,true,false;teamplaysagainstteam45(A, G).;false;false', '4;true,false;teamplaysinleague46(A, H), athleteplaysinleague47(I, H).;true;true', '4;true,false,true;athleteplaysforteam47(C, G), teamalsoknownas48(E, G).;false;false', '4;true,false,false;teamplaysagainstteam48(K, A).;false;false', '5;;teamplayssport50(A,B):- athleteledsportsteam51(C, A), athleteplayssport51(D, C);true;true', '5;true;athleteplayssport52(E, B), athleteledsportsteam53(E, F).;true;false', '5;true,true;teamplaysagainstteam53(A, F).;true;false', '5;true,true,true;teamalsoknownas54(G, A), teamalsoknownas55(G, F).;false;false', '5;false;athleteplayssport55(H, B).;true;false', '5;false,true;athleteplaysforteam56(H, I).;true;true', '5;false,true,true;teamplaysinleague57(A, F), teamplaysinleague58(F, E).;false;true', '5;false,true,true,false;athleteplayssport58(I, J).;false;false', '5;false,true,false;athleteplaysinleague59(L, H), teamplaysagainstteam510(M, A).;false;false', '6;;teamplayssport60(A,B):- athleteplayssport61(C, B), athleteplaysinleague61(D, C);true;true', '6;true;athleteledsportsteam62(E, A).;false;true', '6;true,false;teamplaysinleague63(K, A).;false;true', '6;true,false,false;athleteplayssport64(L, B).;false;true', '6;true,false,false,false;teamplaysagainstteam65(A, M), teamalsoknownas66(A, N).;false;false', '6;false;teamalsoknownas66(K, A), athleteplaysforteam67(L, K).;true;false', '6;false,true;teamplaysagainstteam67(M, A), teamplaysagains ...
# TRANSFER:  ['source: teamplayssport00(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport00(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport01(athlete,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplayssport01(A,B)=companyeconomicsector(A,B).', 'source: athleteledsportsteam02(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteledsportsteam02(A,B)=bankboughtbank(A,B).', 'source: teamplaysinleague03(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague03(A,B)=economicsectorcompany(A,B).', 'source: teamplaysinleague04(sportsteam,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplaysinleague04(A,B)=companyeconomicsector(A,B).', 'source: athleteplaysforteam04(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteplaysforteam04(A,B)=bankboughtbank(A,B).', 'source: teamplaysagainstteam05(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamplaysagainstteam05(A,B)=acquired(A,B).', 'source: athleteplaysforteam06(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteplaysforteam06(A,B)=bankboughtbank(A,B).', 'source: teamalsoknownas06(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamalsoknownas06(A,B)=companyalsoknownas(A,B).', 'source: teamplayssport10(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport10(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport11(athlete,sport).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplayssport11(A,B)=economicsectorcompany(A,B).', 'source: athleteplaysinleague11(athlete,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplaysinleague11(A,B)=companyeconomicsector(A,B).', 'source: athleteledsportsteam12(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteledsportsteam12(A,B)=bankboughtbank(A,B).', 'source: teamplaysagainstteam13(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamplaysagainstteam13(A,B)=companyalsoknownas(A,B).', 'source: teamalsoknownas14(sportsteam,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: teamalsoknownas14(A,B)=bankboughtbank(A,B).', 'source: teamplaysinleague14(sportsteam,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplaysinleague14(A,B)=companyeconomicsector(A,B).', 'source: athleteplaysinleague15(athlete,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplaysinleague15(A,B)=economicsectorcompany(A,B).', 'source: teamplaysagainstteam15(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamplaysagainstteam15(A,B)=acquired(A,B).', 'source: teamplaysinleague16(sportsteam,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplaysinleague16(A,B)=companyeconomicsector(A,B).', 'source: teamplaysagainstteam17(sportsteam,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: teamplaysagainstteam17(A,B)=bankboughtbank(A,B).', 'source: athleteledsportsteam17(athlete,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: athleteledsportsteam17(A,B)=companyalsoknownas(A,B).', 'source: teamplaysinleague18(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague18(A,B)=economicsectorcompany(A,B).', 'source: teamplaysagainstteam18(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamplaysagainstteam18(A,B)=acquired(A,B).', 'source: teamplaysinleague19(sportsteam,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplaysinleague19(A,B)=companyeconomicsector(A,B).', 'source: teamplayssport20(sportsteam,sport).', 'target: companyeconomicsector(compa ...
# ==========================

# %% [markdown]
# ## aleatório

# %%
start = time.time()
res_cc_a = genetic(new_src_struct, target, source, train_pos, 
                                         train_neg, train_facts, kb_source, kb_target, pred_target,
                                          NUM_GEN=14, pop_size=30, crossover_type='tree', revision='random')
print("FIM DO GROOT GENETIC: ", time.time()-start)
# Out:
# GENERATION:  0
# MELHOR RESULTADO:  -0.28104357955039644
# entrei aqui
# BEST: {'m_auc_pr': 0.052082500000000004, 'm_auc_roc': 0.9627870000000001, 'm_cll': -0.2761755, 'm_rec': 0.408088, 'm_pred': 0.29343549999999996, 'm_f1': 0.1432125, 's_auc_pr': 0.001691500000000002, 's_auc_roc': 0.0006759999999999544, 's_cll': 0.0003304999999999836, 's_rec': 0.007352999999999998, 's_prec': 0.20656951689019848, 's_f1': 0.002314499999999997}
# GENERATION:  1
# MELHOR RESULTADO:  -0.5031515538085914
# entrei aqui
# BEST: {'m_auc_pr': 0.464228, 'm_auc_roc': 0.9855659999999999, 'm_cll': -0.194046, 'm_rec': 0.8878675, 'm_pred': 0.26333249999999997, 'm_f1': 0.0517735, 's_auc_pr': 0.014638000000000012, 's_auc_roc': 0.0007689999999999642, 's_cll': 0.002582000000000001, 's_rec': 0.0018385000000000207, 's_prec': 0.2366684877645311, 's_f1': 0.0018255000000000007}
# GENERATION:  2
# MELHOR RESULTADO:  -0.5031515538085914
# entrei aqui
# BEST: {'m_auc_pr': 0.464228, 'm_auc_roc': 0.9855659999999999, 'm_cll': -0.194046, 'm_rec': 0.8878675, 'm_pred': 0.26333249999999997, 'm_f1': 0.0517735, 's_auc_pr': 0.014638000000000012, 's_auc_roc': 0.0007689999999999642, 's_cll': 0.002582000000000001, 's_rec': 0.0018385000000000207, 's_prec': 0.2366684877645311, 's_f1': 0.0018255000000000007}
# GENERATION:  3
# MELHOR RESULTADO:  -0.5031515538085914
# entrei aqui
# BEST: {'m_auc_pr': 0.464228, 'm_auc_roc': 0.9855659999999999, 'm_cll': -0.194046, 'm_rec': 0.8878675, 'm_pred': 0.26333249999999997, 'm_f1': 0.0517735, 's_auc_pr': 0.014638000000000012, 's_auc_roc': 0.0007689999999999642, 's_cll': 0.002582000000000001, 's_rec': 0.0018385000000000207, 's_prec': 0.2366684877645311, 's_f1': 0.0018255000000000007}
# GENERATION:  4
# MELHOR RESULTADO:  -0.5031515538085914
# entrei aqui
# BEST: {'m_auc_pr': 0.464228, 'm_auc_roc': 0.9855659999999999, 'm_cll': -0.194046, 'm_rec': 0.8878675, 'm_pred': 0.26333249999999997, 'm_f1': 0.0517735, 's_auc_pr': 0.014638000000000012, 's_auc_roc': 0.0007689999999999642, 's_cll': 0.002582000000000001, 's_rec': 0.0018385000000000207, 's_prec': 0.2366684877645311, 's_f1': 0.0018255000000000007}
# GENERATION:  5
# MELHOR RESULTADO:  -0.5031515538085914
# entrei aqui
# BEST: {'m_auc_pr': 0.464228, 'm_auc_roc': 0.9855659999999999, 'm_cll': -0.194046, 'm_rec': 0.8878675, 'm_pred': 0.26333249999999997, 'm_f1': 0.0517735, 's_auc_pr': 0.014638000000000012, 's_auc_roc': 0.0007689999999999642, 's_cll': 0.002582000000000001, 's_rec': 0.0018385000000000207, 's_prec': 0.2366684877645311, 's_f1': 0.0018255000000000007}
# GENERATION:  6
# MELHOR RESULTADO:  -0.5031515538085914
# entrei aqui
# BEST: {'m_auc_pr': 0.464228, 'm_auc_roc': 0.9855659999999999, 'm_cll': -0.194046, 'm_rec': 0.8878675, 'm_pred': 0.26333249999999997, 'm_f1': 0.0517735, 's_auc_pr': 0.014638000000000012, 's_auc_roc': 0.0007689999999999642, 's_cll': 0.002582000000000001, 's_rec': 0.0018385000000000207, 's_prec': 0.2366684877645311, 's_f1': 0.0018255000000000007}
# GENERATION:  7
# MELHOR RESULTADO:  -0.5031515538085914
# entrei aqui
# BEST: {'m_auc_pr': 0.464228, 'm_auc_roc': 0.9855659999999999, 'm_cll': -0.194046, 'm_rec': 0.8878675, 'm_pred': 0.26333249999999997, 'm_f1': 0.0517735, 's_auc_pr': 0.014638000000000012, 's_auc_roc': 0.0007689999999999642, 's_cll': 0.002582000000000001, 's_rec': 0.0018385000000000207, 's_prec': 0.2366684877645311, 's_f1': 0.0018255000000000007}
# GENERATION:  8
# MELHOR RESULTADO:  -0.5031515538085914
# entrei aqui
# BEST: {'m_auc_pr': 0.464228, 'm_auc_roc': 0.9855659999999999, 'm_cll': -0.194046, 'm_rec': 0.8878675, 'm_pred': 0.26333249999999997, 'm_f1': 0.0517735, 's_auc_pr': 0.014638000000000012, 's_auc_roc': 0.0007689999999999642, 's_cll': 0.002582000000000001, 's_rec': 0.0018385000000000207, 's_prec': 0.2366684877645311, 's_f1': 0.0018255000000000007}
# GENERATION:  9
# MELHOR RESULTADO:  -0.5031515538085914
# FIM DO GROOT GENETIC:  6215.289084196091

# %%
res_cc_a
# Out:
# (<src.s_genetic.population.Population at 0x7fa97bc39ba8>,
#  [-0.28104357955039644,
#   -0.5031515538085914,
#   -0.5031515538085914,
#   -0.5031515538085914,
#   -0.5031515538085914,
#   -0.5031515538085914,
#   -0.5031515538085914,
#   -0.5031515538085914,
#   -0.5031515538085914,
#   -0.5031515538085914],
#  [{'m_auc_pr': 0.052082500000000004,
#    'm_auc_roc': 0.9627870000000001,
#    'm_cll': -0.2761755,
#    'm_rec': 0.408088,
#    'm_pred': 0.29343549999999996,
#    'm_f1': 0.1432125,
#    's_auc_pr': 0.001691500000000002,
#    's_auc_roc': 0.0006759999999999544,
#    's_cll': 0.0003304999999999836,
#    's_rec': 0.007352999999999998,
#    's_prec': 0.20656951689019848,
#    's_f1': 0.002314499999999997},
#   {'m_auc_pr': 0.464228,
#    'm_auc_roc': 0.9855659999999999,
#    'm_cll': -0.194046,
#    'm_rec': 0.8878675,
#    'm_pred': 0.26333249999999997,
#    'm_f1': 0.0517735,
#    's_auc_pr': 0.014638000000000012,
#    's_auc_roc': 0.0007689999999999642,
#    's_cll': 0.002582000000000001,
#    's_rec': 0.0018385000000000207,
#    's_prec': 0.2366684877645311,
#    's_f1': 0.0018255000000000007},
#   {'m_auc_pr': 0.464228,
#    'm_auc_roc': 0.9855659999999999,
#    'm_cll': -0.194046,
#    'm_rec': 0.8878675,
#    'm_pred': 0.26333249999999997,
#    'm_f1': 0.0517735,
#    's_auc_pr': 0.014638000000000012,
#    's_auc_roc': 0.0007689999999999642,
#    's_cll': 0.002582000000000001,
#    's_rec': 0.0018385000000000207,
#    's_prec': 0.2366684877645311,
#    's_f1': 0.0018255000000000007},
#   {'m_auc_pr': 0.464228,
#    'm_auc_roc': 0.9855659999999999,
#    'm_cll': -0.194046,
#    'm_rec': 0.8878675,
#    'm_pred': 0.26333249999999997,
#    'm_f1': 0.0517735,
#    's_auc_pr': 0.014638000000000012,
#    's_auc_roc': 0.0007689999999999642,
#    's_cll': 0.002582000000000001,
#    's_rec': 0.0018385000000000207,
#    's_prec': 0.2366684877645311,
#    's_f1': 0.0018255000000000007},
#   {'m_auc_pr': 0.464228,
#    'm_auc_roc': 0.9855659999999999,
#    'm_cll': -0.194046,
#    'm_rec': 0.8878675,
#    'm_pred': 0.26333249999999997,
#    'm_f1': 0.0517735,
#    's_auc_pr': 0.014638000000000012,
#    's_auc_roc': 0.0007689999999999642,
#    's_cll': 0.002582000000000001,
#    's_rec': 0.0018385000000000207,
#    's_prec': 0.2366684877645311,
#    's_f1': 0.0018255000000000007},
#   {'m_auc_pr': 0.464228,
#    'm_auc_roc': 0.9855659999999999,
#    'm_cll': -0.194046,
#    'm_rec': 0.8878675,
#    'm_pred': 0.26333249999999997,
#    'm_f1': 0.0517735,
#    's_auc_pr': 0.014638000000000012,
#    's_auc_roc': 0.0007689999999999642,
#    's_cll': 0.002582000000000001,
#    's_rec': 0.0018385000000000207,
#    's_prec': 0.2366684877645311,
#    's_f1': 0.0018255000000000007},
#   {'m_auc_pr': 0.464228,
#    'm_auc_roc': 0.9855659999999999,
#    'm_cll': -0.194046,
#    'm_rec': 0.8878675,
#    'm_pred': 0.26333249999999997,
#    'm_f1': 0.0517735,
#    's_auc_pr': 0.014638000000000012,
#    's_auc_roc': 0.0007689999999999642,
#    's_cll': 0.002582000000000001,
#    's_rec': 0.0018385000000000207,
#    's_prec': 0.2366684877645311,
#    's_f1': 0.0018255000000000007},
#   {'m_auc_pr': 0.464228,
#    'm_auc_roc': 0.9855659999999999,
#    'm_cll': -0.194046,
#    'm_rec': 0.8878675,
#    'm_pred': 0.26333249999999997,
#    'm_f1': 0.0517735,
#    's_auc_pr': 0.014638000000000012,
#    's_auc_roc': 0.0007689999999999642,
#    's_cll': 0.002582000000000001,
#    's_rec': 0.0018385000000000207,
#    's_prec': 0.2366684877645311,
#    's_f1': 0.0018255000000000007},
#   {'m_auc_pr': 0.464228,
#    'm_auc_roc': 0.9855659999999999,
#    'm_cll': -0.194046,
#    'm_rec': 0.8878675,
#    'm_pred': 0.26333249999999997,
#    'm_f1': 0.0517735,
#    's_auc_pr': 0.014638000000000012,
#    's_auc_roc': 0.0007689999999999642,
#    's_cll': 0.002582000000000001,
#    's_rec': 0.0018385000000000207,
#    's_prec': 0.2366684877645311,
#    's_f1': 0.0018255000000000007}])

# %%
# final_results[f'groot_test:{source}->{target}'] = []
# final_results[f'groot_test_rev:{source}->{target}'] = []
# final_results[f'inf_res:{source}->{target}'] = []
# final_results[f'inf_res_rev:{source}->{target}'] = []

# uwcse_dataset = datasets.load('uwcse', kb_target, target=target, seed=441773)
# train_facts, train_pos, train_neg, test_facts, test_pos, test_neg = get_train_test(uwcse_dataset, 1)
# tr_train_pos = []
# tr_train_neg = []
# tr_train_facts = []

# for i in range(0, len(train_pos)):
#     tr_train_pos.extend(train_pos[i])
#     tr_train_neg.extend(train_neg[i])
#     tr_train_facts.extend(train_facts[i])

# train = [tr_train_pos, tr_train_neg, tr_train_facts]
test = [test_pos, test_neg, test_facts[0]]

individuals = get_k_best_individuals(res_cc_a[0].population, 3)

n_ind = 1
for individual in individuals:
    print("INDIVIDUO ", n_ind)
    refine, transfer = get_refine_transfer(individual, source, target, 'yago2s', 'nell_finances')
    for i in range(len(train_pos)):
        ttrain = [train_pos[i], train_neg[i][:2*len(train_pos[i])], train_facts[i]]
        res_ = test_refine_transfer(kb_target, target, refine, transfer, ttrain, test)
        print(res_)
#         final_results[f'groot_test:{source}->{target}'].append(res)
#         import os
    #     thisFile = f'boostsrl/best/test/results_{target.replace('recursion_', '')}.db'
    #     thisFile = f'boostsrl/best/test/results_{target}.db'
    #     base = os.path.splitext(thisFile)[0]
    #     os.rename(thisFile, base + ".txt")
    #     tt = open('boostsrl/best/test/results_advisedby.txt', 'r').readlines()
    #     final = []
    #     for i in tt:
    #         final.append(i.replace('\n', ''))
    #     final_results[f'inf_res:{source}->{target}'].append(final)
        print("===========================================================================")
#         break

    n_ind += 1
# Out:
# INDIVIDUO  1
# ({'AUC ROC': 0.985545, 'AUC PR': 0.440511, 'CLL': -0.191139, 'Precision': [0.028422, 0.5], 'Recall': 0.884615, 'F1': 0.055075}, <boostsrl.boostsrl.test object at 0x7fa9776ef860>)
# ===========================================================================
# ({'AUC ROC': 0.985274, 'AUC PR': 0.438807, 'CLL': -0.190552, 'Precision': [0.032136, 0.5], 'Recall': 0.871795, 'F1': 0.061987}, <boostsrl.boostsrl.test object at 0x7fa9776efef0>)
# ===========================================================================
# INDIVIDUO  2
# ({'AUC ROC': 0.985545, 'AUC PR': 0.440511, 'CLL': -0.191139, 'Precision': [0.028422, 0.5], 'Recall': 0.884615, 'F1': 0.055075}, <boostsrl.boostsrl.test object at 0x7fa9db5d7208>)
# ===========================================================================
# ({'AUC ROC': 0.985274, 'AUC PR': 0.438807, 'CLL': -0.190552, 'Precision': [0.032136, 0.5], 'Recall': 0.871795, 'F1': 0.061987}, <boostsrl.boostsrl.test object at 0x7fa9776ef320>)
# ===========================================================================
# INDIVIDUO  3
# ({'AUC ROC': 0.985545, 'AUC PR': 0.440511, 'CLL': -0.191139, 'Precision': [0.028422, 0.5], 'Recall': 0.884615, 'F1': 0.055075}, <boostsrl.boostsrl.test object at 0x7fa9db5d7208>)
# ===========================================================================
# ({'AUC ROC': 0.985274, 'AUC PR': 0.438807, 'CLL': -0.190552, 'Precision': [0.032136, 0.5], 'Recall': 0.871795, 'F1': 0.061987}, <boostsrl.boostsrl.test object at 0x7fa9776ef8d0>)
# ===========================================================================

# %%
individuals_rc = get_k_best_individuals(res_cc_a[0].population, 3)
n_i = 1
for ind in individuals_rc:
    refine, transfer = get_refine_transfer(ind, source, target, 'nell_sports', 'nell_finances')
    print("INDIVIDUO ", n_i)
    print("REFINE: ", refine)
    print("TRANSFER: ", transfer)
    print("==========================")
    n_i += 1
# Out:
# INDIVIDUO  1
# REFINE:  ['0;;teamplayssport00(A,B):- athleteplayssport01(B, C);true;false', '0;true;athleteledsportsteam02(C, D).;true;true', '0;true,true;teamplaysinleague03(E, A), teamplaysinleague04(E, D).;true;false', '0;true,true,true;athleteplaysforteam04(C, D).;false;false', '0;true,false;teamplaysagainstteam05(H, A), athleteplaysinleague06(C, I).;true;true', '0;true,false,true;athleteplaysforteam06(J, H), athleteplaysinleague07(J, I).;false;false', '0;true,false,false;teamalsoknownas07(K, A).;false;false', '1;;teamplayssport10(A,B):- athleteplayssport11(B, C), athleteplaysinleague11(C, D);true;true', '1;true;athleteledsportsteam12(C, E).;true;true', '1;true,true;teamplaysagainstteam13(F, A), teamalsoknownas14(G, F).;false;true', '1;true,true,false;economicsectorcompanytarget14(W, E).;false;false', '1;true,false;teamplaysinleague15(A, H), athleteplaysinleague16(I, H).;true;false', '1;true,false,true;teamplaysagainstteam16(A, F).;true;false', '1;true,false,true,true;teamalsoknownas17(G, A), teamalsoknownas18(G, F).;false;false', '1;false;teamplaysinleague18(K, A).;false;true', '1;false,false;athleteplayssport19(B, L).;false;true', '1;false,false,false;teamplaysagainstteam110(A, M), teamalsoknownas111(A, N).;false;false', '2;;teamplayssport20(A,B):- athleteplayssport21(B, C), athleteplaysinleague21(C, D);true;true', '2;true;teamplaysagainstteam22(E, A), teamplaysinleague23(A, F).;false;true', '2;true,false;teamalsoknownas23(G, A), teamplaysinleague24(H, A).;false;true', '2;true,false,false;athleteledsportsteam24(C, I), teamplaysagainstteam25(A, J).;false;false', '2;false;teamalsoknownas25(K, A), teamalsoknownas26(L, K).;true;true', '2;false,false;bankchiefexecutiveceotarget26(P, J).;false;false', '2;false,true;teamplaysagainstteam27(A, L), athleteplaysforteam28(M, L).;true;true', '2;false,true,true;teamalsoknownas28(N, L).;false;false', '2;false,true,false;teamalsoknownas29(K, L).;false;false', '3;;teamplayssport30(A,B):- athleteplayssport31(C, B), athleteplaysinleague31(C, D);true;true', '3;true;athleteledsportsteam32(C, E).;false;false', '3;false;teamplaysinleague33(A, H).;true;true', '3;false,true;teamalsoknownas34(I, A), athleteplaysforteam35(J, I).;false;false', '3;false,false;teamplaysagainstteam35(A, K), teamalsoknownas36(L, A).;false;true', '3;false,false,false;teamplaysagainstteam36(M, A).;false;false', '4;;teamplayssport40(A,B):- athleteplayssport41(B, C);true;false', '4;true;athleteledsportsteam42(C, D).;true;true', '4;true,true;athleteplaysforteam43(E, A), athleteledsportsteam44(E, F).;true;true', '4;true,true,true;teamplaysagainstteam44(A, D), athleteplaysforteam45(C, D).;false;true', '4;true,true,true,false;cityhascompanyofficetarget45(B, H), cityhascompanyofficetarget46(K, B).;false;false', '4;true,true,false;teamplaysagainstteam46(A, G).;false;false', '4;true,false;teamplaysinleague47(H, A), athleteplaysinleague48(H, I).;true;true', '4;true,false,true;athleteplayssport48(J, I).;false;false', '4;true,false,false;teamplaysagainstteam49(K, A).;false;false', '5;;teamplayssport50(A,B):- athleteledsportsteam51(C, A), athleteplayssport51(D, C);true;true', '5;true;athleteplayssport52(E, B), athleteledsportsteam53(E, F).;true;true', '5;true,false;companyeconomicsectortarget53(C, E), bankboughtbanktarget54(F, Y).;false;false', '5;true,true;teamplaysagainstteam54(A, J).;false;false', '5;false;athleteplayssport55(B, H).;true;false', '5;false,true;athleteplaysforteam56(H, I).;true;true', '5;false,true,true;teamplaysinleague57(J, A), athleteledsportsteam58(K, I).;false;false', '5;false,true,false;athleteplaysinleague58(H, L), teamplaysagainstteam59(M, A).;false;false', '6;;teamplayssport60(A,B):- athleteplayssport61(C, B), athleteplaysinleague61(C, D);true;true', '6;true;athleteledsportsteam62(E, A).;false;true', '6;true,false;teamplaysinleague63(F, A), teamplaysagainstteam64(A, G).;true;true', '6;true,false,true;athleteledsportsteam64(C, H), teamplaysinleague65(H, F).;false;false', '6;true,false,false;teamplaysagainstteam65(I, A), te ...
# TRANSFER:  ['source: teamplayssport00(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport00(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport01(athlete,sport).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplayssport01(A,B)=economicsectorcompany(A,B).', 'source: athleteledsportsteam02(athlete,sportsteam).', 'target: acquired(company,company).', 'setMap: athleteledsportsteam02(A,B)=acquired(A,B).', 'source: teamplaysinleague03(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague03(A,B)=economicsectorcompany(A,B).', 'source: teamplaysinleague04(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague04(A,B)=economicsectorcompany(A,B).', 'source: athleteplaysforteam04(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteplaysforteam04(A,B)=bankboughtbank(A,B).', 'source: teamplaysagainstteam05(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamplaysagainstteam05(A,B)=acquired(A,B).', 'source: athleteplaysinleague06(athlete,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplaysinleague06(A,B)=companyeconomicsector(A,B).', 'source: athleteplaysforteam06(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteplaysforteam06(A,B)=bankboughtbank(A,B).', 'source: athleteplaysinleague07(athlete,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplaysinleague07(A,B)=companyeconomicsector(A,B).', 'source: teamalsoknownas07(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamalsoknownas07(A,B)=acquired(A,B).', 'source: teamplayssport10(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport10(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport11(athlete,sport).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplayssport11(A,B)=economicsectorcompany(A,B).', 'source: athleteplaysinleague11(athlete,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplaysinleague11(A,B)=companyeconomicsector(A,B).', 'source: athleteledsportsteam12(athlete,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: athleteledsportsteam12(A,B)=companyalsoknownas(A,B).', 'source: teamplaysagainstteam13(sportsteam,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: teamplaysagainstteam13(A,B)=bankboughtbank(A,B).', 'source: teamalsoknownas14(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamalsoknownas14(A,B)=acquired(A,B).', 'source: economicsectorcompanytarget14(economicsectorcompanytype1,economicsectorcompanytype2).', 'target: economicsectorcompany(sector,company).', 'setMap: economicsectorcompanytarget14(A,B)=economicsectorcompany(A,B).', 'source: teamplaysinleague15(sportsteam,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplaysinleague15(A,B)=companyeconomicsector(A,B).', 'source: athleteplaysinleague16(athlete,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplaysinleague16(A,B)=companyeconomicsector(A,B).', 'source: teamplaysagainstteam16(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamplaysagainstteam16(A,B)=companyalsoknownas(A,B).', 'source: teamalsoknownas17(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamalsoknownas17(A,B)=acquired(A,B).', 'source: teamalsoknownas18(sportsteam,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: teamalsoknownas18(A,B)=bankboughtbank(A,B).', 'source: teamplaysinleague18(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague18(A,B)=economicsectorcompany(A,B).', 'source: athleteplayssport19(athlete,sport).', 'target: economicsec ...
# ==========================
# INDIVIDUO  2
# REFINE:  ['0;;teamplayssport00(A,B):- athleteplayssport01(B, C);true;false', '0;true;athleteledsportsteam02(C, D).;true;true', '0;true,true;teamplaysinleague03(E, A), teamplaysinleague04(E, D).;true;false', '0;true,true,true;athleteplaysforteam04(C, D).;false;false', '0;true,false;teamplaysagainstteam05(H, A), athleteplaysinleague06(C, I).;true;true', '0;true,false,true;athleteplaysforteam06(J, H), athleteplaysinleague07(J, I).;false;false', '0;true,false,false;teamalsoknownas07(K, A).;false;false', '1;;teamplayssport10(A,B):- athleteplayssport11(B, C), athleteplaysinleague11(C, D);true;true', '1;true;athleteledsportsteam12(C, E).;true;true', '1;true,true;teamplaysagainstteam13(F, A), teamalsoknownas14(G, F).;false;true', '1;true,true,false;economicsectorcompanytarget14(W, E).;false;false', '1;true,false;teamplaysinleague15(A, H), athleteplaysinleague16(I, H).;true;false', '1;true,false,true;teamplaysagainstteam16(A, F).;true;false', '1;true,false,true,true;teamalsoknownas17(G, A), teamalsoknownas18(G, F).;false;false', '1;false;teamplaysinleague18(K, A).;false;true', '1;false,false;athleteplayssport19(B, L).;false;true', '1;false,false,false;teamplaysagainstteam110(A, M), teamalsoknownas111(A, N).;false;false', '2;;teamplayssport20(A,B):- athleteplayssport21(B, C), athleteplaysinleague21(C, D);true;true', '2;true;teamplaysagainstteam22(E, A), teamplaysinleague23(A, F).;false;true', '2;true,false;teamalsoknownas23(G, A), teamplaysinleague24(H, A).;false;true', '2;true,false,false;athleteledsportsteam24(C, I), teamplaysagainstteam25(A, J).;false;false', '2;false;teamalsoknownas25(K, A), teamalsoknownas26(L, K).;true;true', '2;false,false;bankchiefexecutiveceotarget26(P, J).;false;false', '2;false,true;teamplaysagainstteam27(A, L), athleteplaysforteam28(M, L).;true;true', '2;false,true,true;teamalsoknownas28(N, L).;false;false', '2;false,true,false;teamalsoknownas29(K, L).;false;false', '3;;teamplayssport30(A,B):- athleteplayssport31(C, B), athleteplaysinleague31(C, D);true;true', '3;true;athleteledsportsteam32(C, E).;false;false', '3;false;teamplaysinleague33(A, H).;true;true', '3;false,true;teamalsoknownas34(I, A), athleteplaysforteam35(J, I).;false;false', '3;false,false;teamplaysagainstteam35(A, K), teamalsoknownas36(L, A).;false;true', '3;false,false,false;teamplaysagainstteam36(M, A).;false;false', '4;;teamplayssport40(A,B):- athleteplayssport41(B, C);true;false', '4;true;athleteledsportsteam42(C, D).;true;true', '4;true,true;athleteplaysforteam43(E, A), athleteledsportsteam44(E, F).;true;true', '4;true,true,true;teamplaysagainstteam44(A, D), athleteplaysforteam45(C, D).;false;true', '4;true,true,true,false;cityhascompanyofficetarget45(B, H), cityhascompanyofficetarget46(K, B).;false;false', '4;true,true,false;teamplaysagainstteam46(A, G).;false;false', '4;true,false;teamplaysinleague47(H, A), athleteplaysinleague48(H, I).;true;true', '4;true,false,true;athleteplayssport48(J, I).;false;false', '4;true,false,false;teamplaysagainstteam49(K, A).;false;false', '5;;teamplayssport50(A,B):- athleteledsportsteam51(C, A), athleteplayssport51(D, C);true;true', '5;true;athleteplayssport52(E, B), athleteledsportsteam53(E, F).;true;true', '5;true,false;companyeconomicsectortarget53(C, E), bankboughtbanktarget54(F, Y).;false;false', '5;true,true;teamplaysagainstteam54(A, J).;false;false', '5;false;athleteplayssport55(B, H).;true;false', '5;false,true;athleteplaysforteam56(H, I).;true;true', '5;false,true,true;teamplaysinleague57(J, A), athleteledsportsteam58(K, I).;false;false', '5;false,true,false;athleteplaysinleague58(H, L), teamplaysagainstteam59(M, A).;false;false', '6;;teamplayssport60(A,B):- athleteplayssport61(C, B), athleteplaysinleague61(C, D);true;true', '6;true;athleteledsportsteam62(E, A).;false;true', '6;true,false;teamplaysinleague63(F, A), teamplaysagainstteam64(A, G).;true;true', '6;true,false,true;athleteledsportsteam64(C, H), teamplaysinleague65(H, F).;false;false', '6;true,false,false;teamplaysagainstteam65(I, A), te ...
# TRANSFER:  ['source: teamplayssport00(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport00(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport01(athlete,sport).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplayssport01(A,B)=economicsectorcompany(A,B).', 'source: athleteledsportsteam02(athlete,sportsteam).', 'target: acquired(company,company).', 'setMap: athleteledsportsteam02(A,B)=acquired(A,B).', 'source: teamplaysinleague03(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague03(A,B)=economicsectorcompany(A,B).', 'source: teamplaysinleague04(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague04(A,B)=economicsectorcompany(A,B).', 'source: athleteplaysforteam04(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteplaysforteam04(A,B)=bankboughtbank(A,B).', 'source: teamplaysagainstteam05(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamplaysagainstteam05(A,B)=acquired(A,B).', 'source: athleteplaysinleague06(athlete,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplaysinleague06(A,B)=companyeconomicsector(A,B).', 'source: athleteplaysforteam06(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteplaysforteam06(A,B)=bankboughtbank(A,B).', 'source: athleteplaysinleague07(athlete,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplaysinleague07(A,B)=companyeconomicsector(A,B).', 'source: teamalsoknownas07(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamalsoknownas07(A,B)=acquired(A,B).', 'source: teamplayssport10(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport10(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport11(athlete,sport).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplayssport11(A,B)=economicsectorcompany(A,B).', 'source: athleteplaysinleague11(athlete,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplaysinleague11(A,B)=companyeconomicsector(A,B).', 'source: athleteledsportsteam12(athlete,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: athleteledsportsteam12(A,B)=companyalsoknownas(A,B).', 'source: teamplaysagainstteam13(sportsteam,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: teamplaysagainstteam13(A,B)=bankboughtbank(A,B).', 'source: teamalsoknownas14(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamalsoknownas14(A,B)=acquired(A,B).', 'source: economicsectorcompanytarget14(economicsectorcompanytype1,economicsectorcompanytype2).', 'target: economicsectorcompany(sector,company).', 'setMap: economicsectorcompanytarget14(A,B)=economicsectorcompany(A,B).', 'source: teamplaysinleague15(sportsteam,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplaysinleague15(A,B)=companyeconomicsector(A,B).', 'source: athleteplaysinleague16(athlete,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplaysinleague16(A,B)=companyeconomicsector(A,B).', 'source: teamplaysagainstteam16(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamplaysagainstteam16(A,B)=companyalsoknownas(A,B).', 'source: teamalsoknownas17(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamalsoknownas17(A,B)=acquired(A,B).', 'source: teamalsoknownas18(sportsteam,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: teamalsoknownas18(A,B)=bankboughtbank(A,B).', 'source: teamplaysinleague18(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague18(A,B)=economicsectorcompany(A,B).', 'source: athleteplayssport19(athlete,sport).', 'target: economicsec ...
# ==========================
# INDIVIDUO  3
# REFINE:  ['0;;teamplayssport00(A,B):- athleteplayssport01(B, C);true;false', '0;true;athleteledsportsteam02(C, D).;true;true', '0;true,true;teamplaysinleague03(E, A), teamplaysinleague04(E, D).;true;false', '0;true,true,true;athleteplaysforteam04(C, D).;false;false', '0;true,false;teamplaysagainstteam05(H, A), athleteplaysinleague06(C, I).;true;true', '0;true,false,true;athleteplaysforteam06(J, H), athleteplaysinleague07(J, I).;false;false', '0;true,false,false;teamalsoknownas07(K, A).;false;false', '1;;teamplayssport10(A,B):- athleteplayssport11(B, C), athleteplaysinleague11(C, D);true;true', '1;true;athleteledsportsteam12(C, E).;true;true', '1;true,true;teamplaysagainstteam13(F, A), teamalsoknownas14(G, F).;false;true', '1;true,true,false;economicsectorcompanytarget14(W, E).;false;false', '1;true,false;teamplaysinleague15(A, H), athleteplaysinleague16(I, H).;true;false', '1;true,false,true;teamplaysagainstteam16(A, F).;true;false', '1;true,false,true,true;teamalsoknownas17(G, A), teamalsoknownas18(G, F).;false;false', '1;false;teamplaysinleague18(K, A).;false;true', '1;false,false;athleteplayssport19(B, L).;false;true', '1;false,false,false;teamplaysagainstteam110(A, M), teamalsoknownas111(A, N).;false;false', '2;;teamplayssport20(A,B):- athleteplayssport21(B, C), athleteplaysinleague21(C, D);true;true', '2;true;teamplaysagainstteam22(E, A), teamplaysinleague23(A, F).;false;true', '2;true,false;teamalsoknownas23(G, A), teamplaysinleague24(H, A).;false;true', '2;true,false,false;athleteledsportsteam24(C, I), teamplaysagainstteam25(A, J).;false;false', '2;false;teamalsoknownas25(K, A), teamalsoknownas26(L, K).;true;true', '2;false,false;bankchiefexecutiveceotarget26(P, J).;false;false', '2;false,true;teamplaysagainstteam27(A, L), athleteplaysforteam28(M, L).;true;true', '2;false,true,true;teamalsoknownas28(N, L).;false;false', '2;false,true,false;teamalsoknownas29(K, L).;false;false', '3;;teamplayssport30(A,B):- athleteplayssport31(C, B), athleteplaysinleague31(C, D);true;true', '3;true;athleteledsportsteam32(C, E).;false;false', '3;false;teamplaysinleague33(A, H).;true;true', '3;false,true;teamalsoknownas34(I, A), athleteplaysforteam35(J, I).;false;false', '3;false,false;teamplaysagainstteam35(A, K), teamalsoknownas36(L, A).;false;true', '3;false,false,false;teamplaysagainstteam36(M, A).;false;false', '4;;teamplayssport40(A,B):- athleteplayssport41(B, C);true;false', '4;true;athleteledsportsteam42(C, D).;true;true', '4;true,true;athleteplaysforteam43(E, A), athleteledsportsteam44(E, F).;true;true', '4;true,true,true;teamplaysagainstteam44(A, D), athleteplaysforteam45(C, D).;false;true', '4;true,true,true,false;cityhascompanyofficetarget45(B, H), cityhascompanyofficetarget46(K, B).;false;false', '4;true,true,false;teamplaysagainstteam46(A, G).;false;false', '4;true,false;teamplaysinleague47(H, A), athleteplaysinleague48(H, I).;true;true', '4;true,false,true;athleteplayssport48(J, I).;false;false', '4;true,false,false;teamplaysagainstteam49(K, A).;false;false', '5;;teamplayssport50(A,B):- athleteledsportsteam51(C, A), athleteplayssport51(D, C);true;true', '5;true;athleteplayssport52(E, B), athleteledsportsteam53(E, F).;true;true', '5;true,false;companyeconomicsectortarget53(C, E), bankboughtbanktarget54(F, Y).;false;false', '5;true,true;teamplaysagainstteam54(A, J).;false;false', '5;false;athleteplayssport55(B, H).;true;false', '5;false,true;athleteplaysforteam56(H, I).;true;true', '5;false,true,true;teamplaysinleague57(J, A), athleteledsportsteam58(K, I).;false;false', '5;false,true,false;athleteplaysinleague58(H, L), teamplaysagainstteam59(M, A).;false;false', '6;;teamplayssport60(A,B):- athleteplayssport61(C, B), athleteplaysinleague61(C, D);true;true', '6;true;athleteledsportsteam62(E, A).;false;true', '6;true,false;teamplaysinleague63(F, A), teamplaysagainstteam64(A, G).;true;true', '6;true,false,true;athleteledsportsteam64(C, H), teamplaysinleague65(H, F).;false;false', '6;true,false,false;teamplaysagainstteam65(I, A), te ...
# TRANSFER:  ['source: teamplayssport00(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport00(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport01(athlete,sport).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplayssport01(A,B)=economicsectorcompany(A,B).', 'source: athleteledsportsteam02(athlete,sportsteam).', 'target: acquired(company,company).', 'setMap: athleteledsportsteam02(A,B)=acquired(A,B).', 'source: teamplaysinleague03(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague03(A,B)=economicsectorcompany(A,B).', 'source: teamplaysinleague04(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague04(A,B)=economicsectorcompany(A,B).', 'source: athleteplaysforteam04(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteplaysforteam04(A,B)=bankboughtbank(A,B).', 'source: teamplaysagainstteam05(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamplaysagainstteam05(A,B)=acquired(A,B).', 'source: athleteplaysinleague06(athlete,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplaysinleague06(A,B)=companyeconomicsector(A,B).', 'source: athleteplaysforteam06(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteplaysforteam06(A,B)=bankboughtbank(A,B).', 'source: athleteplaysinleague07(athlete,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplaysinleague07(A,B)=companyeconomicsector(A,B).', 'source: teamalsoknownas07(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamalsoknownas07(A,B)=acquired(A,B).', 'source: teamplayssport10(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport10(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport11(athlete,sport).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplayssport11(A,B)=economicsectorcompany(A,B).', 'source: athleteplaysinleague11(athlete,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplaysinleague11(A,B)=companyeconomicsector(A,B).', 'source: athleteledsportsteam12(athlete,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: athleteledsportsteam12(A,B)=companyalsoknownas(A,B).', 'source: teamplaysagainstteam13(sportsteam,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: teamplaysagainstteam13(A,B)=bankboughtbank(A,B).', 'source: teamalsoknownas14(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamalsoknownas14(A,B)=acquired(A,B).', 'source: economicsectorcompanytarget14(economicsectorcompanytype1,economicsectorcompanytype2).', 'target: economicsectorcompany(sector,company).', 'setMap: economicsectorcompanytarget14(A,B)=economicsectorcompany(A,B).', 'source: teamplaysinleague15(sportsteam,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplaysinleague15(A,B)=companyeconomicsector(A,B).', 'source: athleteplaysinleague16(athlete,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplaysinleague16(A,B)=companyeconomicsector(A,B).', 'source: teamplaysagainstteam16(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamplaysagainstteam16(A,B)=companyalsoknownas(A,B).', 'source: teamalsoknownas17(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamalsoknownas17(A,B)=acquired(A,B).', 'source: teamalsoknownas18(sportsteam,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: teamalsoknownas18(A,B)=bankboughtbank(A,B).', 'source: teamplaysinleague18(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague18(A,B)=economicsectorcompany(A,B).', 'source: athleteplayssport19(athlete,sport).', 'target: economicsec ...
# ==========================

# %% [markdown]
# ## guiado

# %%
start = time.time()
res_cc_g = genetic(new_src_struct, target, source, train_pos, 
                                         train_neg, train_facts, kb_source, kb_target, pred_target,
                                          NUM_GEN=14, pop_size=30, crossover_type='tree', revision='guided')
print("FIM DO GROOT GENETIC: ", time.time()-start)
# Out:
# GENERATION:  0
# MELHOR RESULTADO:  -0.256967184364074
# entrei aqui
# BEST: {'m_auc_pr': 0.073752, 'm_auc_roc': 0.9791034999999999, 'm_cll': -0.24615599999999999, 'm_rec': 0.6783085, 'm_pred': 0.27080950000000004, 'm_f1': 0.077104, 's_auc_pr': 0.004914000000000002, 's_auc_roc': 0.00072549999999999, 's_cll': 0.00014399999999999136, 's_rec': 0.14522049999999997, 's_prec': 0.22939970410235933, 's_f1': 0.023381000000000002}
# GENERATION:  1
# MELHOR RESULTADO:  -0.26810352329697196
# entrei aqui
# BEST: {'m_auc_pr': 0.072412, 'm_auc_roc': 0.9783105, 'm_cll': -0.25813949999999997, 'm_rec': 0.623162, 'm_pred': 0.27399225000000005, 'm_f1': 0.086406, 's_auc_pr': 0.011025, 's_auc_roc': 0.0002995000000000081, 's_cll': 0.0011635000000000117, 's_rec': 0.141544, 's_prec': 0.22649501663433458, 's_f1': 0.034275999999999994}
# GENERATION:  2
# MELHOR RESULTADO:  -0.3412685979474232
# entrei aqui
# BEST: {'m_auc_pr': 0.042147000000000004, 'm_auc_roc': 0.6959979999999999, 'm_cll': -0.33865599999999996, 'm_rec': 0.0128675, 'm_pred': 0.34629624999999997, 'm_f1': 0.023814500000000002, 's_auc_pr': 0.003081999999999998, 's_auc_roc': 0.019121, 's_cll': 0.00039300000000000446, 's_rec': 0.0055144999999999994, 's_prec': 0.1537929721807453, 's_f1': 0.0096305}
# GENERATION:  3
# MELHOR RESULTADO:  -0.3412685979474232
# entrei aqui
# BEST: {'m_auc_pr': 0.042147000000000004, 'm_auc_roc': 0.6959979999999999, 'm_cll': -0.33865599999999996, 'm_rec': 0.0128675, 'm_pred': 0.34629624999999997, 'm_f1': 0.023814500000000002, 's_auc_pr': 0.003081999999999998, 's_auc_roc': 0.019121, 's_cll': 0.00039300000000000446, 's_rec': 0.0055144999999999994, 's_prec': 0.1537929721807453, 's_f1': 0.0096305}
# GENERATION:  4
# MELHOR RESULTADO:  -0.3412685979474232
# entrei aqui
# BEST: {'m_auc_pr': 0.042147000000000004, 'm_auc_roc': 0.6959979999999999, 'm_cll': -0.33865599999999996, 'm_rec': 0.0128675, 'm_pred': 0.34629624999999997, 'm_f1': 0.023814500000000002, 's_auc_pr': 0.003081999999999998, 's_auc_roc': 0.019121, 's_cll': 0.00039300000000000446, 's_rec': 0.0055144999999999994, 's_prec': 0.1537929721807453, 's_f1': 0.0096305}
# GENERATION:  5
# MELHOR RESULTADO:  -0.3412685979474232
# entrei aqui
# BEST: {'m_auc_pr': 0.042147000000000004, 'm_auc_roc': 0.6959979999999999, 'm_cll': -0.33865599999999996, 'm_rec': 0.0128675, 'm_pred': 0.34629624999999997, 'm_f1': 0.023814500000000002, 's_auc_pr': 0.003081999999999998, 's_auc_roc': 0.019121, 's_cll': 0.00039300000000000446, 's_rec': 0.0055144999999999994, 's_prec': 0.1537929721807453, 's_f1': 0.0096305}
# GENERATION:  6
# MELHOR RESULTADO:  -0.3412685979474232
# entrei aqui
# BEST: {'m_auc_pr': 0.042147000000000004, 'm_auc_roc': 0.6959979999999999, 'm_cll': -0.33865599999999996, 'm_rec': 0.0128675, 'm_pred': 0.34629624999999997, 'm_f1': 0.023814500000000002, 's_auc_pr': 0.003081999999999998, 's_auc_roc': 0.019121, 's_cll': 0.00039300000000000446, 's_rec': 0.0055144999999999994, 's_prec': 0.1537929721807453, 's_f1': 0.0096305}
# GENERATION:  7
# MELHOR RESULTADO:  -0.3412685979474232
# entrei aqui
# BEST: {'m_auc_pr': 0.042147000000000004, 'm_auc_roc': 0.6959979999999999, 'm_cll': -0.33865599999999996, 'm_rec': 0.0128675, 'm_pred': 0.34629624999999997, 'm_f1': 0.023814500000000002, 's_auc_pr': 0.003081999999999998, 's_auc_roc': 0.019121, 's_cll': 0.00039300000000000446, 's_rec': 0.0055144999999999994, 's_prec': 0.1537929721807453, 's_f1': 0.0096305}
# GENERATION:  8
# MELHOR RESULTADO:  -0.34164569738985445
# entrei aqui
# BEST: {'m_auc_pr': 0.285289, 'm_auc_roc': 0.985121, 'm_cll': -0.187968, 'm_rec': 0.9963234999999999, 'm_pred': 0.25686725, 'm_f1': 0.027095, 's_auc_pr': 0.03925999999999999, 's_auc_roc': 0.0008690000000000087, 's_cll': 8.099999999999774e-05, 's_rec': 0.003676500000000027, 's_prec': 0.24313276593805183, 's_f1': 0.0002409999999999999}
# GENERATION:  9
# MELHOR RESULTADO:  -0.34164569738985445
# entrei aqui
# BEST: {'m_auc_pr': 0.285289, 'm_auc_roc': 0.985121, 'm_cll': -0.187968, 'm_rec': 0.9963234999999999, 'm_pred': 0.25686725, 'm_f1': 0.027095, 's_auc_pr': 0.03925999999999999, 's_auc_roc': 0.0008690000000000087, 's_cll': 8.099999999999774e-05, 's_rec': 0.003676500000000027, 's_prec': 0.24313276593805183, 's_f1': 0.0002409999999999999}
# GENERATION:  10
# MELHOR RESULTADO:  -0.34164569738985445
# entrei aqui
# BEST: {'m_auc_pr': 0.285289, 'm_auc_roc': 0.985121, 'm_cll': -0.187968, 'm_rec': 0.9963234999999999, 'm_pred': 0.25686725, 'm_f1': 0.027095, 's_auc_pr': 0.03925999999999999, 's_auc_roc': 0.0008690000000000087, 's_cll': 8.099999999999774e-05, 's_rec': 0.003676500000000027, 's_prec': 0.24313276593805183, 's_f1': 0.0002409999999999999}
# GENERATION:  11
# MELHOR RESULTADO:  -0.34164569738985445
# entrei aqui
# BEST: {'m_auc_pr': 0.285289, 'm_auc_roc': 0.985121, 'm_cll': -0.187968, 'm_rec': 0.9963234999999999, 'm_pred': 0.25686725, 'm_f1': 0.027095, 's_auc_pr': 0.03925999999999999, 's_auc_roc': 0.0008690000000000087, 's_cll': 8.099999999999774e-05, 's_rec': 0.003676500000000027, 's_prec': 0.24313276593805183, 's_f1': 0.0002409999999999999}
# GENERATION:  12
# MELHOR RESULTADO:  -0.3705767129758695
# entrei aqui
# BEST: {'m_auc_pr': 0.001418, 'm_auc_roc': 0.5052800000000001, 'm_cll': -0.370574, 'm_rec': 0.001838, 'm_pred': nan, 'm_f1': nan, 's_auc_pr': 4.3999999999999985e-05, 's_auc_roc': 0.011281000000000013, 's_cll': 0.0008879999999999999, 's_rec': 0.001838, 's_prec': nan, 's_f1': nan}
# GENERATION:  13
# MELHOR RESULTADO:  -0.3705767129758695
# entrei aqui
# BEST: {'m_auc_pr': 0.001418, 'm_auc_roc': 0.5052800000000001, 'm_cll': -0.370574, 'm_rec': 0.001838, 'm_pred': nan, 'm_f1': nan, 's_auc_pr': 4.3999999999999985e-05, 's_auc_roc': 0.011281000000000013, 's_cll': 0.0008879999999999999, 's_rec': 0.001838, 's_prec': nan, 's_f1': nan}
# -0.3705767129758695 -0.3705767129758695
# -0.3705767129758695 -0.3705767129758695
# [{'m_auc_pr': 0.001418, 'm_auc_roc': 0.5052800000000001, 'm_cll': -0.370574, 'm_rec': 0.001838, 'm_pred': nan, 'm_f1': nan, 's_auc_pr': 4.3999999999999985e-05, 's_auc_roc': 0.011281000000000013, 's_cll': 0.0008879999999999999, 's_rec': 0.001838, 's_prec': nan, 's_f1': nan}, {'m_auc_pr': 0.001418, 'm_auc_roc': 0.5052800000000001, 'm_cll': -0.370574, 'm_rec': 0.001838, 'm_pred': nan, 'm_f1': nan, 's_auc_pr': 4.3999999999999985e-05, 's_auc_roc': 0.011281000000000013, 's_cll': 0.0008879999999999999, 's_rec': 0.001838, 's_prec': nan, 's_f1': nan}]
# RESULT: {'m_auc_pr': 0.001418, 'm_auc_roc': 0.5052800000000001, 'm_cll': -0.370574, 'm_rec': 0.001838, 'm_pred': nan, 'm_f1': nan, 's_auc_pr': 4.3999999999999985e-05, 's_auc_roc': 0.011281000000000013, 's_cll': 0.0008879999999999999, 's_rec': 0.001838, 's_prec': nan, 's_f1': nan}
# FIM DO GROOT GENETIC:  23257.434251070023

# %%
res_cc_g
# Out:
# (<src.s_genetic.population.Population at 0x7fa9777d6128>,
#  [-0.256967184364074,
#   -0.26810352329697196,
#   -0.3412685979474232,
#   -0.3412685979474232,
#   -0.3412685979474232,
#   -0.3412685979474232,
#   -0.3412685979474232,
#   -0.3412685979474232,
#   -0.34164569738985445,
#   -0.34164569738985445,
#   -0.34164569738985445,
#   -0.34164569738985445,
#   -0.3705767129758695,
#   -0.3705767129758695,
#   -0.3705767129758695],
#  [{'m_auc_pr': 0.073752,
#    'm_auc_roc': 0.9791034999999999,
#    'm_cll': -0.24615599999999999,
#    'm_rec': 0.6783085,
#    'm_pred': 0.27080950000000004,
#    'm_f1': 0.077104,
#    's_auc_pr': 0.004914000000000002,
#    's_auc_roc': 0.00072549999999999,
#    's_cll': 0.00014399999999999136,
#    's_rec': 0.14522049999999997,
#    's_prec': 0.22939970410235933,
#    's_f1': 0.023381000000000002},
#   {'m_auc_pr': 0.072412,
#    'm_auc_roc': 0.9783105,
#    'm_cll': -0.25813949999999997,
#    'm_rec': 0.623162,
#    'm_pred': 0.27399225000000005,
#    'm_f1': 0.086406,
#    's_auc_pr': 0.011025,
#    's_auc_roc': 0.0002995000000000081,
#    's_cll': 0.0011635000000000117,
#    's_rec': 0.141544,
#    's_prec': 0.22649501663433458,
#    's_f1': 0.034275999999999994},
#   {'m_auc_pr': 0.042147000000000004,
#    'm_auc_roc': 0.6959979999999999,
#    'm_cll': -0.33865599999999996,
#    'm_rec': 0.0128675,
#    'm_pred': 0.34629624999999997,
#    'm_f1': 0.023814500000000002,
#    's_auc_pr': 0.003081999999999998,
#    's_auc_roc': 0.019121,
#    's_cll': 0.00039300000000000446,
#    's_rec': 0.0055144999999999994,
#    's_prec': 0.1537929721807453,
#    's_f1': 0.0096305},
#   {'m_auc_pr': 0.042147000000000004,
#    'm_auc_roc': 0.6959979999999999,
#    'm_cll': -0.33865599999999996,
#    'm_rec': 0.0128675,
#    'm_pred': 0.34629624999999997,
#    'm_f1': 0.023814500000000002,
#    's_auc_pr': 0.003081999999999998,
#    's_auc_roc': 0.019121,
#    's_cll': 0.00039300000000000446,
#    's_rec': 0.0055144999999999994,
#    's_prec': 0.1537929721807453,
#    's_f1': 0.0096305},
#   {'m_auc_pr': 0.042147000000000004,
#    'm_auc_roc': 0.6959979999999999,
#    'm_cll': -0.33865599999999996,
#    'm_rec': 0.0128675,
#    'm_pred': 0.34629624999999997,
#    'm_f1': 0.023814500000000002,
#    's_auc_pr': 0.003081999999999998,
#    's_auc_roc': 0.019121,
#    's_cll': 0.00039300000000000446,
#    's_rec': 0.0055144999999999994,
#    's_prec': 0.1537929721807453,
#    's_f1': 0.0096305},
#   {'m_auc_pr': 0.042147000000000004,
#    'm_auc_roc': 0.6959979999999999,
#    'm_cll': -0.33865599999999996,
#    'm_rec': 0.0128675,
#    'm_pred': 0.34629624999999997,
#    'm_f1': 0.023814500000000002,
#    's_auc_pr': 0.003081999999999998,
#    's_auc_roc': 0.019121,
#    's_cll': 0.00039300000000000446,
#    's_rec': 0.0055144999999999994,
#    's_prec': 0.1537929721807453,
#    's_f1': 0.0096305},
#   {'m_auc_pr': 0.042147000000000004,
#    'm_auc_roc': 0.6959979999999999,
#    'm_cll': -0.33865599999999996,
#    'm_rec': 0.0128675,
#    'm_pred': 0.34629624999999997,
#    'm_f1': 0.023814500000000002,
#    's_auc_pr': 0.003081999999999998,
#    's_auc_roc': 0.019121,
#    's_cll': 0.00039300000000000446,
#    's_rec': 0.0055144999999999994,
#    's_prec': 0.1537929721807453,
#    's_f1': 0.0096305},
#   {'m_auc_pr': 0.042147000000000004,
#    'm_auc_roc': 0.6959979999999999,
#    'm_cll': -0.33865599999999996,
#    'm_rec': 0.0128675,
#    'm_pred': 0.34629624999999997,
#    'm_f1': 0.023814500000000002,
#    's_auc_pr': 0.003081999999999998,
#    's_auc_roc': 0.019121,
#    's_cll': 0.00039300000000000446,
#    's_rec': 0.0055144999999999994,
#    's_prec': 0.1537929721807453,
#    's_f1': 0.0096305},
#   {'m_auc_pr': 0.285289,
#    'm_auc_roc': 0.985121,
#    'm_cll': -0.187968,
#    'm_rec': 0.9963234999999999,
#    'm_pred': 0.25686725,
#    'm_f1': 0.027095,
#    's_auc_pr': 0.03925999999999999,
#    's_auc_roc': 0.0008690000000000087,
#    's_cll': 8.099999999999774e-05,
#    's_rec': 0.003676500000000027,
#    's_prec': 0.24313276593805183,
#    's_f1': 0.0002409999999999999},
#   {'m_auc_pr': 0.285289,
#    'm_auc_roc': 0.985121,
#    'm_cll': -0.187968,
#    'm_rec': 0.9963234999999999,
#    'm_pred': 0.25686725,
#    'm_f1': 0.027095,
#    's_auc_pr': 0.03925999999999999,
#    's_auc_roc': 0.0008690000000000087,
#    's_cll': 8.099999999999774e-05,
#    's_rec': 0.003676500000000027,
#    's_prec': 0.24313276593805183,
#    's_f1': 0.0002409999999999999},
#   {'m_auc_pr': 0.285289,
#    'm_auc_roc': 0.985121,
#    'm_cll': -0.187968,
#    'm_rec': 0.9963234999999999,
#    'm_pred': 0.25686725,
#    'm_f1': 0.027095,
#    's_auc_pr': 0.03925999999999999,
#    's_auc_roc': 0.0008690000000000087,
#    's_cll': 8.099999999999774e-05,
#    's_rec': 0.003676500000000027,
#    's_prec': 0.24313276593805183,
#    's_f1': 0.0002409999999999999},
#   {'m_auc_pr': 0.285289,
#    'm_auc_roc': 0.985121,
#    'm_cll': -0.187968,
#    'm_rec': 0.9963234999999999,
#    'm_pred': 0.25686725,
#    'm_f1': 0.027095,
#    's_auc_pr': 0.03925999999999999,
#    's_auc_roc': 0.0008690000000000087,
#    's_cll': 8.099999999999774e-05,
#    's_rec': 0.003676500000000027,
#    's_prec': 0.24313276593805183,
#    's_f1': 0.0002409999999999999},
#   {'m_auc_pr': 0.001418,
#    'm_auc_roc': 0.5052800000000001,
#    'm_cll': -0.370574,
#    'm_rec': 0.001838,
#    'm_pred': nan,
#    'm_f1': nan,
#    's_auc_pr': 4.3999999999999985e-05,
#    's_auc_roc': 0.011281000000000013,
#    's_cll': 0.0008879999999999999,
#    's_rec': 0.001838,
#    's_prec': nan,
#    's_f1': nan},
#   {'m_auc_pr': 0.001418,
#    'm_auc_roc': 0.5052800000000001,
#    'm_cll': -0.370574,
#    'm_rec': 0.001838,
#    'm_pred': nan,
#    'm_f1': nan,
#    's_auc_pr': 4.3999999999999985e-05,
#    's_auc_roc': 0.011281000000000013,
#    's_cll': 0.0008879999999999999,
#    's_rec': 0.001838,
#    's_prec': nan,
#    's_f1': nan},
#   {'m_auc_pr': 0.001418,
#    'm_auc_roc': 0.5052800000000001,
#    'm_cll': -0.370574,
#    'm_rec': 0.001838,
#    'm_pred': nan,
#    'm_f1': nan,
#    's_auc_pr': 4.3999999999999985e-05,
#    's_auc_roc': 0.011281000000000013,
#    's_cll': 0.0008879999999999999,
#    's_rec': 0.001838,
#    's_prec': nan,
#    's_f1': nan}])

# %%
# final_results[f'groot_test:{source}->{target}'] = []
# final_results[f'groot_test_rev:{source}->{target}'] = []
# final_results[f'inf_res:{source}->{target}'] = []
# final_results[f'inf_res_rev:{source}->{target}'] = []

# uwcse_dataset = datasets.load('uwcse', kb_target, target=target, seed=441773)
# train_facts, train_pos, train_neg, test_facts, test_pos, test_neg = get_train_test(uwcse_dataset, 1)
# tr_train_pos = []
# tr_train_neg = []
# tr_train_facts = []

# for i in range(0, len(train_pos)):
#     tr_train_pos.extend(train_pos[i])
#     tr_train_neg.extend(train_neg[i])
#     tr_train_facts.extend(train_facts[i])

# train = [tr_train_pos, tr_train_neg, tr_train_facts]
test = [test_pos, test_neg, test_facts[0]]

individuals = get_k_best_individuals(res_cc_g[0].population, 3)

n_ind = 1
for individual in individuals:
    print("INDIVIDUO ", n_ind)
    refine, transfer = get_refine_transfer(individual, source, target, 'yago2s', 'nell_finances')
    for i in range(len(train_pos)):
        ttrain = [train_pos[i], train_neg[i][:2*len(train_pos[i])], train_facts[i]]
        res_ = test_refine_transfer(kb_target, target, refine, transfer, ttrain, test)
        print(res_)
#         final_results[f'groot_test:{source}->{target}'].append(res)
#         import os
    #     thisFile = f'boostsrl/best/test/results_{target.replace('recursion_', '')}.db'
    #     thisFile = f'boostsrl/best/test/results_{target}.db'
    #     base = os.path.splitext(thisFile)[0]
    #     os.rename(thisFile, base + ".txt")
    #     tt = open('boostsrl/best/test/results_advisedby.txt', 'r').readlines()
    #     final = []
    #     for i in tt:
    #         final.append(i.replace('\n', ''))
    #     final_results[f'inf_res:{source}->{target}'].append(final)
        print("===========================================================================")
#         break

    n_ind += 1
# Out:
# INDIVIDUO  1
# ({'AUC ROC': 0.512847, 'AUC PR': 0.00152, 'CLL': -0.36974, 'Precision': [nan, 0.5], 'Recall': 0.0, 'F1': nan}, <boostsrl.boostsrl.test object at 0x7fa95be8f748>)
# ===========================================================================
# ({'AUC ROC': 0.484303, 'AUC PR': 0.001377, 'CLL': -0.369256, 'Precision': [nan, 0.5], 'Recall': 0.0, 'F1': nan}, <boostsrl.boostsrl.test object at 0x7fa95be8fb38>)
# ===========================================================================
# INDIVIDUO  2
# ({'AUC ROC': 0.512847, 'AUC PR': 0.00152, 'CLL': -0.36974, 'Precision': [nan, 0.5], 'Recall': 0.0, 'F1': nan}, <boostsrl.boostsrl.test object at 0x7fa9776ef8d0>)
# ===========================================================================
# ({'AUC ROC': 0.484303, 'AUC PR': 0.001377, 'CLL': -0.369256, 'Precision': [nan, 0.5], 'Recall': 0.0, 'F1': nan}, <boostsrl.boostsrl.test object at 0x7fa95be8fd68>)
# ===========================================================================
# INDIVIDUO  3
# ({'AUC ROC': 0.985916, 'AUC PR': 0.291565, 'CLL': -0.179562, 'Precision': [0.019971, 0.5], 'Recall': 0.92735, 'F1': 0.039099}, <boostsrl.boostsrl.test object at 0x7fa9776ef8d0>)
# ===========================================================================
# ({'AUC ROC': 0.985564, 'AUC PR': 0.329233, 'CLL': -0.181199, 'Precision': [0.020122, 0.5], 'Recall': 0.931624, 'F1': 0.039393}, <boostsrl.boostsrl.test object at 0x7fa95be8fac8>)
# ===========================================================================

# %%
individuals_rc = get_k_best_individuals(res_cc_g[0].population, 3)
n_i = 1
for ind in individuals_rc:
    refine, transfer = get_refine_transfer(ind, source, target, 'nell_sports', 'nell_finances')
    print("INDIVIDUO ", n_i)
    print("REFINE: ", refine)
    print("TRANSFER: ", transfer)
    print("==========================")
    n_i += 1
# Out:
# INDIVIDUO  1
# REFINE:  ['0;;teamplayssport00(A,B):- athleteplayssport01(C, B);true;false', '0;true;athleteledsportsteam02(C, D).;true;true', '0;true,true;teamplaysinleague03(E, A), teamplaysinleague04(E, D).;true;true', '0;true,true,true;athleteplaysforteam04(C, D).;false;false', '0;true,true,false;teamplaysagainstteam05(A, F), athleteplaysforteam06(G, A).;false;false', '0;true,false;teamplaysagainstteam06(H, A), athleteplaysinleague07(C, I).;true;false', '0;true,false,true;athleteplaysforteam07(J, H), athleteplaysinleague08(I, J).;false;false', '1;;teamplayssport10(A,B):- athleteplayssport11(C, B), athleteplaysinleague11(D, C);true;true', '1;true;athleteledsportsteam12(C, E).;true;true', '1;true,true;teamplaysagainstteam13(F, A), teamalsoknownas14(G, F).;false;false', '1;true,false;teamplaysinleague14(H, A), athleteplaysinleague15(H, I).;true;false', '1;true,false,true;teamplaysagainstteam15(A, J).;false;false', '1;false;teamplaysinleague16(K, A).;false;true', '1;false,false;athleteplayssport17(L, B).;false;false', '2;;teamplayssport20(A,B):- athleteplayssport21(B, C), athleteplaysinleague21(C, D);true;true', '2;true;teamplaysagainstteam22(E, A), teamplaysinleague23(F, A).;false;true', '2;true,false;teamalsoknownas23(G, A), teamplaysinleague24(A, H).;false;true', '2;true,false,false;athleteledsportsteam24(C, I), teamplaysagainstteam25(A, J).;false;false', '2;false;teamalsoknownas25(K, A), teamalsoknownas26(L, K).;true;false', '2;false,true;teamplaysagainstteam26(A, L), athleteplaysforteam27(M, L).;true;true', '2;false,true,true;teamalsoknownas27(N, L).;false;false', '2;false,true,false;teamalsoknownas28(K, L).;false;true', '2;false,true,false,false;bankboughtbanktarget29(I, H), acquiredtarget210(V, H).;false;false', '3;;teamplayssport30(A,B):- athleteplayssport31(C, B), athleteplaysinleague31(C, D);true;true', '3;true;athleteledsportsteam32(C, E).;true;false', '3;true,true;teamplaysinleague33(F, A), teamplaysinleague34(F, E).;false;true', '3;true,true,false;athleteplaysforteam34(C, G), teamalsoknownas35(E, G).;false;false', '3;false;teamplaysinleague35(H, A).;true;true', '3;false,true;teamalsoknownas36(I, A), athleteplaysforteam37(J, I).;false;false', '3;false,false;teamplaysagainstteam37(A, K), teamalsoknownas38(L, A).;false;false', '4;;teamplayssport40(A,B):- athleteplayssport41(C, B);true;false', '4;true;athleteledsportsteam42(C, D).;true;true', '4;true,true;athleteplaysforteam43(E, A), athleteledsportsteam44(E, F).;true;true', '4;true,true,true;teamplaysagainstteam44(I, A), teamplaysinleague45(J, I).;false;false', '4;true,true,false;athleteplaysinleague45(H, L), teamplaysagainstteam46(M, A).;false;false', '4;true,false;teamplaysinleague46(A, H), athleteplaysinleague47(I, H).;true;true', '4;true,false,true;athleteplayssport47(I, J).;false;false', '4;true,false,false;teamplaysagainstteam48(K, A).;false;false', '5;;teamplayssport50(A,B):- athleteledsportsteam51(C, A), athleteplayssport51(D, C);true;true', '5;true;athleteplayssport52(E, B), athleteledsportsteam53(E, F).;true;false', '5;true,true;teamplaysagainstteam53(A, F).;true;false', '5;true,true,true;teamalsoknownas54(G, A), teamalsoknownas55(G, F).;false;false', '5;false;athleteplayssport55(H, B).;true;false', '5;false,true;teamplaysagainstteam56(L, A), teamplaysagainstteam57(L, J).;false;true', '5;false,true,false;athleteledsportsteam57(K, J).;false;false', '6;;teamplayssport60(A,B):- athleteplayssport61(C, B), athleteplaysinleague61(D, C);true;true', '6;true;athleteledsportsteam62(E, A).;false;true', '6;true,false;teamplaysinleague63(A, F), teamplaysagainstteam64(A, G).;true;true', '6;true,false,true;athleteledsportsteam64(C, H), teamplaysinleague65(F, H).;false;false', '6;true,false,false;teamplaysagainstteam65(A, D), athleteplaysforteam66(C, D).;false;false', '6;false;teamalsoknownas66(K, A), athleteplaysforteam67(L, K).;true;false', '6;false,true;teamplaysagainstteam67(A, E), athleteledsportsteam68(F, E).;true;true', '6;false,true,true;athleteplaysinleague68(F, G), teamplaysinle ...
# TRANSFER:  ['source: teamplayssport00(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport00(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport01(athlete,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplayssport01(A,B)=companyeconomicsector(A,B).', 'source: athleteledsportsteam02(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteledsportsteam02(A,B)=bankboughtbank(A,B).', 'source: teamplaysinleague03(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague03(A,B)=economicsectorcompany(A,B).', 'source: teamplaysinleague04(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague04(A,B)=economicsectorcompany(A,B).', 'source: athleteplaysforteam04(athlete,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: athleteplaysforteam04(A,B)=companyalsoknownas(A,B).', 'source: teamplaysagainstteam05(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamplaysagainstteam05(A,B)=companyalsoknownas(A,B).', 'source: athleteplaysforteam06(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteplaysforteam06(A,B)=bankboughtbank(A,B).', 'source: teamplaysagainstteam06(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamplaysagainstteam06(A,B)=acquired(A,B).', 'source: athleteplaysinleague07(athlete,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplaysinleague07(A,B)=companyeconomicsector(A,B).', 'source: athleteplaysforteam07(athlete,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: athleteplaysforteam07(A,B)=companyalsoknownas(A,B).', 'source: athleteplaysinleague08(athlete,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplaysinleague08(A,B)=economicsectorcompany(A,B).', 'source: teamplayssport10(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport10(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport11(athlete,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplayssport11(A,B)=companyeconomicsector(A,B).', 'source: athleteplaysinleague11(athlete,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplaysinleague11(A,B)=economicsectorcompany(A,B).', 'source: athleteledsportsteam12(athlete,sportsteam).', 'target: acquired(company,company).', 'setMap: athleteledsportsteam12(A,B)=acquired(A,B).', 'source: teamplaysagainstteam13(sportsteam,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: teamplaysagainstteam13(A,B)=bankboughtbank(A,B).', 'source: teamalsoknownas14(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamalsoknownas14(A,B)=companyalsoknownas(A,B).', 'source: teamplaysinleague14(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague14(A,B)=economicsectorcompany(A,B).', 'source: athleteplaysinleague15(athlete,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplaysinleague15(A,B)=economicsectorcompany(A,B).', 'source: teamplaysagainstteam15(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamplaysagainstteam15(A,B)=companyalsoknownas(A,B).', 'source: teamplaysinleague16(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague16(A,B)=economicsectorcompany(A,B).', 'source: athleteplayssport17(athlete,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplayssport17(A,B)=companyeconomicsector(A,B).', 'source: teamplayssport20(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport20(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport21(athlete,sport).', ...
# ==========================
# INDIVIDUO  2
# REFINE:  ['0;;teamplayssport00(A,B):- athleteplayssport01(C, B);true;false', '0;true;athleteledsportsteam02(C, D).;true;true', '0;true,true;teamplaysinleague03(E, A), teamplaysinleague04(E, D).;true;true', '0;true,true,true;athleteplaysforteam04(C, D).;false;false', '0;true,true,false;teamplaysagainstteam05(A, F), athleteplaysforteam06(G, A).;false;false', '0;true,false;teamplaysagainstteam06(H, A), athleteplaysinleague07(C, I).;true;false', '0;true,false,true;athleteplaysforteam07(J, H), athleteplaysinleague08(I, J).;false;false', '1;;teamplayssport10(A,B):- athleteplayssport11(C, B), athleteplaysinleague11(D, C);true;true', '1;true;athleteledsportsteam12(C, E).;true;true', '1;true,true;teamplaysagainstteam13(F, A), teamalsoknownas14(G, F).;false;false', '1;true,false;teamplaysinleague14(H, A), athleteplaysinleague15(H, I).;true;false', '1;true,false,true;teamplaysagainstteam15(A, J).;false;false', '1;false;teamplaysinleague16(K, A).;false;true', '1;false,false;athleteplayssport17(L, B).;false;false', '2;;teamplayssport20(A,B):- athleteplayssport21(B, C), athleteplaysinleague21(C, D);true;true', '2;true;teamplaysagainstteam22(E, A), teamplaysinleague23(F, A).;false;true', '2;true,false;teamalsoknownas23(G, A), teamplaysinleague24(A, H).;false;true', '2;true,false,false;athleteledsportsteam24(C, I), teamplaysagainstteam25(A, J).;false;false', '2;false;teamalsoknownas25(K, A), teamalsoknownas26(L, K).;true;false', '2;false,true;teamplaysagainstteam26(A, L), athleteplaysforteam27(M, L).;true;true', '2;false,true,true;teamalsoknownas27(N, L).;false;false', '2;false,true,false;teamalsoknownas28(K, L).;false;true', '2;false,true,false,false;bankboughtbanktarget29(I, H), acquiredtarget210(V, H).;false;false', '3;;teamplayssport30(A,B):- athleteplayssport31(C, B), athleteplaysinleague31(C, D);true;true', '3;true;athleteledsportsteam32(C, E).;true;false', '3;true,true;teamplaysinleague33(F, A), teamplaysinleague34(F, E).;false;true', '3;true,true,false;athleteplaysforteam34(C, G), teamalsoknownas35(E, G).;false;false', '3;false;teamplaysinleague35(H, A).;true;true', '3;false,true;teamalsoknownas36(I, A), athleteplaysforteam37(J, I).;false;false', '3;false,false;teamplaysagainstteam37(A, K), teamalsoknownas38(L, A).;false;false', '4;;teamplayssport40(A,B):- athleteplayssport41(C, B);true;false', '4;true;athleteledsportsteam42(C, D).;true;true', '4;true,true;athleteplaysforteam43(E, A), athleteledsportsteam44(E, F).;true;true', '4;true,true,true;teamplaysagainstteam44(I, A), teamplaysinleague45(J, I).;false;false', '4;true,true,false;athleteplaysinleague45(H, L), teamplaysagainstteam46(M, A).;false;false', '4;true,false;teamplaysinleague46(A, H), athleteplaysinleague47(I, H).;true;true', '4;true,false,true;athleteplayssport47(I, J).;false;false', '4;true,false,false;teamplaysagainstteam48(K, A).;false;false', '5;;teamplayssport50(A,B):- athleteledsportsteam51(C, A), athleteplayssport51(D, C);true;true', '5;true;athleteplayssport52(E, B), athleteledsportsteam53(E, F).;true;false', '5;true,true;teamplaysagainstteam53(A, F).;true;false', '5;true,true,true;teamalsoknownas54(G, A), teamalsoknownas55(G, F).;false;false', '5;false;athleteplayssport55(H, B).;true;false', '5;false,true;teamplaysagainstteam56(L, A), teamplaysagainstteam57(L, J).;false;true', '5;false,true,false;athleteledsportsteam57(K, J).;false;false', '6;;teamplayssport60(A,B):- athleteplayssport61(C, B), athleteplaysinleague61(D, C);true;true', '6;true;athleteledsportsteam62(E, A).;false;true', '6;true,false;teamplaysinleague63(A, F), teamplaysagainstteam64(A, G).;true;true', '6;true,false,true;athleteledsportsteam64(C, H), teamplaysinleague65(F, H).;false;false', '6;true,false,false;teamplaysagainstteam65(A, D), athleteplaysforteam66(C, D).;false;false', '6;false;teamalsoknownas66(K, A), athleteplaysforteam67(L, K).;true;false', '6;false,true;teamplaysagainstteam67(A, E), athleteledsportsteam68(F, E).;true;true', '6;false,true,true;athleteplaysinleague68(F, G), teamplaysinle ...
# TRANSFER:  ['source: teamplayssport00(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport00(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport01(athlete,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplayssport01(A,B)=companyeconomicsector(A,B).', 'source: athleteledsportsteam02(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteledsportsteam02(A,B)=bankboughtbank(A,B).', 'source: teamplaysinleague03(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague03(A,B)=economicsectorcompany(A,B).', 'source: teamplaysinleague04(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague04(A,B)=economicsectorcompany(A,B).', 'source: athleteplaysforteam04(athlete,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: athleteplaysforteam04(A,B)=companyalsoknownas(A,B).', 'source: teamplaysagainstteam05(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamplaysagainstteam05(A,B)=companyalsoknownas(A,B).', 'source: athleteplaysforteam06(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteplaysforteam06(A,B)=bankboughtbank(A,B).', 'source: teamplaysagainstteam06(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamplaysagainstteam06(A,B)=acquired(A,B).', 'source: athleteplaysinleague07(athlete,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplaysinleague07(A,B)=companyeconomicsector(A,B).', 'source: athleteplaysforteam07(athlete,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: athleteplaysforteam07(A,B)=companyalsoknownas(A,B).', 'source: athleteplaysinleague08(athlete,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplaysinleague08(A,B)=economicsectorcompany(A,B).', 'source: teamplayssport10(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport10(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport11(athlete,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplayssport11(A,B)=companyeconomicsector(A,B).', 'source: athleteplaysinleague11(athlete,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplaysinleague11(A,B)=economicsectorcompany(A,B).', 'source: athleteledsportsteam12(athlete,sportsteam).', 'target: acquired(company,company).', 'setMap: athleteledsportsteam12(A,B)=acquired(A,B).', 'source: teamplaysagainstteam13(sportsteam,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: teamplaysagainstteam13(A,B)=bankboughtbank(A,B).', 'source: teamalsoknownas14(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamalsoknownas14(A,B)=companyalsoknownas(A,B).', 'source: teamplaysinleague14(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague14(A,B)=economicsectorcompany(A,B).', 'source: athleteplaysinleague15(athlete,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplaysinleague15(A,B)=economicsectorcompany(A,B).', 'source: teamplaysagainstteam15(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamplaysagainstteam15(A,B)=companyalsoknownas(A,B).', 'source: teamplaysinleague16(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague16(A,B)=economicsectorcompany(A,B).', 'source: athleteplayssport17(athlete,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplayssport17(A,B)=companyeconomicsector(A,B).', 'source: teamplayssport20(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport20(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport21(athlete,sport).', ...
# ==========================
# INDIVIDUO  3
# REFINE:  ['0;;teamplayssport00(A,B):- athleteplayssport01(B, C);true;false', '0;true;athleteledsportsteam02(C, D).;true;true', '0;true,true;teamplaysinleague03(E, A), teamplaysinleague04(E, D).;true;true', '0;true,true,true;athleteplaysforteam04(C, D).;false;false', '0;true,true,false;teamplaysagainstteam05(A, F), athleteplaysforteam06(G, A).;false;false', '0;true,false;teamplaysagainstteam06(H, A), athleteplaysinleague07(C, I).;true;false', '0;true,false,true;athleteplaysforteam07(J, H), athleteplaysinleague08(J, I).;false;false', '1;;teamplayssport10(A,B):- athleteplayssport11(C, B), athleteplaysinleague11(D, C);true;true', '1;true;athleteledsportsteam12(C, E).;true;true', '1;true,true;teamplaysagainstteam13(F, A), teamalsoknownas14(G, F).;false;false', '1;true,false;teamplaysinleague14(H, A), athleteplaysinleague15(H, I).;true;false', '1;true,false,true;teamplaysagainstteam15(A, J).;false;false', '1;false;teamplaysinleague16(A, K).;false;true', '1;false,false;athleteplayssport17(B, L).;false;false', '2;;teamplayssport20(A,B):- athleteplayssport21(C, B), athleteplaysinleague21(C, D);true;true', '2;true;teamplaysagainstteam22(E, A), teamplaysinleague23(F, A).;false;true', '2;true,false;teamalsoknownas23(G, A), teamplaysinleague24(A, H).;false;true', '2;true,false,false;athleteledsportsteam24(C, I), teamplaysagainstteam25(A, J).;false;false', '2;false;teamalsoknownas25(K, A), teamalsoknownas26(L, K).;true;false', '2;false,true;teamplaysagainstteam26(A, L), athleteplaysforteam27(M, L).;true;true', '2;false,true,true;teamalsoknownas27(N, L).;false;false', '2;false,true,false;teamalsoknownas28(K, L).;false;true', '2;false,true,false,false;bankboughtbanktarget29(I, H), acquiredtarget210(V, H).;false;false', '3;;teamplayssport30(A,B):- athleteplayssport31(C, B), athleteplaysinleague31(C, D);true;true', '3;true;athleteledsportsteam32(C, E).;true;false', '3;true,true;teamplaysinleague33(F, A), teamplaysinleague34(E, F).;false;true', '3;true,true,false;athleteplaysforteam34(C, G), teamalsoknownas35(E, G).;false;false', '3;false;teamplaysinleague35(H, A).;true;true', '3;false,true;teamalsoknownas36(I, A), athleteplaysforteam37(J, I).;false;false', '3;false,false;teamplaysagainstteam37(A, K), teamalsoknownas38(L, A).;false;false', '4;;teamplayssport40(A,B):- athleteplayssport41(B, C);true;false', '4;true;athleteledsportsteam42(C, D).;true;true', '4;true,true;athleteplaysforteam43(E, A), athleteledsportsteam44(E, F).;true;true', '4;true,true,true;teamplaysagainstteam44(I, A), teamplaysinleague45(J, I).;false;false', '4;true,true,false;athleteplaysinleague45(H, L), teamplaysagainstteam46(M, A).;false;false', '4;true,false;teamplaysinleague46(H, A), athleteplaysinleague47(I, H).;true;true', '4;true,false,true;athleteplayssport47(I, J).;false;false', '4;true,false,false;teamplaysagainstteam48(K, A).;false;false', '5;;teamplayssport50(A,B):- athleteledsportsteam51(C, A), athleteplayssport51(C, D);true;true', '5;true;athleteplayssport52(B, E), athleteledsportsteam53(E, F).;true;false', '5;true,true;teamplaysagainstteam53(A, F).;true;false', '5;true,true,true;teamalsoknownas54(G, A), teamalsoknownas55(G, F).;false;false', '5;false;athleteplayssport55(B, H).;true;false', '5;false,true;athleteplaysforteam56(H, I).;true;true', '5;false,true,true;teamplaysinleague57(J, A), athleteledsportsteam58(K, I).;false;false', '5;false,true,false;teamplaysagainstteam58(A, G).;false;false', '6;;teamplayssport60(A,B):- athleteplayssport61(B, C), athleteplaysinleague61(D, C);true;true', '6;true;athleteledsportsteam62(E, A).;false;true', '6;true,false;teamplaysinleague63(A, F), teamplaysagainstteam64(A, G).;true;true', '6;true,false,true;athleteledsportsteam64(C, H), teamplaysinleague65(F, H).;false;false', '6;true,false,false;teamplaysagainstteam65(A, D), athleteplaysforteam66(C, D).;false;false', '6;false;teamalsoknownas66(K, A), athleteplaysforteam67(L, K).;true;false', '6;false,true;teamplaysagainstteam67(A, E), athleteledsportsteam68(F, E).;true;true', '6;f ...
# TRANSFER:  ['source: teamplayssport00(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport00(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport01(athlete,sport).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplayssport01(A,B)=economicsectorcompany(A,B).', 'source: athleteledsportsteam02(athlete,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: athleteledsportsteam02(A,B)=companyalsoknownas(A,B).', 'source: teamplaysinleague03(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague03(A,B)=economicsectorcompany(A,B).', 'source: teamplaysinleague04(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague04(A,B)=economicsectorcompany(A,B).', 'source: athleteplaysforteam04(athlete,sportsteam).', 'target: acquired(company,company).', 'setMap: athleteplaysforteam04(A,B)=acquired(A,B).', 'source: teamplaysagainstteam05(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamplaysagainstteam05(A,B)=acquired(A,B).', 'source: athleteplaysforteam06(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteplaysforteam06(A,B)=bankboughtbank(A,B).', 'source: teamplaysagainstteam06(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamplaysagainstteam06(A,B)=companyalsoknownas(A,B).', 'source: athleteplaysinleague07(athlete,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplaysinleague07(A,B)=companyeconomicsector(A,B).', 'source: athleteplaysforteam07(athlete,sportsteam).', 'target: bankboughtbank(company,company).', 'setMap: athleteplaysforteam07(A,B)=bankboughtbank(A,B).', 'source: athleteplaysinleague08(athlete,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplaysinleague08(A,B)=companyeconomicsector(A,B).', 'source: teamplayssport10(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport10(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport11(athlete,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: athleteplayssport11(A,B)=companyeconomicsector(A,B).', 'source: athleteplaysinleague11(athlete,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplaysinleague11(A,B)=economicsectorcompany(A,B).', 'source: athleteledsportsteam12(athlete,sportsteam).', 'target: acquired(company,company).', 'setMap: athleteledsportsteam12(A,B)=acquired(A,B).', 'source: teamplaysagainstteam13(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamplaysagainstteam13(A,B)=companyalsoknownas(A,B).', 'source: teamalsoknownas14(sportsteam,sportsteam).', 'target: companyalsoknownas(company,company).', 'setMap: teamalsoknownas14(A,B)=companyalsoknownas(A,B).', 'source: teamplaysinleague14(sportsteam,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: teamplaysinleague14(A,B)=economicsectorcompany(A,B).', 'source: athleteplaysinleague15(athlete,sportsleague).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplaysinleague15(A,B)=economicsectorcompany(A,B).', 'source: teamplaysagainstteam15(sportsteam,sportsteam).', 'target: acquired(company,company).', 'setMap: teamplaysagainstteam15(A,B)=acquired(A,B).', 'source: teamplaysinleague16(sportsteam,sportsleague).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplaysinleague16(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport17(athlete,sport).', 'target: economicsectorcompany(company,sector).', 'setMap: athleteplayssport17(A,B)=economicsectorcompany(A,B).', 'source: teamplayssport20(sportsteam,sport).', 'target: companyeconomicsector(company,sector).', 'setMap: teamplayssport20(A,B)=companyeconomicsector(A,B).', 'source: athleteplayssport21(athlete,sport).', 'target: companyeconomicsector( ...
# ==========================

# %% [markdown]
# ## mixed

# %%
start = time.time()
res_cc_m = genetic(new_src_struct, target, source, train_pos, 
                                         train_neg, train_facts, kb_source, kb_target, pred_target,
                                          NUM_GEN=14, pop_size=30, crossover_type='tree', revision='mixed')
print("FIM DO GROOT GENETIC: ", time.time()-start)
# Out:
# Process ForkPoolWorker-2415:
# Process ForkPoolWorker-2416:
# Traceback (most recent call last):
#   File "/Users/leticia.figueiredo/opt/anaconda3/envs/groot/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/leticia.figueiredo/opt/anaconda3/envs/groot/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/leticia.figueiredo/opt/anaconda3/envs/groot/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/Users/leticia.figueiredo/opt/anaconda3/envs/groot/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/Users/leticia.figueiredo/opt/anaconda3/envs/groot/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/Users/leticia.figueiredo/opt/anaconda3/envs/groot/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/Users/leticia.figueiredo/opt/anaconda3/envs/groot/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Users/leticia.figueiredo/opt/anaconda3/envs/groot/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/Users/leticia.figueiredo/opt/anaconda3/envs/groot/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/leticia.figueiredo/opt/anaconda3/envs/groot/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/leticia.figueiredo/opt/anaconda3/envs/groot/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/Users/leticia.figueiredo/Documents/faculdade/groot/src/individual.py", line 276, in evaluate
#     maxTreeDepth=3, nodeSize=2, numOfClauses=8)
#   File "/Users/leticia.figueiredo/opt/anaconda3/envs/groot/lib/python3.6/site-packages/boostsrl/boostsrl.py", line 208, in __init__
#     write_to_file(background_knowledge, 'boostsrl/background.txt')
#   File "/Users/leticia.figueiredo/opt/anaconda3/envs/groot/lib/python3.6/site-packages/boostsrl/boostsrl.py", line 98, in write_to_file
#     f.write(line + '\n')
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-853e05631e8e> in <module>
#       2 res_cc_m = genetic(new_src_struct, target, source, train_pos,
#       3                                          train_neg, train_facts, kb_source, kb_target, pred_target,
# ----> 4                                           NUM_GEN=14, pop_size=30, crossover_type='tree', revision='mixed')
#       5 print("FIM DO GROOT GENETIC: ", time.time()-start)
#
# ~/Documents/faculdade/groot/src/s_genetic/genetic.py in genetic(src_struct, target, source, pos_target, neg_target, facts_target, kb_source, kb_target, target_pred, NUM_GEN, pop_size, crossover, mutation, trees, revision, crossover_type)
#      21
#      22     pop.evaluation(pop.population, trees, pos_target,
# ---> 23                    neg_target, facts_target)
#      24
#      25
#
# ~/Documents/faculdade/groot/src/s_genetic/population.py in evaluation(self, population, trees, pos_target, neg_target, facts_target)
#     194                 ind.transfer = tree[2]
#     195
# --> 196             results = evaluate_pop[0].run_evaluate(evaluate_pop, pos_target, neg_target, facts_target)
#     197             for ind, result in zip(evaluate_pop, results):
#     198                 # ind.fitness.values = result[3],
#
# ~/Documents/faculdade/groot/src/individual.py in run_evaluate(self, population, pos_target, neg_target, facts_target)
#     391         input_list = self._input_list(population, pos_target, neg_target, facts_target)
#     392         pool = multiprocessing.Pool()
# --> 393         results = pool.map(self.evaluate, input_list)
#     394
#     395         pool.terminate()
#
# ~/opt/anaconda3/envs/groot/lib/python3.6/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     264         in a list that is returned.
#     265         '''
# --> 266         return self._map_async(func, iterable, mapstar, chunksize).get()
#     267
#     268     def starmap(self, func, iterable, chunksize=None):
#
# ~/opt/anaconda3/envs/groot/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     636
#     637     def get(self, timeout=None):
# --> 638         self.wait(timeout)
#     639         if not self.ready():
#     640             raise TimeoutError
#
# ~/opt/anaconda3/envs/groot/lib/python3.6/multiprocessing/pool.py in wait(self, timeout)
#     633
#     634     def wait(self, timeout=None):
# --> 635         self._event.wait(timeout)
#     636
#     637     def get(self, timeout=None):
#
# ~/opt/anaconda3/envs/groot/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# ~/opt/anaconda3/envs/groot/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:

# %%
res_cc_m

# %%
# final_results[f'groot_test:{source}->{target}'] = []
# final_results[f'groot_test_rev:{source}->{target}'] = []
# final_results[f'inf_res:{source}->{target}'] = []
# final_results[f'inf_res_rev:{source}->{target}'] = []

# uwcse_dataset = datasets.load('uwcse', kb_target, target=target, seed=441773)
# train_facts, train_pos, train_neg, test_facts, test_pos, test_neg = get_train_test(uwcse_dataset, 1)
# tr_train_pos = []
# tr_train_neg = []
# tr_train_facts = []

# for i in range(0, len(train_pos)):
#     tr_train_pos.extend(train_pos[i])
#     tr_train_neg.extend(train_neg[i])
#     tr_train_facts.extend(train_facts[i])

# train = [tr_train_pos, tr_train_neg, tr_train_facts]
test = [test_pos, test_neg, test_facts[0]]

individuals = get_k_best_individuals(res_cc_m[0].population, 3)

n_ind = 1
for individual in individuals:
    print("INDIVIDUO ", n_ind)
    refine, transfer = get_refine_transfer(individual, source, target, 'yago2s', 'nell_finances')
    for i in range(len(train_pos)):
        ttrain = [train_pos[i], train_neg[i][:2*len(train_pos[i])], train_facts[i]]
        res_ = test_refine_transfer(kb_target, target, refine, transfer, ttrain, test)
        print(res_)
#         final_results[f'groot_test:{source}->{target}'].append(res)
#         import os
    #     thisFile = f'boostsrl/best/test/results_{target.replace('recursion_', '')}.db'
    #     thisFile = f'boostsrl/best/test/results_{target}.db'
    #     base = os.path.splitext(thisFile)[0]
    #     os.rename(thisFile, base + ".txt")
    #     tt = open('boostsrl/best/test/results_advisedby.txt', 'r').readlines()
    #     final = []
    #     for i in tt:
    #         final.append(i.replace('\n', ''))
    #     final_results[f'inf_res:{source}->{target}'].append(final)
        print("===========================================================================")
#         break

    n_ind += 1

# %%
individuals_rc = get_k_best_individuals(res_cc_m[0].population, 3)
n_i = 1
for ind in individuals_rc:
    refine, transfer = get_refine_transfer(ind, source, target, 'nell_sports', 'nell_finances')
    print("INDIVIDUO ", n_i)
    print("REFINE: ", refine)
    print("TRANSFER: ", transfer)
    print("==========================")
    n_i += 1

# %%
from datasets.get_datasets import *
import time
from src.genetic import *

from src.predicate import *
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# %%
bk = {
      'imdb': ['workedunder(+person,+person).',
              'workedunder(+person,-person).',
              'workedunder(-person,+person).',
              'female(+person).',
              'actor(+person).',
              'director(+person).',
              'movie(+movie,+person).',
              'movie(+movie,-person).',
              'movie(-movie,+person).',
              'genre(+person,+genre).'],
      'uwcse': ['professor(+person).',
        'student(+person).',
        'advisedby(+person,+person).',
        'advisedby(+person,-person).',
        'advisedby(-person,+person).',
        'tempadvisedby(+person,+person).',
        'tempadvisedby(+person,-person).',
        'tempadvisedby(-person,+person).',
        'ta(+course,+person,+quarter).',
        'ta(-course,-person,+quarter).',
        'ta(+course,-person,-quarter).',
        'ta(-course,+person,-quarter).',
        'hasposition(+person,+faculty).',
        'hasposition(+person,-faculty).',
        'hasposition(-person,+faculty).',
        'publication(+title,+person).',
        'publication(+title,-person).',
        'publication(-title,+person).',
        'inphase(+person,+prequals).',
        'inphase(+person,-prequals).',
        'inphase(-person,+prequals).',
        'courselevel(+course,+level).',
        'courselevel(+course,-level).',
        'courselevel(-course,+level).',
        'yearsinprogram(+person,+year).',
        'yearsinprogram(-person,+year).',
        'yearsinprogram(+person,-year).',
        'projectmember(+project,+person).',
        'projectmember(+project,-person).',
        'projectmember(-project,+person).',
        'sameproject(+project,+project).',
        'sameproject(+project,-project).',
        'sameproject(-project,+project).',
        'samecourse(+course,+course).',
        'samecourse(+course,-course).',
        'samecourse(-course,+course).',
        'sameperson(+person,+person).',
        'sameperson(+person,-person).',
        'sameperson(-person,+person).',],
      'cora': ['sameauthor(+author,+author).',
              'sameauthor(+author,-author).',
              'sameauthor(-author,+author).',
              'samebib(+class,+class).',
              'samebib(+class,-class).',
              'samebib(-class,+class).',
              'sametitle(+title,+title).',
              'sametitle(+title,-title).',
              'sametitle(-title,+title).',
              'samevenue(+venue,+venue).',
              'samevenue(+venue,-venue).',
              'samevenue(-venue,+venue).',
              'author(+class,+author).',
              'author(+class,-author).',
              'author(-class,+author).',
              'title(+class,+title).',
              'title(+class,-title).',
              'title(-class,+title).',
              'venue(+class,+venue).',
              'venue(+class,-venue).',
              'venue(-class,+venue).',
              'haswordauthor(+author,+word).',
              'haswordauthor(+author,-word).',
              'haswordauthor(-author,+word).',
              'haswordtitle(+title,+word).',
              'haswordtitle(+title,-word).',
              'haswordtitle(-title,+word).',
              'haswordvenue(+venue,+word).',
              'haswordvenue(+venue,-word).',
              'haswordvenue(-venue,+word).'],
      'webkb': ['coursepage(+page).',
                'facultypage(+page).',
                'studentpage(+page).',
                'researchprojectpage(+page).',
                'linkto(+id,+page,+page).',
                'linkto(+id,-page,-page).',
                'linkto(-id,-page,+page).',
                'linkto(-id,+page,-page).',
                'has(+word,+page).',
                'has(+word,-page).',
                'has(-word,+page).',
                'hasalphanumericword(+id).',
                'allwordscapitalized(+id).',
                'instructorsof(+page,+page).',
                'instructorsof(+page,-page).',
                'instructorsof(-page,+page).',
                'hasanchor(+word,+page).',
                'hasanchor(+word,-page).',
                'hasanchor(-word,+page).',
                'membersofproject(+page,+page).',
                'membersofproject(+page,-page).',
                'membersofproject(-page,+page).',
                'departmentof(+page,+page).',
                'departmentof(+page,-page).',
                'departmentof(-page,+page).',
                'pageclass(+page,+class).',
                'pageclass(+page,-class).',
                'pageclass(-page,+class).'],
      'twitter': ['accounttype(+account,+type).',
                  'accounttype(+account,-type).',
                  'accounttype(-account,+type).',
                  'tweets(+account,+word).',
                  'tweets(+account,-word).',
                  'tweets(-account,+word).',
                  'follows(+account,+account).',
                  'follows(+account,-account).',
                  'follows(-account,+account).',],
      'yeast': ['location(+protein,+loc).',
                'location(+protein,-loc).',
                'location(-protein,+loc).',
                'interaction(+protein,+protein).',
                'interaction(+protein,-protein).',
                'interaction(-protein,+protein).',
                'proteinclass(+protein,+class).',
                'proteinclass(+protein,-class).',
                'proteinclass(-protein,+class).',
                'enzyme(+protein,+enz).',
                'enzyme(+protein,-enz).',
                'enzyme(-protein,+enz).',
                'function(+protein,+fun).',
                'function(+protein,-fun).',
                'function(-protein,+fun).',
                'complex(+protein,+com).',
                'complex(+protein,-com).',
                'complex(-protein,+com).',
                'phenotype(+protein,+phe).',
                'phenotype(+protein,-phe).',
                'phenotype(-protein,+phe).'],
      'nell_sports': ['athleteledsportsteam(+athlete,+sportsteam).',
              'athleteledsportsteam(+athlete,-sportsteam).',
              'athleteledsportsteam(-athlete,+sportsteam).',
              'athleteplaysforteam(+athlete,+sportsteam).',
              'athleteplaysforteam(+athlete,-sportsteam).',
              'athleteplaysforteam(-athlete,+sportsteam).',
              'athleteplaysinleague(+athlete,+sportsleague).',
              'athleteplaysinleague(+athlete,-sportsleague).',
              'athleteplaysinleague(-athlete,+sportsleague).',
              'athleteplayssport(+athlete,+sport).',
              'athleteplayssport(+athlete,-sport).',
              'athleteplayssport(-athlete,+sport).',
              'teamalsoknownas(+sportsteam,+sportsteam).',
              'teamalsoknownas(+sportsteam,-sportsteam).',
              'teamalsoknownas(-sportsteam,+sportsteam).',
              'teamplaysagainstteam(+sportsteam,+sportsteam).',
              'teamplaysagainstteam(+sportsteam,-sportsteam).',
              'teamplaysagainstteam(-sportsteam,+sportsteam).',
              'teamplaysinleague(+sportsteam,+sportsleague).',
              'teamplaysinleague(+sportsteam,-sportsleague).',
              'teamplaysinleague(-sportsteam,+sportsleague).',
              'teamplayssport(+sportsteam,+sport).',
              'teamplayssport(+sportsteam,-sport).',
              'teamplayssport(-sportsteam,+sport).'],
      'nell_finances': ['countryhascompanyoffice(+country,+company).',
                        'countryhascompanyoffice(+country,-company).',
                        'countryhascompanyoffice(-country,+company).',
                        'companyeconomicsector(+company,+sector).',
                        'companyeconomicsector(+company,-sector).',
                        'companyeconomicsector(-company,+sector).',
                        'economicsectorcompany(+sector,-company).',
                        'economicsectorcompany(-sector,+company).',
                        'companyceo(+company,+person).',
                        'companyceo(+company,-person).',
                        'companyceo(-company,+person).',
                        'companyalsoknownas(+company,+company).',
                        'companyalsoknownas(+company,-company).',
                        'companyalsoknownas(-company,+company).',
                        'cityhascompanyoffice(+city,+company).',
                        'cityhascompanyoffice(+city,-company).',
                        'cityhascompanyoffice(-city,+company).',
                        'acquired(+company,+company).',
                        'acquired(+company,-company).',
                        'acquired(-company,+company).',
                        'bankbankincountry(+person,+country).',
                        'bankbankincountry(+person,-country).',
                        'bankbankincountry(-person,+country).',
                        'bankboughtbank(+company,+company).',
                        'bankboughtbank(+company,-company).',
                        'bankboughtbank(-company,+company).',
                        'bankchiefexecutiveceo(+company,+person).',
                        'bankchiefexecutiveceo(+company,-person).',
                        'bankchiefexecutiveceo(-company,+person).']}

# %% [markdown]
# # Transfer
# The idea for this notebook is to check if the transfers are being mapping in the right way.
# Also, it will have the comparation between the groot transfer and TreeBoostler transfer.

# %% [markdown]
# ## groot

# %%
bk_source = bk['imdb']
bk_target = bk['uwcse']

# %%
imdb_dataset = datasets.load('imdb', bk_source, target='workedunder', seed=441773) #facts, pos, neg
uwcse_dataset = datasets.load('uwcse', bk_target, target='advisedby', seed=441773) #facts, pos, neg

# %% [markdown]
# ### Training with the source background knowledge

# %%
train_facts_source = []
train_pos_source = []
train_neg_source = []
for i in range(0, len(imdb_dataset)):
    train_facts_source.extend(imdb_dataset[0][i])
    train_pos_source.extend(imdb_dataset[1][i])
    train_neg_source.extend(imdb_dataset[2][i])

# %%
target = ['workedunder']
background_knowledge_src = boostsrl.modes(bk_source, target, useStdLogicVariables=False, 
                                          maxTreeDepth=3, nodeSize=2, numOfClauses=8)

model_src = boostsrl.train(background_knowledge_src, train_pos_source, train_neg_source, train_facts_source, trees=10)

# %%
structured_src = []
for i in range(0, 10):
    try:
        structured_src.append(model_src.get_structured_tree(treenumber=i+1).copy())
    except:
        structured_src.append(model_src.get_structured_tree(treenumber='combine').copy())

# %%
#pred_target é : pred_target = [('movie', '+,-'), ('director', '+'),...]
import re
pred_target = []
for pred in bk_target:
    modes = ','.join([pred[occur.start()] for occur in re.finditer('[+\-]', pred)])
    pred_target.append((pred.split('(')[0], modes))

# %%
def get_branch(curr_value, next_value):
    if curr_value == '': 
        return next_value
    return '{},{}'.format(curr_value, next_value)

def define_individual(structured_tree, tree_number):
    individual_tree = []
    target = structured_tree[0]
    nodes = structured_tree[1]
    for values, node in nodes.items():
        if values == '': 
            branch = '{} :- {}.'.format(target, node)
        else: branch = '{}.'.format(node)
        left_branch = 'true' if get_branch(values, 'true') in nodes  else 'false'
        right_branch = 'true' if get_branch(values, 'false') in nodes else 'false'
        individual_tree.append('{};{};{};{};{}'.format(tree_number, values, 
                                                  branch, left_branch, right_branch))
    return individual_tree

src_struct = copy.deepcopy(structured_src)
new_src_struct = []
for i in range(0, len(src_struct)):
    new_src_struct.append(define_individual(src_struct[i], i))

# %%
new_src_struct
# Out:
# [['0;;workedunder(A, B) :- director(B), actor(A).;true;false',
#   '0;true;movie(C, A), movie(C, B).;false;false'],
#  ['1;;workedunder(A, B) :- director(B), actor(A).;true;false',
#   '1;true;movie(C, A), movie(C, B).;false;false'],
#  ['2;;workedunder(A, B) :- director(B), actor(A).;true;false',
#   '2;true;movie(C, A), movie(C, B).;false;false'],
#  ['3;;workedunder(A, B) :- director(B), actor(A).;true;false',
#   '3;true;movie(C, A), movie(C, B).;false;false'],
#  ['4;;workedunder(A, B) :- actor(A), director(B).;true;false',
#   '4;true;movie(C, A), movie(C, B).;false;false'],
#  ['5;;workedunder(A, B) :- actor(A), director(B).;true;false',
#   '5;true;movie(C, A), movie(C, B).;false;false'],
#  ['6;;workedunder(A, B) :- director(B), actor(A).;true;false',
#   '6;true;movie(C, A), movie(C, B).;false;false'],
#  ['7;;workedunder(A, B) :- actor(A), director(B).;true;false',
#   '7;true;movie(C, A), movie(C, B).;false;false'],
#  ['8;;workedunder(A, B) :- director(B), actor(A).;true;false',
#   '8;true;movie(C, A), movie(C, B).;false;false'],
#  ['9;;workedunder(A, B) :- actor(A), director(B).;true;false',
#   '9;true;movie(C, A), movie(C, B).;false;false']]

# %% [markdown]
# ### Starting the transfer between source and target

# %%
train_facts = uwcse_dataset[0][1:]
train_pos = uwcse_dataset[1][1:]
train_neg = uwcse_dataset[2][1:]

test_facts = uwcse_dataset[0][0]
test_pos = uwcse_dataset[1][0]
test_neg = uwcse_dataset[2][0]

# %% [markdown]
# For this test, we only run for 3 generations, to compare with the transfer coming from TreeBoostler

# %%
start = time.time()
pred = Predicate(bk_source, bk_target, pred_target)
aa = genetic(new_src_struct, 'advisedby', 'workedunder', pred, train_pos, 
                        train_neg, train_facts,
                        NUM_GEN=2, pop_size=30)
print("FIM: ", time.time()-start)
# Out:
# MEDIA
# AUC PR:  0.878788
# AUC ROC:  0.931034
# CLL:  -0.35265
# PREC:  0.6893940000000001
# RECALL:  1.0
# F1:  0.935484
# -------------------
# MEDIA
# AUC PR:  0.878788
# AUC ROC:  0.931034
# CLL:  -0.294695
# PREC:  0.6893940000000001
# RECALL:  1.0
# F1:  0.935484
# -------------------
# (0.35265,) False
# (0.294695,) True
# bestResult: 0.294695
# MEDIA
# AUC PR:  0.878788
# AUC ROC:  0.931034
# CLL:  -0.294695
# PREC:  0.6893940000000001
# RECALL:  1.0
# F1:  0.935484
# -------------------
# MEDIA
# AUC PR:  0.878788
# AUC ROC:  0.931034
# CLL:  -0.36211
# PREC:  0.6893940000000001
# RECALL:  1.0
# F1:  0.935484
# -------------------
# (0.294695,) False
# (0.294695,) False
# bestResult: 0.294695
# MEDIA
# AUC PR:  0.878788
# AUC ROC:  0.931034
# CLL:  -0.36211
# PREC:  0.6893940000000001
# RECALL:  1.0
# F1:  0.935484
# -------------------
# MEDIA
# AUC PR:  0.878788
# AUC ROC:  0.931034
# CLL:  -0.36211
# PREC:  0.6893940000000001
# RECALL:  1.0
# F1:  0.935484
# -------------------
# (0.36211,) False
# (0.294695,) True
# bestResult: 0.294695
# FIM:  17.667978048324585

# %%
ind = aa[0].population[2]

best_value = aa[0].population[0].fitness.values[0]
for i in range(0, len(aa[0].population)):
    if aa[0].population[i].fitness.values[0] < best_value:
        ind = aa[0].population[i]
        best_value = aa[0].population[i].fitness.values[0]

# %%
ind.fitness.values
# Out:
# (0.268746,)

# %%
tr_train_pos = []
tr_train_neg = []
tr_train_facts = []

for i in range(0, len(train_pos)):
    tr_train_pos.extend(train_pos[i])
    tr_train_neg.extend(train_neg[i])
    tr_train_facts.extend(train_facts[i])
    
refine = []
for tree in ind.modified_src_tree:
    refine.extend(tree)
    
transfer = ind.transfer.transfer



background_train = boostsrl.modes(bk['uwcse'], ['advisedby'], useStdLogicVariables=False, 
                                  maxTreeDepth=3, nodeSize=2, numOfClauses=8)
model_tr = boostsrl.train(background_train, tr_train_pos, tr_train_neg, tr_train_facts, 
                          refine=refine, transfer=transfer, 
                          trees=10)

# %%
test_model = boostsrl.test(model_tr, test_pos, test_neg, 
                                       test_facts, trees=10)
test_model.summarize_results()
# Out:
# {'AUC ROC': 0.942857,
#  'AUC PR': 0.897436,
#  'CLL': -0.257443,
#  'Precision': [0.897436, 0.5],
#  'Recall': 1.0,
#  'F1': 0.945946}

# %%
variances = [model_tr.get_variances(treenumber=i+1) for i in range(10)]
variances
# Out:
# [{'': [0.10072314049586789, 5.224578939412501e-17],
#   'true': [nan, 0.10072314049586789]},
#  {'': [0.1007231404958703, -3.918434204559376e-17],
#   'true': [nan, 0.1007231404958703]},
#  {'': [4.827056628805028e-18, 0.14828959476002165],
#   'true': [nan, 4.827056628805028e-18]},
#  {'': [0.10072314049586818, 0.0004081610429955891],
#   'true': [nan, 0.10072314049586818]},
#  {'': [-2.100421938480026e-17, 0.10802821767492997],
#   'true': [nan, -2.100421938480026e-17]},
#  {'': [0.1007231404958683, 0.0001861754583142338],
#   'true': [nan, 0.1007231404958683]},
#  {'': [0.1007231404958674, 0.0001561203692432273],
#   'true': [nan, 0.1007231404958674]},
#  {'': [3.469446951953614e-18, 0.07559028083378787], 'true': [nan, 0.0]},
#  {'': [0.10072314049586778, 3.412715507489718e-05],
#   'true': [nan, 0.10072314049586778]},
#  {'': [-8.673617379884035e-18, 0.07070549166390724],
#   'true': [nan, -8.673617379884035e-18]}]

# %% [markdown]
# Testing TreeBoostler

# %%
import sys  
sys.path.insert(0, '../TreeBoostler')

from revision import *
from transfer import *
from mapping import *
from boostsrl import boostsrl
import os

predicate = 'workedunder'
to_predicate = 'advisedby'

def print_function(message):
    global experiment_title
    global nbr
    if not os.path.exists('experiments/' + experiment_title):
        os.makedirs('experiments/' + experiment_title)
    with open('experiments/' + experiment_title + '/' + str(nbr) + '_' + experiment_title + '.txt', 'a') as f:
        print(message, file=f)
        print(message)

# %%
transferred_structured = structured_src
tr_file = transfer.get_transfer_file(bk['imdb'], bk['uwcse'], predicate, to_predicate, searchArgPermutation=True, allowSameTargetMap=False)
new_target = to_predicate

# %%
tr_train_pos = []
tr_train_neg = []
tr_train_facts = []

for i in range(0, len(train_pos)):
    tr_train_pos.extend(train_pos[i])
    tr_train_neg.extend(train_neg[i])
    tr_train_facts.extend(train_facts[i])

# %%
# transfer and revision theory
experiment_title = 'IMDB -> UW-CSE'
nbr = 1
background = boostsrl.modes(bk['uwcse'], [to_predicate], useStdLogicVariables=False, maxTreeDepth=3, nodeSize=2, numOfClauses=8)
[model, t_results, structured, pl_t_results] = revision.theory_revision(background, boostsrl, target, tr_train_pos, tr_train_neg, tr_train_facts, test_pos, test_neg, test_facts, structured_src, transfer=tr_file, trees=10, max_revision_iterations=1, print_function=print_function)
# Out:
# ******************************************
# Performing Parameter Learning
# ******************************************
# Refine
# 0;;workedunder(A, B) :- director(B), actor(A).;true;false
# 0;true;movie(C, A), movie(C, B).;false;false
# 1;;workedunder(A, B) :- director(B), actor(A).;true;false
# 1;true;movie(C, A), movie(C, B).;false;false
# 2;;workedunder(A, B) :- director(B), actor(A).;true;false
# 2;true;movie(C, A), movie(C, B).;false;false
# 3;;workedunder(A, B) :- director(B), actor(A).;true;false
# 3;true;movie(C, A), movie(C, B).;false;false
# 4;;workedunder(A, B) :- actor(A), director(B).;true;false
# 4;true;movie(C, A), movie(C, B).;false;false
# 5;;workedunder(A, B) :- actor(A), director(B).;true;false
# 5;true;movie(C, A), movie(C, B).;false;false
# 6;;workedunder(A, B) :- director(B), actor(A).;true;false
# 6;true;movie(C, A), movie(C, B).;false;false
# 7;;workedunder(A, B) :- actor(A), director(B).;true;false
# 7;true;movie(C, A), movie(C, B).;false;false
# 8;;workedunder(A, B) :- director(B), actor(A).;true;false
# 8;true;movie(C, A), movie(C, B).;false;false
# 9;;workedunder(A, B) :- actor(A), director(B).;true;false
# 9;true;movie(C, A), movie(C, B).;false;false
#
#
# WILL Produced-Tree #1
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, A), publication(C, B) )
# %   | then return 0.822434649385226;  // std dev = 0,982, 28,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=27 */
# %   | else return 0.708148935099512;  // std dev = 2,766, 60,000 (wgt'ed) examples reached here.  /* #neg=9 #pos=51 */
# %   else return -0.14185106490048768;  // std dev = 5,96e-08, 68,000 (wgt'ed) examples reached here.  /* #neg=68 */
# WILL Produced-Tree #2
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, A), publication(C, B) )
# %   | then return 0.6909105759500754;  // std dev = 0,982, 28,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=27 */
# %   | else return 0.5987301289105089;  // std dev = 2,766, 60,000 (wgt'ed) examples reached here.  /* #neg=9 #pos=51 */
# %   else return -0.1254446385283916;  // std dev = 0,000, 68,000 (wgt'ed) examples reached here.  /* #neg=68 */
# WILL Produced-Tree #3
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, A), publication(C, B) )
# %   | then return 0.5354626841427582;  // std dev = 0,982, 28,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=27 */
# %   | else return 0.47084136902302703;  // std dev = 2,766, 60,000 (wgt'ed) examples reached here.  /* #neg=9 #pos=51 */
# %   else return -0.11231637819360629;  // std dev = 4,47e-08, 68,000 (wgt'ed) examples reached here.  /* #neg=68 */
# WILL Produced-Tree #4
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, A), publication(C, B) )
# %   | then return 0.4024026492217927;  // std dev = 0,982, 28,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=27 */
# %   | else return 0.3555696613550181;  // std dev = 2,766, 60,000 (wgt'ed) examples reached here.  /* #neg=9 #pos=51 */
# %   else return -0.10159632948783621;  // std dev = 3,94e-08, 68,000 (wgt'ed) examples reached here.  /* #neg=68 */
# WILL Produced-Tree #5
# % FOR advisedby(A, B):
# %   if ( student(A), professor(B) )
# %   then if ( publication(C, A), publication(C, B) )
# %   | then return 0.30700250684980995;  // std dev = 0,982, 28,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=27 */
# %   | else return 0.2674403085153743;  // std dev = 2,766, 60,000 (wgt'ed) examples reached here.  /* #neg=9 #pos=51 */
# %   else return -0.09269127618926105;  // std dev = 0,000, 68,000 (wgt'ed) examples reached here.  /* #neg=68 */
# WILL Produced-Tree #6
# % FOR advisedby(A, B):
# %   if ( student(A), professor(B) )
# %   then if ( publication(C, A), publication(C, B) )
# %   | then return 0.24152182581632603;  // std dev = 0,982, 28,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=27 */
# %   | else return 0.20417660688414682;  // std dev = 2,766, 60,000 (wgt'ed) examples reached here.  /* #neg=9 #pos=51 */
# %   else return -0.0851847513883968;  // std dev = 3,07e-08, 68,000 (wgt'ed) examples reached here.  /* #neg=68 */
# WILL Produced-Tree #7
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, A), publication(C, B) )
# %   | then return 0.1958080954961511;  // std dev = 0,982, 28,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=27 */
# %   | else return 0.15897684158606587;  // std dev = 2,766, 60,000 (wgt'ed) examples reached here.  /* #neg=9 #pos=51 */
# %   else return -0.07877675473109173;  // std dev = 2,36e-08, 68,000 (wgt'ed) examples reached here.  /* #neg=68 */
# WILL Produced-Tree #8
# % FOR advisedby(A, B):
# %   if ( student(A), professor(B) )
# %   then if ( publication(C, A), publication(C, B) )
# %   | then return 0.1628100390760043;  // std dev = 0,982, 28,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=27 */
# %   | else return 0.12610125737419722;  // std dev = 2,766, 60,000 (wgt'ed) examples reached here.  /* #neg=9 #pos=51 */
# %   else return -0.07324622576333704;  // std dev = 1,29e-08, 68,000 (wgt'ed) examples reached here.  /* #neg=68 */
# WILL Produced-Tree #9
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, A), publication(C, B) )
# %   | then return 0.13816881840032139;  // std dev = 0,982, 28,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=27 */
# %   | else return 0.10162108252318372;  // std dev = 2,766, 60,000 (wgt'ed) examples reached here.  /* #neg=9 #pos=51 */
# %   else return -0.0684269778442027;  // std dev = 2,11e-08, 68,000 (wgt'ed) examples reached here.  /* #neg=68 */
# WILL Produced-Tree #10
# % FOR advisedby(A, B):
# %   if ( student(A), professor(B) )
# %   then if ( publication(C, A), publication(C, B) )
# %   | then return 0.11920579263429053;  // std dev = 0,982, 28,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=27 */
# %   | else return 0.08297179282455365;  // std dev = 2,766, 60,000 (wgt'ed) examples reached here.  /* #neg=9 #pos=51 */
# %   else return -0.06419184008202623;  // std dev = 0,000, 68,000 (wgt'ed) examples reached here.  /* #neg=68 */
#
#
# Results
#    AUC ROC   = 0.965714
#    AUC PR    = 0.959106
#    CLL	      = -0.218634
#    Precision = 0.897436 at threshold = 0.5
#    Recall    = 1.0
#    F1        = 0.945946
#
#
# Total learning time: 4.039 seconds
# Total inference time: 1.773 seconds
# AUC ROC: 0.965714
#
#
# Results scoring model
#    AUC ROC   = 0.951677
#    AUC PR    = 0.929498
#    CLL	      = -0.234219
#    Precision = 0.886364 at threshold = 0.5
#    Recall    = 1.0
#    F1        = 0.939759
#
#
# Total scoring time: 2.216 seconds
# Parameter learned model CLL: -0.234219
#
#
# Structure after Parameter Learning
# [['advisedby(A, B)', {'': 'professor(B), student(A)', 'true': 'publication(C, A), publication(C, B)'}, {'true,true': [0.982, 1, 27], 'true,false': [2.766, 9, 51], 'false': [5.96e-08, 68, 0]}], ['advisedby(A, B)', {'': 'professor(B), student(A)', 'true': 'publication(C, A), publication(C, B)'}, {'true,true': [0.982, 1, 27], 'true,false': [2.766, 9, 51], 'false': [0.0, 68, 0]}], ['advisedby(A, B)', {'': 'professor(B), student(A)', 'true': 'publication(C, A), publication(C, B)'}, {'true,true': [0.982, 1, 27], 'true,false': [2.766, 9, 51], 'false': [4.47e-08, 68, 0]}], ['advisedby(A, B)', {'': 'professor(B), student(A)', 'true': 'publication(C, A), publication(C, B)'}, {'true,true': [0.982, 1, 27], 'true,false': [2.766, 9, 51], 'false': [3.94e-08, 68, 0]}], ['advisedby(A, B)', {'': 'student(A), professor(B)', 'true': 'publication(C, A), publication(C, B)'}, {'true,true': [0.982, 1, 27], 'true,false': [2.766, 9, 51], 'false': [0.0, 68, 0]}], ['advisedby(A, B)', {'': 'student(A), professor(B)', 'true': 'publication(C, A), publication(C, B)'}, {'true,true': [0.982, 1, 27], 'true,false': [2.766, 9, 51], 'false': [3.07e-08, 68, 0]}], ['advisedby(A, B)', {'': 'professor(B), student(A)', 'true': 'publication(C, A), publication(C, B)'}, {'true,true': [0.982, 1, 27], 'true,false': [2.766, 9, 51], 'false': [2.36e-08, 68, 0]}], ['advisedby(A, B)', {'': 'student(A), professor(B)', 'true': 'publication(C, A), publication(C, B)'}, {'true,true': [0.982, 1, 27], 'true,false': [2.766, 9, 51], 'false': [1.29e-08, 68, 0]}], ['advisedby(A, B)', {'': 'professor(B), student(A)', 'true': 'publication(C, A), publication(C, B)'}, {'true,true': [0.982, 1, 27], 'true,false': [2.766, 9, 51], 'false': [2.11e-08, 68, 0]}], ['advisedby(A, B)', {'': 'student(A), professor(B)', 'true': 'publication(C, A), publication(C, B)'}, {'true,true': [0.982, 1, 27], 'true,false': [2.766, 9, 51], 'false': [0.0, 68, 0]}]]
# [{'': [0.10072314049586789, 5.224578939412501e-17], 'true': [0.03443877551020513, 0.12750000000000075]}, {'': [0.09973301876920311, -3.918434204559376e-17], 'true': [0.03443877551020399, 0.1274999999999995]}, {'': [0.098795542225602, 2.938825653419532e-17], 'true': [0.03443877551020431, 0.1275000000000001]}, {'': [0.09836543584212197, 2.2857532859929692e-17], 'true': [0.03443877551020421, 0.12749999999999967]}, {'': [0.09822916119826863, -9.79608551139844e-18], 'true': [0.034438775510204196, 0.12750000000000003]}, {'': [0.09819217209331864, 1.3877787807814457e-17], 'true': [0.034438775510204134, 0.12749999999999992]}, {'': [0.0981839013664323, 8.163404592832034e-18], 'true': [0.03443877551020413, 0.12749999999999997]}, {'': [0.09818194745298486, 2.44902137784961e-18], 'true': [0.03443877551020412, 0.1275]}, {'': [0.0981793880440799, 6.530723674265627e-18], 'true': [0.034438775510204085, 0.12749999999999997]}, {'': [0.0981744343316192, -8.163404592832033e-19], 'true': [0.034438775510204085, 0.12750000000000003]}]
#
#
# ******************************************
# Performing Theory Revision
# ******************************************
# Refining iteration 1
# ********************************
# Candidate for revision
# 0;;advisedby(A, B) :- professor(B), student(A).;true;true
# 1;;advisedby(A, B) :- professor(B), student(A).;true;true
# 2;;advisedby(A, B) :- professor(B), student(A).;true;true
# 3;;advisedby(A, B) :- professor(B), student(A).;true;true
# 4;;advisedby(A, B) :- student(A), professor(B).;true;true
# 5;;advisedby(A, B) :- student(A), professor(B).;true;true
# 6;;advisedby(A, B) :- professor(B), student(A).;true;true
# 7;;advisedby(A, B) :- student(A), professor(B).;true;true
# 8;;advisedby(A, B) :- professor(B), student(A).;true;true
# 9;;advisedby(A, B) :- student(A), professor(B).;true;true
#
#
# Refining candidate
# ***************************
# WILL Produced-Tree #1
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( tempadvisedby(C, B), ta(D, C, E) )
# %   | then if ( ta(F, A, G), ta(D, H, G) )
# %   | | then if ( samecourse(D, F) )
# %   | | | then return 0.6581489350995122;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   | | | else return 0.8581489350995123;  // std dev = 0,000, 9,000 (wgt'ed) examples reached here.  /* #pos=9 */
# %   | | else return 0.8581489350995123;  // std dev = 0,000, 17,000 (wgt'ed) examples reached here.  /* #pos=17 */
# %   | else if ( publication(I, B) )
# %   | | then if ( publication(I, J), student(J) )
# %   | | | then return 0.7812258581764345;  // std dev = 1,664, 39,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=36 */
# %   | | | else return 0.5724346493852266;  // std dev = 1,690, 14,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=10 */
# %   | | else return 0.3581489350995122;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   else return -0.14185106490048768;  // std dev = 5,96e-08, 68,000 (wgt'ed) examples reached here.  /* #neg=68 */
# WILL Produced-Tree #2
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( tempadvisedby(C, B), ta(D, C, E) )
# %   | then if ( ta(F, A, G), ta(D, H, G) )
# %   | | then if ( samecourse(D, F) )
# %   | | | then return 0.5580193346218546;  // std dev = 0,894, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   | | | else return 0.7194734122109543;  // std dev = 2,98e-08, 9,000 (wgt'ed) examples reached here.  /* #pos=9 */
# %   | | else return 0.7194734122109543;  // std dev = 4,21e-08, 17,000 (wgt'ed) examples reached here.  /* #pos=17 */
# %   | else if ( publication(I, B) )
# %   | | then if ( publication(J, A), tempadvisedby(K, B) )
# %   | | | then return 0.4600647258838169;  // std dev = 1,672, 14,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=10 */
# %   | | | else return 0.6677230871659611;  // std dev = 1,639, 39,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=36 */
# %   | | else return 0.308741135785635;  // std dev = 1,000, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   else return -0.1254446385283916;  // std dev = 0,000, 68,000 (wgt'ed) examples reached here.  /* #neg=68 */
# WILL Produced-Tree #3
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, B), publication(C, A) )
# %   | then if ( ta(D, A, E), tempadvisedby(F, B) )
# %   | | then if ( ta(G, H, E), ta(G, F, I) )
# %   | | | then return 0.6073157407131784;  // std dev = 0,095, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | | | else return 0.27589139323386297;  // std dev = 0,786, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | else return 0.5928915937583076;  // std dev = 0,124, 20,000 (wgt'ed) examples reached here.  /* #pos=20 */
# %   | else if ( publication(J, A) )
# %   | | then if ( publication(J, K), professor(K) )
# %   | | | then return 0.08446749109671717;  // std dev = 1,365, 9,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=4 */
# %   | | | else return 0.6526695873780739;  // std dev = 0,148, 7,000 (wgt'ed) examples reached here.  /* #pos=7 */
# %   | | else if ( publication(L, B) )
# %   | | | then return 0.5119325654580421;  // std dev = 1,615, 40,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=37 */
# %   | | | else return 0.40588940275243546;  // std dev = 0,768, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   else return -0.11231637819360629;  // std dev = 4,47e-08, 68,000 (wgt'ed) examples reached here.  /* #neg=68 */
# WILL Produced-Tree #4
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( tempadvisedby(C, B), ta(D, C, E) )
# %   | then if ( ta(F, G, E), publication(H, G) )
# %   | | then return 0.44150250238321004;  // std dev = 0,179, 24,000 (wgt'ed) examples reached here.  /* #pos=24 */
# %   | | else if ( ta(I, J, E), ta(I, A, K) )
# %   | | | then return 0.12473090746496947;  // std dev = 0,743, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | else return 0.4427408156177024;  // std dev = 0,051, 4,000 (wgt'ed) examples reached here.  /* #pos=4 */
# %   | else if ( tempadvisedby(L, B) )
# %   | | then if ( ta(M, A, N) )
# %   | | | then return 0.3485590633858702;  // std dev = 1,191, 11,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=9 */
# %   | | | else return 0.19717882722326804;  // std dev = 1,244, 9,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=6 */
# %   | | else if ( publication(P, B) )
# %   | | | then return 0.410086698685458;  // std dev = 1,293, 33,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=31 */
# %   | | | else return 0.17668901368450063;  // std dev = 0,941, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   else return -0.10159632948783621;  // std dev = 3,94e-08, 68,000 (wgt'ed) examples reached here.  /* #neg=68 */
# WILL Produced-Tree #5
# % FOR advisedby(A, B):
# %   if ( student(A), professor(B) )
# %   then if ( publication(C, A), publication(C, B) )
# %   | then if ( ta(D, A, E), tempadvisedby(F, B) )
# %   | | then if ( ta(G, H, E), ta(G, F, I) )
# %   | | | then return 0.35324141755804533;  // std dev = 0,089, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | | | else return 0.1151875259891999;  // std dev = 0,777, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | else return 0.360501742885027;  // std dev = 0,220, 20,000 (wgt'ed) examples reached here.  /* #pos=20 */
# %   | else if ( tempadvisedby(J, B), ta(K, J, L) )
# %   | | then if ( ta(M, N, L), publication(P, N) )
# %   | | | then return 0.34034601451902674;  // std dev = 0,120, 15,000 (wgt'ed) examples reached here.  /* #pos=15 */
# %   | | | else return 0.2094397327295893;  // std dev = 0,796, 6,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=5 */
# %   | | else if ( publication(Q, A) )
# %   | | | then return 0.15819379384977295;  // std dev = 1,559, 15,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=10 */
# %   | | | else return 0.2804730194174356;  // std dev = 1,508, 24,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=21 */
# %   else return -0.09269127618926105;  // std dev = 0,000, 68,000 (wgt'ed) examples reached here.  /* #neg=68 */
# WILL Produced-Tree #6
# % FOR advisedby(A, B):
# %   if ( student(A), professor(B) )
# %   then if ( publication(C, B), publication(C, A) )
# %   | then if ( ta(D, A, E), tempadvisedby(F, B) )
# %   | | then if ( ta(G, H, E), ta(G, F, I) )
# %   | | | then return 0.2777277210522836;  // std dev = 0,078, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | | | else return 0.08717066711026407;  // std dev = 0,778, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | else return 0.28290953475617453;  // std dev = 0,196, 20,000 (wgt'ed) examples reached here.  /* #pos=20 */
# %   | else if ( tempadvisedby(J, B), publication(K, A) )
# %   | | then if ( publication(K, L), professor(L) )
# %   | | | then return -0.10190343052356132;  // std dev = 0,958, 5,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=2 */
# %   | | | else return 0.39867630238720003;  // std dev = 0,011, 3,000 (wgt'ed) examples reached here.  /* #pos=3 */
# %   | | else if ( ta(M, A, N), publication(P, A) )
# %   | | | then return 0.12312089893094857;  // std dev = 0,754, 4,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=3 */
# %   | | | else return 0.22565051111217707;  // std dev = 1,852, 48,000 (wgt'ed) examples reached here.  /* #neg=5 #pos=43 */
# %   else return -0.0851847513883968;  // std dev = 3,07e-08, 68,000 (wgt'ed) examples reached here.  /* #neg=68 */
# WILL Produced-Tree #7
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( publication(C, B), publication(C, A) )
# %   | then if ( ta(D, A, E), tempadvisedby(F, B) )
# %   | | then if ( ta(G, H, E), ta(G, F, I) )
# %   | | | then return 0.22584459819907043;  // std dev = 0,068, 5,000 (wgt'ed) examples reached here.  /* #pos=5 */
# %   | | | else return 0.06628915013396726;  // std dev = 0,778, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | else return 0.22962191339729388;  // std dev = 0,173, 20,000 (wgt'ed) examples reached here.  /* #pos=20 */
# %   | else if ( ta(J, A, K), tempadvisedby(L, B) )
# %   | | then if ( publication(M, L) )
# %   | | | then return -7.017409329261685E-4;  // std dev = 0,591, 3,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=2 */
# %   | | | else return 0.2350007072206331;  // std dev = 0,930, 18,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=17 */
# %   | | else if ( tempadvisedby(N, B), publication(P, B) )
# %   | | | then return 0.03646608658808414;  // std dev = 1,078, 11,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=8 */
# %   | | | else return 0.1752065612576483;  // std dev = 1,611, 28,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=24 */
# %   else return -0.07877675473109173;  // std dev = 2,36e-08, 68,000 (wgt'ed) examples reached here.  /* #neg=68 */
# WILL Produced-Tree #8
# % FOR advisedby(A, B):
# %   if ( student(A), professor(B) )
# %   then if ( tempadvisedby(C, B), ta(D, C, E) )
# %   | then if ( ta(D, A, F) )
# %   | | then return 0.03901059213403422;  // std dev = 0,797, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   | | else return 0.20340608056036202;  // std dev = 0,221, 26,000 (wgt'ed) examples reached here.  /* #pos=26 */
# %   | else if ( publication(G, B) )
# %   | | then if ( publication(G, H), student(H) )
# %   | | | then return 0.16999862004409405;  // std dev = 1,481, 39,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=36 */
# %   | | | else return 0.038563745975881324;  // std dev = 1,336, 14,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=10 */
# %   | | else return -0.012798272701697783;  // std dev = 0,933, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   else return -0.07324622576333704;  // std dev = 1,29e-08, 68,000 (wgt'ed) examples reached here.  /* #neg=68 */
# WILL Produced-Tree #9
# % FOR advisedby(A, B):
# %   if ( professor(B), student(A) )
# %   then if ( tempadvisedby(C, B), ta(D, C, E) )
# %   | then if ( ta(D, A, F) )
# %   | | then return 0.03206443744645027;  // std dev = 0,798, 5,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=4 */
# %   | | else return 0.17274179798281522;  // std dev = 0,196, 26,000 (wgt'ed) examples reached here.  /* #pos=26 */
# %   | else if ( tempadvisedby(G, B) )
# %   | | then if ( ta(H, A, I) )
# %   | | | then return 0.11710745309556128;  // std dev = 1,104, 11,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=9 */
# %   | | | else return -0.0165074138673345;  // std dev = 1,048, 9,000 (wgt'ed) examples reached here.  /* #neg=3 #pos=6 */
# %   | | else if ( publication(J, B) )
# %   | | | then return 0.14484487953008254;  // std dev = 1,274, 33,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=31 */
# %   | | | else return -0.009637196522980382;  // std dev = 0,933, 4,000 (wgt'ed) examples reached here.  /* #neg=2 #pos=2 */
# %   else return -0.0684269778442027;  // std dev = 2,11e-08, 68,000 (wgt'ed) examples reached here.  /* #neg=68 */
# WILL Produced-Tree #10
# % FOR advisedby(A, B):
# %   if ( student(A), professor(B) )
# %   then if ( publication(C, B), publication(C, A) )
# %   | then if ( publication(C, D), ta(E, D, F) )
# %   | | then if ( tempadvisedby(G, B), ta(H, G, I) )
# %   | | | then return 0.1683017782941533;  // std dev = 0,132, 7,000 (wgt'ed) examples reached here.  /* #pos=7 */
# %   | | | else return 0.055240807787266755;  // std dev = 0,795, 6,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=5 */
# %   | | else return 0.1547150536595436;  // std dev = 0,160, 15,000 (wgt'ed) examples reached here.  /* #pos=15 */
# %   | else if ( publication(J, A), publication(K, B) )
# %   | | then if ( publication(J, L), publication(K, L) )
# %   | | | then return -0.22262216397318002;  // std dev = 0,993, 6,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=2 */
# %   | | | else return 0.22716505929075126;  // std dev = 0,080, 7,000 (wgt'ed) examples reached here.  /* #pos=7 */
# %   | | else if ( ta(M, A, N), tempadvisedby(P, B) )
# %   | | | then return 0.12541587693959727;  // std dev = 0,855, 17,000 (wgt'ed) examples reached here.  /* #neg=1 #pos=16 */
# %   | | | else return 0.09126115118571779;  // std dev = 1,591, 30,000 (wgt'ed) examples reached here.  /* #neg=4 #pos=26 */
# %   else return -0.06419184008202623;  // std dev = 0,000, 68,000 (wgt'ed) examples reached here.  /* #neg=68 */
# Results
#    AUC ROC   = 0.974286
#    AUC PR    = 0.966059
#    CLL	      = -0.248882
#    Precision = 0.911765 at threshold = 0.5
#    Recall    = 0.885714
#    F1        = 0.898551
#
#
# Total learning time: 21.021 seconds
# Total inference time: 1.41 seconds
# AUC ROC: 0.974286
#
#
# Results scoring model
#    AUC ROC   = 0.991289
#    AUC PR    = 0.989492
#    CLL	      = -0.182964
#    Precision = 0.928571 at threshold = 0.5
#    Recall    = 1.0
#    F1        = 0.962963
#
#
# Total scoring time: 1.57 seconds
# Refined model CLL: -0.182964
#
#
# ******************************************
# Best model found
# ******************************************
# Results
#    AUC ROC   = 0.974286
#    AUC PR    = 0.966059
#    CLL	      = -0.248882
#    Precision = 0.911765 at threshold = 0.5
#    Recall    = 0.885714
#    F1        = 0.898551
#
#
# Total learning time: 28.846 seconds
# Total inference time: 1.41 seconds
# AUC ROC: 0.974286
# Total revision time: 28.846
# Best scored revision CLL: -0.182964

# %%
from graphviz import Source
s = Source.from_file("boostsrl/best/train/models/bRDNs/dotFiles/WILLTreeFor_advisedby2.dot")
s.view()
# Out:
# 'boostsrl/best/train/models/bRDNs/dotFiles/WILLTreeFor_advisedby2.dot.pdf'

# %%
from graphviz import Source
s = Source.from_file("boostsrl/results/WILLTreeFor_advisedby2.dot")
s.view()
# Out:
# 'boostsrl/results/WILLTreeFor_advisedby2.dot.pdf'
